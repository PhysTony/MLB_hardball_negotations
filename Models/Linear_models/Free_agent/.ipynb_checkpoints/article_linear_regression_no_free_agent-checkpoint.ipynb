# %% [markdown]
# # Modelo lineal del artículo - No agentes libres
#
# Para entender mejor el proceso que se lleva a cabo para obtener el modelo es recomendable revisar primero el script referente a los agentes libres. En este script, se aplicará el modelo a los jugadores que no son agentes libres.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from matplotlib.colors import ListedColormap
from sklearn.naive_bayes import GaussianNB
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
import pandas as pd
import numpy as np
import array
import math
import os
import warnings
print('Modulos importados')
# Out:
# Modulos importados

# %%
# Configuraciones
warnings.filterwarnings('ignore')
# Reduzcamos el número de línea a leer
pd.options.display.max_rows = 15

# %%
# Veamos el directorio actual de trabajo
print(os.getcwd())
# El directorio anterior es el correcto, pero si no lo fuese, hacemos lo sigueinte:
path = '/home/usuario/Documentos/Github/Proyectos/MLB_HN'
os.chdir(path)
# Out:
# /home/usuario/Documentos/Github/Proyectos/MLB_HN

# %%
print("Para modificar el tamaño de todos los gráficos")
from matplotlib import rcParams
rcParams['figure.figsize'] = 15,9
# Out:
# Para modificar el tamaño de todos los gráficos

# %% [markdown]
# El cósigo es totalmente análogo al script citado anteriormente. Esto se debe a que el código se construye pensando en la replicabilidad. Con esto en mente, solo hay que cambiar los directorios de los cuáles leeremos las bases de datos, es decir, las que conciernen a los no agentes libres,

# %%
# Años de análisis
period = 11
csv = '.csv'
# Directorios
names_path = 'Data/Teams/team_acronym'
teams_path = 'Data/New_Data/Teams/free_agents_team_'
batters_path = 'Data/New_Data/Hitters/No_Free_Agent/no_free_agents_batters_'
pitchers_path = 'Data/New_Data/Pitchers/No_Free_Agent/no_free_agents_pitchers_'
# Originales:
df_team = [None]*period
df_team_copy = [None]*period
df_batters = [None]*period
df_batters_copy = [None]*period
df_pitchers = [None]*period
df_pitchers_copy = [None]*period
df_players = [None]*period
df_players_copy = [None]*period

# %% [markdown]
# Leamos todos las bases de datos correspondientes

# %%
names = pd.read_csv(names_path + csv)
for year in range(0,period):
    df_batters[year] = pd.read_csv(batters_path + str(2011 + year) + csv)
    df_batters_copy[year] = df_batters[year].copy()
    
    df_pitchers[year] = pd.read_csv(pitchers_path + str(2011 + year) + csv)
    df_pitchers_copy[year] = df_pitchers[year].copy()
    
    df_team[year] = pd.read_csv(teams_path + str(2011 + year) + csv)
    df_team_copy[year] = df_team[year].copy()

# %% [markdown]
# Observemos el contenido de las bases de datos

# %%
# Nombres de todos los equipos en todss las bases de datos
names.head()
# Out:
#                  Equipo Acronimo         Estado
# 0  Arizona Diamondbacks      ARI        Arizona
# 1        Atlanta Braves      ATL        Georgia
# 2     Baltimore Orioles      BAL       Maryland
# 3        Boston Red Sox      BOS  Massachusetts
# 4          Chicago Cubs      CHC       Illinois

# %%
# Equipos
df_team_copy[1].head()
# Out:
#                   Equipo  Cantidad_agentes_libres  Valor_contrato Acronimo  \
# 0     Los Angeles Angels                        4       321150000      LAA
# 1         Detroit Tigers                        3       221000000      DET
# 2          Miami Marlins                        6       203300000      MIA
# 3  Philadelphia Phillies                        7        57650000      PHI
# 4    Los Angeles Dodgers                        9        44651311      LAD
#
#    Victorias  Juegos totales  Promedio_victorias
# 0         89             162            0.549383
# 1         88             162            0.543210
# 2         69             162            0.425926
# 3         81             162            0.500000
# 4         86             162            0.530864

# %%
# Bateadores
df_batters_copy[1].head()
# Out:
#           Jugador Posicion  Juegos  Porcetnaje_juegos  At-bats  Bateos  \
# 0     Derek Jeter       SS     159              0.982      683     216
# 1  Miguel Cabrera       1B     161              0.994      622     205
# 2   Robinson Cano       2B     161              0.994      627     196
# 3  Everth Cabrera       SS     230              0.710      796     196
# 4  Everth Cabrera       SS     230              0.710      796     196
#
#    Home-runs  RBI  Porcentaje_bateo    OPS Equipo    Sueldo
# 0         15   58             0.316  0.791    NYY  16000000
# 1         44  139             0.330  0.999    DET  21000000
# 2         33   94             0.313  0.929    NYY  14000000
# 3          4   48             0.246  0.648     SD    480000
# 4          4   48             0.246  0.648     SD    480000

# %%
# PItchers
df_pitchers_copy[1].head()
# Out:
#            Jugador Posicion  Juegos  Juegos_iniciados  Inning_pitched  \
# 0      R.A. Dickey       SP      34                33           233.7
# 1  Felix Hernandez       SP      33                33           232.0
# 2    James Shields       SP      33                33           227.7
# 3  Clayton Kershaw       SP      34                33           227.7
# 4        Matt Cain       RP      35                32           219.3
#
#    Bateos_pitcher  Carreras  Carreras_ganadas  Walks  Strike-outs  Wins  \
# 0             192        78                71     54          230    20
# 1             209        84                79     56          223    13
# 2             209       103                89     58          223    15
# 3             170        70                64     63          229    14
# 4             177        73                68     51          193    16
#
#    Losses  Saves  WHIP   ERA Equipo    Sueldo
# 0       6      0  1.05  2.74    NYM   4750000
# 1       9      0  1.14  3.07    SEA  19750000
# 2      10      0  1.17  3.52     TB   7500000
# 3       9      0  1.02  2.53    LAD   7750000
# 4       5      0  1.04  2.79     SF  16266666

# %% [markdown]
# Vemos que hasta las columnas de interés tienen el mismo nombre que los encontrados en las bases de datos de los agentes libres.

# %% [markdown]
# ### Construcción de la base de datos para el modelo
#
# #### Base de datos de los equipos
#
# Primero, tenemos que determinar cuál es el mínimo y máximo del promedio de victorias de cada equipo a lo largo del periodo de análisis. Primero, creemos un diccionario que guarde en una lista ambos valores cuya llave asociada sea el nombre del equipo. Se tomará el promedio y no el número de victorias puesto que no todos los equipos juegan la misma cantidad de partidos en una temporada y habría fallos en el análisis en años como el 2020 por la pandemia que provocó que la cantidad de juegos por temporada fuiera mucho menor  a la usual, siendo alrededor de 60 juegos en dicha temporada.
#
# Para crear este diccionario usaremos la base de datos de los acrónimos puesto que contiene todos los equipos que puedan haber en las bases de datos de los equipos en el periodo de análisis

# %%
minmax_victories = {}
length_names = len(names['Equipo'])
# CReemos las llaves con los nombres de los equipos
for i in range(0,length_names):
    minmax_victories[str(names['Equipo'].iloc[i])] = [None]*2

# %% [markdown]
# Como valores de comparación para las victorias usaremos cualquier base de datos que contenga la misma cantidad de filas que la base de datos *names*. Obtengamos el índice de las bases de datos que cumplan esa condición.

# %%
for year in range(0,period):
    if len(df_team_copy[year]['Equipo']) == length_names:
        print(year)
# Out:
# 2
# 3
# 4
# 5
# 6
# 8
# 10

# %%
# Usaremos la tercera base de datos
team_name = list(minmax_victories.keys())
for i in range(length_names):
    for j in range(length_names):
        if team_name[i] == df_team_copy[2]['Equipo'].iloc[j]:
            minmax_victories[team_name[i]][0] = df_team_copy[2]['Promedio_victorias'].iloc[j]
            minmax_victories[team_name[i]][1] = df_team_copy[2]['Promedio_victorias'].iloc[j]

# %% [markdown]
# Ahora, recorreremos el promedio de victorias de todas las bases de datos para hallar el menor y mayor número de victorias que ha tenido cada equipo en el periodo de análisis.

# %%
for year in range(period):
    # Nombres de los equipos en la base de datos
    team_year_name = list(df_team_copy[year]['Equipo'])
    
    for i in range(length_names):
        # Mínimo actual
        min_victory = minmax_victories[team_name[i]][0]
        # Máximo actual:
        max_victory = minmax_victories[team_name[i]][1]
        
        for j in range(len(team_year_name)):
            
            if team_name[i] == team_year_name[j]:
                year_victory = df_team_copy[year]['Promedio_victorias'].iloc[j]
                
                # Mínimo nuevo:
                if year_victory < min_victory:
                    minmax_victories[team_name[i]][0] = year_victory
                # Máximo nuevo:
                elif year_victory > max_victory:
                    minmax_victories[team_name[i]][1] = year_victory

# %% [markdown]
# Los valores de la lista ahora son de la siguiente forma:

# %%
print(minmax_victories[team_name[1]])
# Out:
# [0.40625, 0.6024844720496895]

# %% [markdown]
# A continuación, se creará una columna que indique si la victoria de la temporada -correspondiente a la base de datos donde se situe- está más cercana del promedio más alto de victorias o del menor. 1 indicará que está más cercano a la mayor victoria, y 0 en otro caso -en caso de empate, se eligirá al 1.

# %%
for year in range(period):
    # Nombres de los equipos en la base de datos
    team_year_name = list(df_team_copy[year]['Equipo'])
    # COlumna dummy:
    df_team_copy[year]['I_t'] = -1
    
    for i in range(length_names):
        # Mínimo actual
        min_victory = minmax_victories[team_name[i]][0]
        # Máximo actual:
        max_victory = minmax_victories[team_name[i]][1]
        
        for j in range(len(team_year_name)):
            
            if team_name[i] == team_year_name[j]:
                year_victory = df_team_copy[year]['Promedio_victorias'].iloc[j]
                
                # Distancia al mínimo:
                dist_min = year_victory - min_victory
                # Distancia al máximo:
                dist_max = max_victory - year_victory
                
                # Mínimo nuevo:
                if dist_min < dist_max:
                    df_team_copy[year]['I_t'].iloc[j] = 1
                # Máximo nuevo
                else:  
                    df_team_copy[year]['I_t'].iloc[j] = 0

# %%
df_team_copy[6].tail()
# Out:
#                Equipo  Cantidad_agentes_libres  Valor_contrato Acronimo  \
# 24  Milwaukee Brewers                        3         7550000      MIL
# 25  Chicago White Sox                        1         6000000      CHW
# 26     Boston Red Sox                        1         5500000      BOS
# 27    Cincinnati Reds                        2         5300000      CIN
# 28     Detroit Tigers                        1         2000000      DET
#
#     Victorias  Juegos totales  Promedio_victorias  I_t
# 24         86             162            0.530864    0
# 25         67             162            0.413580    1
# 26         93             162            0.574074    0
# 27         68             162            0.419753    1
# 28         64             162            0.395062    1

# %% [markdown]
# Usemos la variable dummy para crear la columna que contenga el siguiente dato:
#
# $$
# X = \left( -1 \right)^{I_{t}^{-}}\frac{y_{t}}{\sqrt{y_H}}
# $$

# %%
for year in range(period):
    # Nombres de los equipos en la base de datos
    team_year_name = list(df_team_copy[year]['Equipo'])
    # Columna de la nueva variable
    df_team_copy[year]['X'] = -1
    
    for i in range(length_names):        
        for j in range(len(team_year_name)):
            
            if team_name[i] == team_year_name[j]:
                # Variables auxiliares
                mean_victory = df_team_copy[year]['Promedio_victorias'].iloc[j]
                dummy = df_team_copy[year]['I_t'].iloc[j]
                s_max_victory = np.power(minmax_victories[team_name[i]][1],0.5)
                if dummy == 0:
                    parity = 1
                else:
                    parity = -1
                
                # Variable dummy nueva
                df_team_copy[year]['X'].iloc[j] = parity*mean_victory/s_max_victory

# %%
df_team_copy[1].tail()
# Out:
#                   Equipo  Cantidad_agentes_libres  Valor_contrato Acronimo  \
# 21    Kansas City Royals                        2         5000000       KC
# 22  San Francisco Giants                        3         4800000       SF
# 23        Atlanta Braves                        1         1000000      ATL
# 24     Chicago White Sox                        1          900000      CHW
# 25        Houston Astros                        1          750000      HOU
#
#     Victorias  Juegos totales  Promedio_victorias  I_t         X
# 21         72             162            0.444444    1 -0.581656
# 22         94             162            0.580247    0  0.712844
# 23         94             162            0.580247    0  0.747549
# 24         85             162            0.524691    0  0.686982
# 25         55             162            0.339506    1 -0.418415

# %%
df_team_copy[1].tail()
# Out:
#                   Equipo  Cantidad_agentes_libres  Valor_contrato Acronimo  \
# 21    Kansas City Royals                        2         5000000       KC
# 22  San Francisco Giants                        3         4800000       SF
# 23        Atlanta Braves                        1         1000000      ATL
# 24     Chicago White Sox                        1          900000      CHW
# 25        Houston Astros                        1          750000      HOU
#
#     Victorias  Juegos totales  Promedio_victorias  I_t         X
# 21         72             162            0.444444    1 -0.581656
# 22         94             162            0.580247    0  0.712844
# 23         94             162            0.580247    0  0.747549
# 24         85             162            0.524691    0  0.686982
# 25         55             162            0.339506    1 -0.418415

# %% [markdown]
# Por último, solo nos quedaremos con las columnas de utilidad que son el acrónimo del equipo y la variable $X$.

# %%
for year in range(0,period):
    df_team_copy[year] = df_team_copy[year][["Acronimo", "X"]]

# %%
df_team_copy[1].head()
# Out:
#   Acronimo         X
# 0      LAA  0.704166
# 1      DET  0.716941
# 2      MIA -0.592555
# 3      PHI  0.702782
# 4      LAD -0.629194

# %% [markdown]
# ### Batters
#
# Preparemos las bases de datos de los *batters*.

# %% [markdown]
# Por otro lado, tenemos que traer los valores de los salarios -en dolares- a valor presente, del 2021, ajustado por la inflación. Usaremos la página [CPI Inflation Calculator](https://www.in2013dollars.com/)
#
# Guardaremos los porcentajes de cambio de cada año en un diccionario, de paso, cambiaremos el nombre de la columna *Equipo* por *Acrónimo*.

# %%
change_inflation_percentage = {2011:20.46, 2012:18.02, 2013:16.32, 2014:14.46, 2015:14.33, 2016:12.90, 2017:10.55, 2018:7.86, 2019:5.99, 2020:4.70, 2021:1}

# %%
for year in range(0,period):
    df_batters_copy[year][["Salario_ajustado_2021"]] = df_batters_copy[year][["Sueldo"]]*(1 + change_inflation_percentage[2011 + year]*0.01)
    df_batters_copy[year].rename(columns = {'Equipo':'Acronimo'}, inplace = True)

# %%
df_batters_copy[1].head()
# Out:
#           Jugador Posicion  Juegos  Porcetnaje_juegos  At-bats  Bateos  \
# 0     Derek Jeter       SS     159              0.982      683     216
# 1  Miguel Cabrera       1B     161              0.994      622     205
# 2   Robinson Cano       2B     161              0.994      627     196
# 3  Everth Cabrera       SS     230              0.710      796     196
# 4  Everth Cabrera       SS     230              0.710      796     196
#
#    Home-runs  RBI  Porcentaje_bateo    OPS Acronimo    Sueldo  \
# 0         15   58             0.316  0.791      NYY  16000000
# 1         44  139             0.330  0.999      DET  21000000
# 2         33   94             0.313  0.929      NYY  14000000
# 3          4   48             0.246  0.648       SD    480000
# 4          4   48             0.246  0.648       SD    480000
#
#    Salario_ajustado_2021
# 0             18883200.0
# 1             24784200.0
# 2             16522800.0
# 3               566496.0
# 4               566496.0

# %% [markdown]
# Lo que se tiene que hacer a continuación es añadir la variable $X$ a la base de datos anterior, esto se tiene que hacer de acuerdo al equipo

# %%
for year in range(0,period):
    df_batters_copy[year] = pd.merge(df_batters_copy[year], df_team_copy[year], on = 'Acronimo')

# %%
df_batters_copy[1].head()
# Out:
#              Jugador Posicion  Juegos  Porcetnaje_juegos  At-bats  Bateos  \
# 0        Derek Jeter       SS     159              0.982      683     216
# 1      Robinson Cano       2B     161              0.994      627     196
# 2      Ichiro Suzuki       RF     162              1.000      629     178
# 3       Nick Swisher       OF     148              0.914      537     146
# 4  Curtis Granderson       RF     160              0.988      596     138
#
#    Home-runs  RBI  Porcentaje_bateo    OPS Acronimo    Sueldo  \
# 0         15   58             0.316  0.791      NYY  16000000
# 1         33   94             0.313  0.929      NYY  14000000
# 2          9   55             0.283  0.696      NYY  18000000
# 3         24   93             0.272  0.837      NYY  10250000
# 4         43  106             0.232  0.811      NYY  10025000
#
#    Salario_ajustado_2021        X
# 0             18883200.0  0.73544
# 1             16522800.0  0.73544
# 2             21243600.0  0.73544
# 3             12097050.0  0.73544
# 4             11831505.0  0.73544

# %% [markdown]
# Solo interesan las columnas que contienen el nombre del jugador, su salario ajustado y la variable $X$.
#
# $$
# X = \left( -1 \right)^{I_{t}^{-}}\frac{y_{t}}{\sqrt{y_H}}
# $$

# %%
for year in range(0,period):
    df_batters_copy[year] = df_batters_copy[year][["Jugador", "Salario_ajustado_2021", "X"]]

# %%
df_batters_copy[1].head()
# Out:
#              Jugador  Salario_ajustado_2021        X
# 0        Derek Jeter             18883200.0  0.73544
# 1      Robinson Cano             16522800.0  0.73544
# 2      Ichiro Suzuki             21243600.0  0.73544
# 3       Nick Swisher             12097050.0  0.73544
# 4  Curtis Granderson             11831505.0  0.73544

# %% [markdown]
# ### Pitchers
#
# Repetiremos el mismo proceso que con las bases de datos de los *batters*

# %%
for year in range(0,period):
    df_pitchers_copy[year][["Salario_ajustado_2021"]] = df_pitchers_copy[year][["Sueldo"]]*(1 + change_inflation_percentage[2011 + year]*0.01)
    df_pitchers_copy[year].rename(columns = {'Equipo':'Acronimo'}, inplace = True)
    
    df_pitchers_copy[year] = pd.merge(df_pitchers_copy[year], df_team_copy[year], on = 'Acronimo')
    
    df_pitchers_copy[year] = df_pitchers_copy[year][["Jugador", "Salario_ajustado_2021", "X"]]

# %%
df_pitchers_copy[1].head()
# Out:
#           Jugador  Salario_ajustado_2021         X
# 0     R.A. Dickey              5605950.0 -0.614377
# 1  Jonathan Niese               967173.9 -0.614377
# 2   Johan Santana             28324800.0 -0.614377
# 3      Dillon Gee               592460.4 -0.614377
# 4   Bobby Parnell               594820.8 -0.614377

# %% [markdown]
# ### Players
#
# Debido a que hay agentes libres que son tanto *batters* como *pitchers*, haremos el merge por año.
#
# Sin embargo, primero tenemos que obtener como referencia el número de jugadores que tendrá dicho dataframe; esto, para evitar errores. Para ello, necesitamos obtener los nombres de cada base de datos por año y unirlos ya sea eliminando duplicados o con otro método. Finalmente, se imprimirá la longitud **mínima** de dicha lista. Se dice mínima puesto que aquí no estamos haciendo distinción por caracetrísticas ajenas al nombre.

# %%
for year in range(0,period):
    print("Año: " + str(2011 + year))
    print("Número de nombres únicos en batters: ")
    batters_names = np.unique(df_batters_copy[year]["Jugador"].tolist())
    print(len(batters_names))
    
    print("Número de nombres únicos en pitchers: ")
    pitchers_names = np.unique(df_pitchers_copy[year]["Jugador"].tolist())
    print(len(pitchers_names))
    
    print("Número de nombres únicos en el merge:")
    merge_players = np.unique(batters_names.tolist() + pitchers_names.tolist())
    print(len(merge_players))
    print()
# Out:
# Año: 2011
# Número de nombres únicos en batters:
# 20
# Número de nombres únicos en pitchers:
# 11
# Número de nombres únicos en el merge:
# 23
#
# Año: 2012
# Número de nombres únicos en batters:
# 557
# Número de nombres únicos en pitchers:
# 363
# Número de nombres únicos en el merge:
# 709
#
# Año: 2013
# Número de nombres únicos en batters:
# 654
# Número de nombres únicos en pitchers:
# 434
# Número de nombres únicos en el merge:
# 861
#
# Año: 2014
# Número de nombres únicos en batters:
# 684
# Número de nombres únicos en pitchers:
# 468
# Número de nombres únicos en el merge:
# 917
#
# Año: 2015
# Número de nombres únicos en batters:
# 731
# Número de nombres únicos en pitchers:
# 517
# Número de nombres únicos en el merge:
# 994
#
# Año: 2016
# Número de nombres únicos en batters:
# 733
# Número de nombres únicos en pitchers:
# 521
# Número de nombres únicos en el merge:
# 981
#
# Año: 2017
# Número de nombres únicos en batters:
# 747
# Número de nombres únicos en pitchers:
# 541
# Número de nombres únicos en el merge:
# 1013
#
# Año: 2018
# Número de nombres únicos en batters:
# 737
# Número de nombres únicos en pitchers:
# 571
# Número de nombres únicos en el merge:
# 995
#
# Año: 2019
# Número de nombres únicos en batters:
# 784
# Número de nombres únicos en pitchers:
# 625
# Número de nombres únicos en el merge:
# 1074
#
# Año: 2020
# Número de nombres únicos en batters:
# 373
# Número de nombres únicos en pitchers:
# 447
# Número de nombres únicos en el merge:
# 803
#
# Año: 2021
# Número de nombres únicos en batters:
# 677
# Número de nombres únicos en pitchers:
# 546
# Número de nombres únicos en el merge:
# 931

# %% [markdown]
# Para facilitar el merge de las bases de datos eliminaremos los registros repetidos. Esto tiene como objetivo usar el método concat para evitarnos problemas de duplicados de columnas

# %%
for year in range(0,period):
    batters_names = np.unique(df_batters_copy[year]["Jugador"].tolist())
    pitchers_names = np.unique(df_pitchers_copy[year]["Jugador"].tolist())
    
    df_players_copy[year] = pd.concat([df_batters_copy[year], df_pitchers_copy[year]]).drop_duplicates().reset_index(drop=True)
    print("Año " + str(2011 + year) + ":")
    print(str(len(df_players_copy[year]["Jugador"])) + "\n")
# Out:
# Año 2011:
# 23
#
# Año 2012:
# 711
#
# Año 2013:
# 862
#
# Año 2014:
# 918
#
# Año 2015:
# 995
#
# Año 2016:
# 983
#
# Año 2017:
# 1013
#
# Año 2018:
# 995
#
# Año 2019:
# 1075
#
# Año 2020:
# 804
#
# Año 2021:
# 934

# %%
df_players_copy[1].head()
# Out:
#              Jugador  Salario_ajustado_2021        X
# 0        Derek Jeter             18883200.0  0.73544
# 1      Robinson Cano             16522800.0  0.73544
# 2      Ichiro Suzuki             21243600.0  0.73544
# 3       Nick Swisher             12097050.0  0.73544
# 4  Curtis Granderson             11831505.0  0.73544

# %% [markdown]
# Cuando hagamos el merge, tendremos que eliminar los duplicados restantes que no se pudieron hacer enlos dos códigos anteriores debido al hecho de que solo eliminamos duplicados exactos, pero ahora lo haremos específicamente con los nombres.

# %%
panel_data = pd.merge(df_players_copy[0], df_players_copy[1], how = 'outer', on = 'Jugador')

for year in range(2,period):
    panel_data = pd.merge(panel_data, df_players_copy[year], how = 'outer', on = 'Jugador')

panel_data.drop_duplicates(subset = 'Jugador', inplace = True)

# %%
panel_data.head()
# Out:
#           Jugador  Salario_ajustado_2021_x     X_x  Salario_ajustado_2021_y  \
# 0      Ryan Braun             6.023000e+06  0.7698             8.261400e+06
# 1  Prince Fielder             1.867130e+07  0.7698                      NaN
# 2      Corey Hart             8.231433e+06  0.7698             1.101520e+07
# 3    Rickie Weeks             5.420700e+06  0.7698             1.298220e+07
# 4   Casey McGehee             5.637528e+05  0.7698             2.994758e+06
#
#         X_y  Salario_ajustado_2021_x       X_x  Salario_ajustado_2021_y  \
# 0  0.665557               11050400.0 -0.593388               12590600.0
# 1       NaN               26811760.0  0.757677               27470400.0
# 2  0.665557                      NaN       NaN                      NaN
# 3  0.665557               12795200.0 -0.593388               13735200.0
# 4  0.735440                      NaN       NaN                1259060.0
#
#         X_y  Salario_ajustado_2021_x  ...  Salario_ajustado_2021_x       X_x  \
# 0 -0.657538               14862900.0  ...               22110000.0  0.689613
# 1 -0.538407               27496365.0  ...                      NaN       NaN
# 2       NaN                      NaN  ...                      NaN       NaN
# 3 -0.657538                      NaN  ...                      NaN       NaN
# 4  0.661257                      NaN  ...                      NaN       NaN
#
#    Salario_ajustado_2021_y       X_y  Salario_ajustado_2021_x       X_x  \
# 0               21572000.0  0.765078               20138100.0  0.718102
# 1                      NaN       NaN                      NaN       NaN
# 2                      NaN       NaN                      NaN       NaN
# 3                      NaN       NaN                      NaN       NaN
# 4                      NaN       NaN                      NaN       NaN
#
#    Salario_ajustado_2021_y       X_y  Salario_ajustado_2021   X
# 0               17799000.0 -0.627868                    NaN NaN
# 1                      NaN       NaN                    NaN NaN
# 2                      NaN       NaN                    NaN NaN
# 3                      NaN       NaN                    NaN NaN
# 4                      NaN       NaN                    NaN NaN
#
# [5 rows x 23 columns]

# %%
panel_data.tail()
# Out:
#             Jugador  Salario_ajustado_2021_x  X_x  Salario_ajustado_2021_y  \
# 2727     Kyle Tyler                      NaN  NaN                      NaN
# 2728  Oliver Ortega                      NaN  NaN                      NaN
# 2729    Luis Oviedo                      NaN  NaN                      NaN
# 2730    Ralph Garza                      NaN  NaN                      NaN
# 2731   Jovani Moran                      NaN  NaN                      NaN
#
#       X_y  Salario_ajustado_2021_x  X_x  Salario_ajustado_2021_y  X_y  \
# 2727  NaN                      NaN  NaN                      NaN  NaN
# 2728  NaN                      NaN  NaN                      NaN  NaN
# 2729  NaN                      NaN  NaN                      NaN  NaN
# 2730  NaN                      NaN  NaN                      NaN  NaN
# 2731  NaN                      NaN  NaN                      NaN  NaN
#
#       Salario_ajustado_2021_x  ...  Salario_ajustado_2021_x  X_x  \
# 2727                      NaN  ...                      NaN  NaN
# 2728                      NaN  ...                      NaN  NaN
# 2729                      NaN  ...                      NaN  NaN
# 2730                      NaN  ...                      NaN  NaN
# 2731                      NaN  ...                      NaN  NaN
#
#       Salario_ajustado_2021_y  X_y  Salario_ajustado_2021_x  X_x  \
# 2727                      NaN  NaN                      NaN  NaN
# 2728                      NaN  NaN                      NaN  NaN
# 2729                      NaN  NaN                      NaN  NaN
# 2730                      NaN  NaN                      NaN  NaN
# 2731                      NaN  NaN                      NaN  NaN
#
#       Salario_ajustado_2021_y  X_y  Salario_ajustado_2021         X
# 2727                      NaN  NaN               576205.0 -0.609222
# 2728                      NaN  NaN               576205.0 -0.609222
# 2729                      NaN  NaN               576205.0 -0.480123
# 2730                      NaN  NaN               576205.0 -0.567195
# 2731                      NaN  NaN               576205.0 -0.567195
#
# [5 rows x 23 columns]

# %%
panel_data.shape
# Out:
# (2717, 23)

# %% [markdown]
# Se aprecia que necesitamos reiniciar el índice, pero primero lo ordenaremos alfabéticamente por motivos de *buenas prácticas*.

# %%
panel_data = panel_data.sort_values(by = 'Jugador', ascending = True)

# %%
panel_data.reset_index(drop = True, inplace = True)
panel_data.head()
# Out:
#         Jugador  Salario_ajustado_2021_x  X_x  Salario_ajustado_2021_y  \
# 0   A.J. Achter                      NaN  NaN                      NaN
# 1    A.J. Alexy                      NaN  NaN                      NaN
# 2  A.J. Burnett                      NaN  NaN               19473300.0
# 3     A.J. Cole                      NaN  NaN                      NaN
# 4    A.J. Ellis                      NaN  NaN                 578298.0
#
#         X_y  Salario_ajustado_2021_x       X_x  Salario_ajustado_2021_y  \
# 0       NaN                      NaN       NaN                 572300.0
# 1       NaN                      NaN       NaN                      NaN
# 2  0.628260               19192800.0  0.747549                      NaN
# 3       NaN                      NaN       NaN                      NaN
# 4 -0.629194                2326400.0 -0.673092                4063330.0
#
#         X_y  Salario_ajustado_2021_x  ...  Salario_ajustado_2021_x       X_x  \
# 0 -0.547243                580224.75  ...                      NaN       NaN
# 1       NaN                      NaN  ...                      NaN       NaN
# 2       NaN                      NaN  ...                      NaN       NaN
# 3       NaN                580224.75  ...                 591442.5  0.765118
# 4 -0.684634               4859025.00  ...                      NaN       NaN
#
#    Salario_ajustado_2021_y       X_y  Salario_ajustado_2021_x  X_x  \
# 0                      NaN       NaN                      NaN  NaN
# 1                      NaN       NaN                      NaN  NaN
# 2                      NaN       NaN                      NaN  NaN
# 3                598946.58  0.774148                      NaN  NaN
# 4               1348250.00 -0.516181                      NaN  NaN
#
#    Salario_ajustado_2021_y       X_y  Salario_ajustado_2021         X
# 0                      NaN       NaN                    NaN       NaN
# 1                      NaN       NaN               576205.0 -0.482156
# 2                      NaN       NaN                    NaN       NaN
# 3                 589984.5  0.690226                    NaN       NaN
# 4                      NaN       NaN                    NaN       NaN
#
# [5 rows x 23 columns]

# %%
panel_data.tail()
# Out:
#              Jugador  Salario_ajustado_2021_x  X_x  Salario_ajustado_2021_y  \
# 2712      Zack Short                      NaN  NaN                      NaN
# 2713    Zack Wheeler                      NaN  NaN                      NaN
# 2714    Zeke Spruill                      NaN  NaN                      NaN
# 2715  Zelous Wheeler                      NaN  NaN                      NaN
# 2716   Zoilo Almonte                      NaN  NaN                      NaN
#
#       X_y  Salario_ajustado_2021_x       X_x  Salario_ajustado_2021_y  \
# 2712  NaN                      NaN       NaN                      NaN
# 2713  NaN                 569968.0 -0.614377               586464.425
# 2714  NaN                      NaN       NaN               572300.000
# 2715  NaN                      NaN       NaN               572300.000
# 2716  NaN                 569968.0 -0.658026                      NaN
#
#            X_y  Salario_ajustado_2021_x  ...  Salario_ajustado_2021_x  \
# 2712       NaN                      NaN  ...                      NaN
# 2713 -0.655888                      NaN  ...                 884400.0
# 2714 -0.524651                      NaN  ...                      NaN
# 2715 -0.650284                      NaN  ...                      NaN
# 2716       NaN                      NaN  ...                      NaN
#
#            X_x  Salario_ajustado_2021_y       X_y  Salario_ajustado_2021_x  \
# 2712       NaN                      NaN       NaN                      NaN
# 2713 -0.581167                2049340.0 -0.639284                6332902.5
# 2714       NaN                      NaN       NaN                      NaN
# 2715       NaN                      NaN       NaN                      NaN
# 2716       NaN                      NaN       NaN                      NaN
#
#            X_x  Salario_ajustado_2021_y  X_y  Salario_ajustado_2021         X
# 2712       NaN                      NaN  NaN               576205.0  0.627324
# 2713  0.710086                      NaN  NaN             22725000.0  0.711458
# 2714       NaN                      NaN  NaN                    NaN       NaN
# 2715       NaN                      NaN  NaN                    NaN       NaN
# 2716       NaN                      NaN  NaN                    NaN       NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# Por otro lado, solo resta cambiar el nombre de las columnas u ordenar las columnas de acuerdo a lo que necesitamos.

# %%
panel_data.columns = ['Jugador', 'Salario_2011', 'X_2011', 'Salario_2012', 'X_2012', 'Salario_2013', 'X_2013', 'Salario_2014', 'X_2014'
                     , 'Salario_2015', 'X_2015', 'Salario_2016', 'X_2016', 'Salario_2017', 'X_2017', 'Salario_2018', 'X_2018'
                     , 'Salario_2019', 'X_2019', 'Salario_2020', 'X_2020', 'Salario_2021', 'X_2021']

# %%
panel_data.head()
# Out:
#         Jugador  Salario_2011  X_2011  Salario_2012    X_2012  Salario_2013  \
# 0   A.J. Achter           NaN     NaN           NaN       NaN           NaN
# 1    A.J. Alexy           NaN     NaN           NaN       NaN           NaN
# 2  A.J. Burnett           NaN     NaN    19473300.0  0.628260    19192800.0
# 3     A.J. Cole           NaN     NaN           NaN       NaN           NaN
# 4    A.J. Ellis           NaN     NaN      578298.0 -0.629194     2326400.0
#
#      X_2013  Salario_2014    X_2014  Salario_2015  ...  Salario_2017  \
# 0       NaN      572300.0 -0.547243     580224.75  ...           NaN
# 1       NaN           NaN       NaN           NaN  ...           NaN
# 2  0.747549           NaN       NaN           NaN  ...           NaN
# 3       NaN           NaN       NaN     580224.75  ...      591442.5
# 4 -0.673092     4063330.0 -0.684634    4859025.00  ...           NaN
#
#      X_2017  Salario_2018    X_2018  Salario_2019  X_2019  Salario_2020  \
# 0       NaN           NaN       NaN           NaN     NaN           NaN
# 1       NaN           NaN       NaN           NaN     NaN           NaN
# 2       NaN           NaN       NaN           NaN     NaN           NaN
# 3  0.765118     598946.58  0.774148           NaN     NaN      589984.5
# 4       NaN    1348250.00 -0.516181           NaN     NaN           NaN
#
#      X_2020  Salario_2021    X_2021
# 0       NaN           NaN       NaN
# 1       NaN      576205.0 -0.482156
# 2       NaN           NaN       NaN
# 3  0.690226           NaN       NaN
# 4       NaN           NaN       NaN
#
# [5 rows x 23 columns]

# %%
panel_data = panel_data[['Jugador', 'Salario_2011', 'Salario_2012', 'Salario_2013', 'Salario_2014', 'Salario_2015', 'Salario_2016', 
                         'Salario_2017', 'Salario_2018', 'Salario_2019', 'Salario_2020', 'Salario_2021',
                         'X_2011', 'X_2012', 'X_2013', 'X_2014', 'X_2015', 'X_2016', 'X_2017', 'X_2018', 'X_2019', 'X_2020', 'X_2021', ]]

# %%
panel_data.head()
# Out:
#         Jugador  Salario_2011  Salario_2012  Salario_2013  Salario_2014  \
# 0   A.J. Achter           NaN           NaN           NaN      572300.0
# 1    A.J. Alexy           NaN           NaN           NaN           NaN
# 2  A.J. Burnett           NaN    19473300.0    19192800.0           NaN
# 3     A.J. Cole           NaN           NaN           NaN           NaN
# 4    A.J. Ellis           NaN      578298.0     2326400.0     4063330.0
#
#    Salario_2015  Salario_2016  Salario_2017  Salario_2018  Salario_2019  ...  \
# 0     580224.75      572967.5           NaN           NaN           NaN  ...
# 1           NaN           NaN           NaN           NaN           NaN  ...
# 2           NaN           NaN           NaN           NaN           NaN  ...
# 3     580224.75      572967.5      591442.5     598946.58           NaN  ...
# 4    4859025.00     5080500.0           NaN    1348250.00           NaN  ...
#
#      X_2012    X_2013    X_2014    X_2015    X_2016    X_2017    X_2018  \
# 0       NaN       NaN -0.547243  0.652904 -0.581162       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2  0.628260  0.747549       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN  0.662822  0.750665  0.765118  0.774148
# 4 -0.629194 -0.673092 -0.684634 -0.669911 -0.611115       NaN -0.516181
#
#    X_2019    X_2020    X_2021
# 0     NaN       NaN       NaN
# 1     NaN       NaN -0.482156
# 2     NaN       NaN       NaN
# 3     NaN  0.690226       NaN
# 4     NaN       NaN       NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# Para solo quedarnos con los datos que necesitamos -para el modelo del artículo- tenemos que quitar a todos los jugadores que solo han jugado una temporada en el periodo de análisis.

# %%
maximo_nan = panel_data.shape[1] - (1 + 1*2) - 1
print("Máximo número de 'nan' que pueden haber en un renglón: " + str(maximo_nan))
# Out:
# Máximo número de 'nan' que pueden haber en un renglón: 19

# %%
all_players_names = np.unique(panel_data['Jugador'])
index_drop = array.array('i',[2])

# %%
for i in range(0,len(all_players_names)):
    row = panel_data.iloc[i]
    row_length = row.size
    k = 0
    
    for j in range(row_length):
        if pd.isna(row[j]):
            k = k + 1
    
    if k > maximo_nan:
        index_drop.insert(-1, i)

index_group = np.array(index_drop)
index_drop = index_drop[:-1]

# %% [markdown]
# Los jugadores que quitaremos de la lista son los siguientes:

# %%
len(index_drop)
# Out:
# 648

# %% [markdown]
# Quitemos a dichos jugadores

# %%
panel_data.drop(index_drop, inplace = True)

# %%
panel_data.reset_index(drop = True, inplace = True)

# %%
# Para asegurar que se siga cumpliendo;
panel_data = panel_data.sort_values(by = 'Jugador', ascending = True)

# %%
print("Nos quedan " + str(panel_data.shape[0]) + " jugadores en la base de datos.")
# Out:
# Nos quedan 2069 jugadores en la base de datos.

# %%
panel_data.tail()
# Out:
#            Jugador  Salario_2011  Salario_2012  Salario_2013  Salario_2014  \
# 2064   Zack Cozart           NaN      566496.0      613588.0  6.867600e+05
# 2065   Zack Godley           NaN           NaN           NaN           NaN
# 2066  Zack Greinke    16262100.0    15932700.0           NaN  2.975960e+07
# 2067  Zack Littell           NaN           NaN           NaN           NaN
# 2068  Zack Wheeler           NaN           NaN      569968.0  5.864644e+05
#
#       Salario_2015  Salario_2016  Salario_2017  Salario_2018  Salario_2019  \
# 2064    2686755.00     3302325.0     5886787.5           NaN  1.342540e+07
# 2065     580224.75      572967.5      591442.5     624725.12           NaN
# 2066   28582500.00           NaN    37587000.0   36672400.00  3.656655e+07
# 2067           NaN           NaN           NaN     587837.00           NaN
# 2068           NaN           NaN      884400.0    2049340.00  6.332902e+06
#
#       ...    X_2012    X_2013    X_2014    X_2015    X_2016    X_2017  \
# 2064  ...  0.773799  0.717958 -0.606276 -0.513719 -0.545827 -0.542457
# 2065  ...       NaN       NaN       NaN  0.639418 -0.557441  0.757677
# 2066  ...  0.665557       NaN -0.684634 -0.669911       NaN  0.757677
# 2067  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 2068  ...       NaN -0.614377 -0.655888       NaN       NaN -0.581167
#
#         X_2018    X_2019    X_2020    X_2021
# 2064       NaN -0.573200       NaN       NaN
# 2065  0.668059       NaN -0.489898       NaN
# 2066  0.668059  0.811409 -0.595671  0.722718
# 2067 -0.609785       NaN       NaN  0.813988
# 2068 -0.639284  0.710086       NaN  0.711458
#
# [5 rows x 23 columns]

# %% [markdown]
# Puesto que tendremos el mismo orden para los sueldo en valor presente 2021 y para las variables X, trabajemos por separado con los salarios.

# %%
adjusted_salary = panel_data.iloc[:,0:12]
year_x = panel_data.iloc[:,12:24]
year_x['Jugador'] = panel_data['Jugador']

# %%
adjusted_salary.head()
# Out:
#         Jugador  Salario_2011  Salario_2012  Salario_2013  Salario_2014  \
# 0   A.J. Achter           NaN           NaN           NaN      572300.0
# 1  A.J. Burnett           NaN    19473300.0    19192800.0           NaN
# 2     A.J. Cole           NaN           NaN           NaN           NaN
# 3    A.J. Ellis           NaN      578298.0     2326400.0     4063330.0
# 4  A.J. Griffin           NaN      566496.0      572876.0           NaN
#
#    Salario_2015  Salario_2016  Salario_2017  Salario_2018  Salario_2019  \
# 0     580224.75      572967.5           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2     580224.75      572967.5      591442.5     598946.58           NaN
# 3    4859025.00     5080500.0           NaN    1348250.00           NaN
# 4           NaN           NaN     2211000.0           NaN           NaN
#
#    Salario_2020  Salario_2021
# 0           NaN           NaN
# 1           NaN           NaN
# 2      589984.5           NaN
# 3           NaN           NaN
# 4           NaN           NaN

# %%
adjusted_salary.shape
# Out:
# (2069, 12)

# %% [markdown]
# Se observa que tenemos una gran cantidad de datos para la construcción del modelo.

# %%
year_x.head()
# Out:
#    X_2011    X_2012    X_2013    X_2014    X_2015    X_2016    X_2017  \
# 0     NaN       NaN       NaN -0.547243  0.652904 -0.581162       NaN
# 1     NaN  0.628260  0.747549       NaN       NaN       NaN       NaN
# 2     NaN       NaN       NaN       NaN  0.662822  0.750665  0.765118
# 3     NaN -0.629194 -0.673092 -0.684634 -0.669911 -0.611115       NaN
# 4     NaN  0.749096  0.765034       NaN       NaN       NaN  0.626803
#
#      X_2018  X_2019    X_2020  X_2021       Jugador
# 0       NaN     NaN       NaN     NaN   A.J. Achter
# 1       NaN     NaN       NaN     NaN  A.J. Burnett
# 2  0.774148     NaN  0.690226     NaN     A.J. Cole
# 3 -0.516181     NaN       NaN     NaN    A.J. Ellis
# 4       NaN     NaN       NaN     NaN  A.J. Griffin

# %% [markdown]
# Recorramos todos los valores del salario a la izquierda para calcular $Y$ más adelante.
#
# $$
# Y = \sqrt{\omega_{t+1}} - \sqrt{\omega_{t}}
# $$salario

# %%
for i in range(0,len(adjusted_salary['Jugador'])):
    row = adjusted_salary.iloc[i]
    row_length = row.size
    sustitute = []
    
    for j in range(row_length):
        if pd.isna(row[j]) != True:
            sustitute.append(row[j])
            
    sustitute_length = len(sustitute)
    
    for k in range(row_length-sustitute_length):
        sustitute.append(np.nan)
        
    for j in range(row_length):
        adjusted_salary.iloc[i,j] = sustitute[j]

adjusted_salary.columns = ['Jugador', 'w_1', 'w_2', 'w_3', 'w_4', 'w_5', 'w_6', 
                           'w_7', 'w_8', 'w_9', 'w_10', 'w_11']

# %%
adjusted_salary.head()
# Out:
#         Jugador          w_1          w_2        w_3         w_4        w_5  \
# 0   A.J. Achter    572300.00    580224.75   572967.5         NaN        NaN
# 1  A.J. Burnett  19473300.00  19192800.00        NaN         NaN        NaN
# 2     A.J. Cole    580224.75    572967.50   591442.5   598946.58   589984.5
# 3    A.J. Ellis    578298.00   2326400.00  4063330.0  4859025.00  5080500.0
# 4  A.J. Griffin    566496.00    572876.00  2211000.0         NaN        NaN
#
#          w_6  w_7  w_8  w_9  w_10  w_11
# 0        NaN  NaN  NaN  NaN   NaN   NaN
# 1        NaN  NaN  NaN  NaN   NaN   NaN
# 2        NaN  NaN  NaN  NaN   NaN   NaN
# 3  1348250.0  NaN  NaN  NaN   NaN   NaN
# 4        NaN  NaN  NaN  NaN   NaN   NaN

# %%
adjusted_salary.tail()
# Out:
#            Jugador          w_1           w_2         w_3          w_4  \
# 2064   Zack Cozart    566496.00  6.135880e+05    686760.0   2686755.00
# 2065   Zack Godley    580224.75  5.729675e+05    591442.5    624725.12
# 2066  Zack Greinke  16262100.00  1.593270e+07  29759600.0  28582500.00
# 2067  Zack Littell    587837.00  5.762050e+05         NaN          NaN
# 2068  Zack Wheeler    569968.00  5.864644e+05    884400.0   2049340.00
#
#              w_5         w_6           w_7         w_8         w_9  w_10  w_11
# 2064   3302325.0   5886787.5  1.342540e+07         NaN         NaN   NaN   NaN
# 2065   1570500.0         NaN           NaN         NaN         NaN   NaN   NaN
# 2066  37587000.0  36672400.0  3.656655e+07  36645000.0  35350000.0   NaN   NaN
# 2067         NaN         NaN           NaN         NaN         NaN   NaN   NaN
# 2068   6332902.5  22725000.0           NaN         NaN         NaN   NaN   NaN

# %%
# Creemos una copia
df_y = adjusted_salary.copy()
y_names = df_y['Jugador']

# %%
for i in range(0,len(y_names)):
    row = df_y.iloc[i]
    row_length = row.size
    k = 0

    sustitute = []

    for j in range(0,row_length):
        if pd.isna(row[j]) != True:
            k = k + 1

    sustitute.append(y_names[i])
    for j in range(1,k - 1):
        sustitute.append(row[j + 1]**0.5 - row[j]**0.5)

    sustitute_length = len(sustitute)

    for k in range(row_length - sustitute_length):
        sustitute.append(np.nan)

    for j in range(row_length):
        df_y.iloc[i,j] = sustitute[j]

df_y.columns = ['Jugador', 'Y_1', 'Y_2', 'Y_3', 'Y_4', 'Y_5', 'Y_6', 
                           'Y_7', 'Y_8', 'Y_9', 'Y_10', 'Y_11']

# %%
df_y.head()
# Out:
#         Jugador         Y_1         Y_2         Y_3        Y_4          Y_5  \
# 0   A.J. Achter    5.219730   -4.778685         NaN        NaN          NaN
# 1  A.J. Burnett  -31.897419         NaN         NaN        NaN          NaN
# 2     A.J. Cole   -4.778685   12.106822    4.863402  -5.811906          NaN
# 3    A.J. Ellis  764.795005  490.516247  188.549299  49.676828 -1092.854771
# 4  A.J. Griffin    4.226439  730.057449         NaN        NaN          NaN
#
#    Y_6  Y_7  Y_8  Y_9  Y_10  Y_11
# 0  NaN  NaN  NaN  NaN   NaN   NaN
# 1  NaN  NaN  NaN  NaN   NaN   NaN
# 2  NaN  NaN  NaN  NaN   NaN   NaN
# 3  NaN  NaN  NaN  NaN   NaN   NaN
# 4  NaN  NaN  NaN  NaN   NaN   NaN

# %% [markdown]
# Repitamos parcialmente el proceso para la varibale $X$. Sin embargo, quitaremos el último valor de $X$ puesto que no lo necesitamos debido a cómo se calcula $Y$.

# %%
year_x = year_x[['Jugador', 'X_2011', 'X_2012', 'X_2013', 'X_2014', 'X_2015', 
                 'X_2016', 'X_2017', 'X_2018', 'X_2019', 'X_2020', 'X_2021']]
year_x.head()
# Out:
#         Jugador  X_2011    X_2012    X_2013    X_2014    X_2015    X_2016  \
# 0   A.J. Achter     NaN       NaN       NaN -0.547243  0.652904 -0.581162
# 1  A.J. Burnett     NaN  0.628260  0.747549       NaN       NaN       NaN
# 2     A.J. Cole     NaN       NaN       NaN       NaN  0.662822  0.750665
# 3    A.J. Ellis     NaN -0.629194 -0.673092 -0.684634 -0.669911 -0.611115
# 4  A.J. Griffin     NaN  0.749096  0.765034       NaN       NaN       NaN
#
#      X_2017    X_2018  X_2019    X_2020  X_2021
# 0       NaN       NaN     NaN       NaN     NaN
# 1       NaN       NaN     NaN       NaN     NaN
# 2  0.765118  0.774148     NaN  0.690226     NaN
# 3       NaN -0.516181     NaN       NaN     NaN
# 4  0.626803       NaN     NaN       NaN     NaN

# %%
df_x = year_x.copy()
x_names = year_x['Jugador']

# %%
for i in range(0,len(x_names)):
    row = df_x.iloc[i]
    row_length = row.size
    sustitute = []
    
    for j in range(row_length):
        if pd.isna(row[j]) != True:
            sustitute.append(row[j])
            
    sustitute_length = len(sustitute)
    
    for k in range(row_length-sustitute_length):
        sustitute.append(np.nan)
        
    sustitute[sustitute_length - 1] = np.nan
    
    for j in range(row_length):
        df_x.iloc[i,j] = sustitute[j]

df_x.columns = ['Jugador', 'X_1', 'X_2', 'X_3', 'X_4', 'X_5', 'X_6', 
                           'X_7', 'X_8', 'X_9', 'X_10', 'X_11']

# %%
df_x.head()
# Out:
#         Jugador       X_1       X_2       X_3       X_4       X_5  X_6  X_7  \
# 0   A.J. Achter -0.547243  0.652904       NaN       NaN       NaN  NaN  NaN
# 1  A.J. Burnett  0.628260       NaN       NaN       NaN       NaN  NaN  NaN
# 2     A.J. Cole  0.662822  0.750665  0.765118  0.774148       NaN  NaN  NaN
# 3    A.J. Ellis -0.629194 -0.673092 -0.684634 -0.669911 -0.611115  NaN  NaN
# 4  A.J. Griffin  0.749096  0.765034       NaN       NaN       NaN  NaN  NaN
#
#    X_8  X_9  X_10  X_11
# 0  NaN  NaN   NaN   NaN
# 1  NaN  NaN   NaN   NaN
# 2  NaN  NaN   NaN   NaN
# 3  NaN  NaN   NaN   NaN
# 4  NaN  NaN   NaN   NaN

# %% [markdown]
# La estrategia para construir la base de datos para la regresión consiste en el siguiente proceso:
# - Crear dataframes que contengan la columna del nombre del jugador y la variable de $X$ y $Y$ del mismo subíndice.
# - Hacer merge de las bases de datos que contengan el mismo subíndice.
# - Concatenar todas las bases de datos.
# - Eliminar las filas que contengan datos faltantes.

# %%
regression_list = [None]*(period-1)

# %%
for i in range(0,len(regression_list)):
    merge = pd.merge(df_y.iloc[:,[0,i+1]], df_x.iloc[:,[0,i+1]])
    regression_list[i] = merge
    regression_list[i].columns = ['Jugador', 'Y', 'X']

# %%
df_article_regression = regression_list[0]

for i in range(1,len(regression_list)):
    df_article_regression = pd.concat([df_article_regression, regression_list[i]])

# %%
df_article_regression = df_article_regression.sort_values(by = 'Jugador', ascending = True)
df_article_regression.reset_index(drop = True, inplace = True)
df_article_regression
# Out:
#             Jugador           Y         X
# 0       A.J. Achter    5.219730 -0.547243
# 1       A.J. Achter         NaN       NaN
# 2       A.J. Achter         NaN       NaN
# 3       A.J. Achter         NaN       NaN
# 4       A.J. Achter   -4.778685  0.652904
# ...             ...         ...       ...
# 20685  Zack Wheeler  491.126170 -0.581167
# 20686  Zack Wheeler  174.615782 -0.655888
# 20687  Zack Wheeler   10.847403 -0.614377
# 20688  Zack Wheeler         NaN       NaN
# 20689  Zack Wheeler         NaN       NaN
#
# [20690 rows x 3 columns]

# %% [markdown]
# Por último, eliminemos las filas que contengan filas con datos *NaN*.

# %%
df_article_regression.dropna(inplace = True)
df_article_regression.reset_index(drop = True, inplace = True)
df_article_regression
# Out:
#            Jugador            Y         X
# 0      A.J. Achter     5.219730 -0.547243
# 1      A.J. Achter    -4.778685  0.652904
# 2     A.J. Burnett   -31.897419  0.628260
# 3        A.J. Cole    12.106822  0.750665
# 4        A.J. Cole     4.863402  0.765118
# ...            ...          ...       ...
# 6579  Zack Wheeler  2250.548696  0.710086
# 6580  Zack Wheeler  1084.974273 -0.639284
# 6581  Zack Wheeler   491.126170 -0.581167
# 6582  Zack Wheeler   174.615782 -0.655888
# 6583  Zack Wheeler    10.847403 -0.614377
#
# [6584 rows x 3 columns]

# %% [markdown]
# Observemos que ya no hay valores *NaN*.

# %%
pd.isnull(df_article_regression).sum(axis=0)
# Out:
# Jugador    0
# Y          0
# X          0
# dtype: int64

# %% [markdown]
# Finalmente, exportemos la nueva base de datos para que se pueda hacer el análisis en cualquier lenguaje

# %%
df_article_regression.to_csv('Data/New_Data/Models/Article/article_linear_regression_nfa.csv', index = False)

# %% [markdown]
# A continuación se aprecia el comportamiento gráfico de los datos

# %%
sns.regplot(x = 'X', y = df_article_regression['Y']/4000, data = df_article_regression,
            scatter_kws={"color": '#DC143C', 'edgecolor':'#CCCC00', "s":75, "alpha":0.4},
            line_kws={"color": "#8e00ce"})
plt.title("No agentes libres", fontsize = 20, fontweight = 'bold')
plt.xlabel("X", fontsize = 16, fontweight = 'bold')
plt.ylabel("Y", fontsize = 16, fontweight = 'bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim(-1,1)
plt.grid(color='purple', linestyle='-')
plt.show()

# %% [markdown]
# Se sospecha que un modelo adecuado sea de clasificación, pero falta ver la significancia estadística.

# %% [markdown]
# ### Modelo
#
# Regresemos $Y$ sobre $X$.

# %%
Y = df_article_regression['Y'].tolist()
X = df_article_regression['X'].tolist()

X = sm.add_constant(X)

no_free_agent_model = sm.OLS(Y, X).fit()

# %%
no_free_agent_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     22.51
# Date:                Sat, 16 Jul 2022   Prob (F-statistic):           2.14e-06
# Time:                        08:45:33   Log-Likelihood:                -50374.
# No. Observations:                6584   AIC:                         1.008e+05
# Df Residuals:                    6582   BIC:                         1.008e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        146.1356      6.303     23.186      0.000     133.780     158.491
# x1            45.8711      9.668      4.744      0.000      26.918      64.824
# ==============================================================================
# Omnibus:                     1615.527   Durbin-Watson:                   2.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            35978.614
# Skew:                          -0.636   Prob(JB):                         0.00
# Kurtosis:                      14.381   Cond. No.                         1.55
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# A pesar de estar dividido por clusters, se aprecia que la significancia estadística es bastante alta -para un nivel de 0.01- por lo que los resultados son prometedores.
