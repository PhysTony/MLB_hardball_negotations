# %% [markdown]
# # Best X finder - Test for one period
#
# Veremos cómo funciona el algoritmo en un script distinto puesto que podría haber variables inicializadas en los test del script *two_best_X_finder.ipynb*

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from matplotlib.colors import ListedColormap
from termcolor import colored
from sklearn.naive_bayes import GaussianNB
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
import pandas as pd
import numpy as np
import array
import math
import os
import warnings
print('Modulos importados')
# Out:
# Modulos importados

# %%
# Configuraciones
warnings.filterwarnings('ignore')
# Reduzcamos el número de línea a leer
pd.options.display.max_rows = 15

# %%
# Veamos el directorio actual de trabajo
print(os.getcwd())
# El directorio anterior es el correcto, pero si no lo fuese, hacemos lo sigueinte:
path = '/home/usuario/Documentos/Github/Proyectos/MLB_HN'
os.chdir(path)
# Out:
# /home/usuario/Documentos/Github/Proyectos/MLB_HN/Models/Linear_models/Free_agent/Best_X_finder

# %%
print("Para modificar el tamaño de todos los gráficos")
from matplotlib import rcParams
rcParams['figure.figsize'] = 15,9
# Out:
# Para modificar el tamaño de todos los gráficos

# %%
# Veamos el directorio actual de trabajo
print(os.getcwd())
# El directorio anterior es el correcto, pero si no lo fuese, hacemos lo sigueinte:
path = '/home/usuario/Documentos/Github/Proyectos/MLB_HN'
print("Nuevo directorio de trabajo: " + str(os.chdir(path)))
# Out:
# /home/usuario/Documentos/Github/Proyectos/MLB_HN
# Nuevo directorio de trabajo: None

# %% [markdown]
# ## Exploración de datos
#
# Estudiaremos de manera general si hay datos faltantes, así como el tipo de datos que contiene

# %%
# Años de análisis
starting_year = 2012
period = 11
csv = '.csv'
# Directorios
hitters_path = 'ETL_Data/Agent/First_Two_Years_Contract/Period_t_1/Free_Agent/Hitters/free_agents_batters_'
pitchers_path = 'ETL_Data/Agent/First_Two_Years_Contract/Period_t_1/Free_Agent/Pitchers/free_agents_pitchers_'
# Originales:
df_pitchers = [None]*period
df_pitchers_copy = [None]*period
df_hitters = [None]*period
df_hitters_copy = [None]*period

# %% [markdown]
# Leamos todos las bases de datos correspondientes

# %%
for year in range(0,period):
    df_pitchers[year] = pd.read_csv(pitchers_path + str(starting_year + year) + csv)
    df_pitchers_copy[year] = df_pitchers[year].copy()
    
    df_hitters[year] = pd.read_csv(hitters_path + str(starting_year + year) + csv)
    df_hitters_copy[year] = df_hitters[year].copy()

# %% [markdown]
# Observemos el contenido de las bases de datos

# %%
# Pitchers
df_pitchers_copy[5].head()
# Out:
#   Acronimo_t Acronimo_t_1  Altura_t  Altura_t_1  Anio_de_agente_libre_t  \
# 0        NYY          CHC  6.400000     6.40000                    2022
# 1        LAD          LAD  6.500000     6.50000                    2022
# 2         SF          WSH  6.100000     6.10000                    2021
# 3        LAD          LAD  6.500000     6.50000                    2020
# 4        STL          TOR  5.718369     5.72134                    2021
#
#    Anio_de_agente_libre_t_1  Anio_t  Anios_de_contrato  Anios_de_contrato_t  \
# 0                      2017    2017                  5                    5
# 1                      2017    2017                  5                    5
# 2                      2017    2017                  4                    4
# 3                      2017    2017                  3                    3
# 4                      2017    2017                  4                    4
#
#    Anios_de_contrato_t_1  ...  Walks_2_t_1  Walks_t  Walks_t_1  Wins_2_t  \
# 0                      1  ...          324       20         18        16
# 1                      1  ...          121        7         11        25
# 2                      1  ...          144        6         12         1
# 3                      1  ...         1089       49         33       144
# 4                      1  ...           64       16          8         4
#
#    Wins_2_t_1  Wins_t  Wins_t_1  ln_Sueldo_ajustado_t  ln_Sueldo_base_t  \
# 0          16       4         4             16.660420         16.523561
# 1           9       5         3             16.243259         16.118096
# 2           4       1         2             16.454568         15.201805
# 3         144      12        12             16.354484         16.300417
# 4           1       2         1             15.863203         15.830414
#
#    ln_Sueldo_regular_t
# 0            16.660420
# 1            16.243259
# 2            16.454568
# 3            16.354484
# 4            15.863203
#
# [5 rows x 136 columns]

# %%
list(enumerate(df_pitchers_copy[5].columns))
# Out:
# [(0, 'Acronimo_t'),
#  (1, 'Acronimo_t_1'),
#  (2, 'Altura_t'),
#  (3, 'Altura_t_1'),
#  (4, 'Anio_de_agente_libre_t'),
#  (5, 'Anio_de_agente_libre_t_1'),
#  (6, 'Anio_t'),
#  (7, 'Anios_de_contrato'),
#  (8, 'Anios_de_contrato_t'),
#  (9, 'Anios_de_contrato_t_1'),
#  (10, 'Antiguedad_t'),
#  (11, 'Antiguedad_t_1'),
#  (12, 'Bateos_en_contra_2_t'),
#  (13, 'Bateos_en_contra_2_t_1'),
#  (14, 'Bateos_en_contra_t'),
#  (15, 'Bateos_en_contra_t_1'),
#  (16, 'Bono_por_firma_t'),
#  (17, 'Bono_por_firma_t_1'),
#  (18, 'Cantidad_agentes_libres_t'),
#  (19, 'Cantidad_agentes_libres_t_1'),
#  (20, 'Cantidad_de_equipos_t'),
#  (21, 'Cantidad_de_equipos_t_1'),
#  (22, 'Carreras_en_contra_2_t'),
#  (23, 'Carreras_en_contra_2_t_1'),
#  (24, 'Carreras_en_contra_t'),
#  (25, 'Carreras_en_contra_t_1'),
#  (26, 'Carreras_ganadas_2_t'),
#  (27, 'Carreras_ganadas_2_t_1'),
#  (28, 'Carreras_ganadas_t'),
#  (29, 'Carreras_ganadas_t_1'),
#  (30, 'Comando_2_t'),
#  (31, 'Comando_2_t_1'),
#  (32, 'Comando_t'),
#  (33, 'Comando_t_1'),
#  (34, 'Control_2_t'),
#  (35, 'Control_2_t_1'),
#  (36, 'Control_t'),
#  (37, 'Control_t_1'),
#  (38, 'Dominio_2_t'),
#  (39, 'Dominio_2_t_1'),
#  (40, 'Dominio_t'),
#  (41, 'Dominio_t_1'),
#  (42, 'ERA_2_t'),
#  (43, 'ERA_2_t_1'),
#  (44, 'ERA_t'),
#  (45, 'ERA_t_1'),
#  (46, 'Edad_al_firmar_t'),
#  (47, 'Edad_al_firmar_t_1'),
#  (48, 'Edad_t'),
#  (49, 'Equipo_anterior'),
#  (50, 'Equipo_t'),
#  (51, 'Equipo_t_1'),
#  (52, 'Estado_t'),
#  (53, 'Ganancias_t'),
#  (54, 'Ganancias_t_1'),
#  (55, 'Inning_pitched_2_t'),
#  (56, 'Inning_pitched_2_t_1'),
#  (57, 'Inning_pitched_t'),
#  (58, 'Inning_pitched_t_1'),
#  (59, 'Juegos_iniciados_t'),
#  (60, 'Juegos_iniciados_t_1'),
#  (61, 'Juegos_t'),
#  (62, 'Juegos_t_1'),
#  (63, 'Juegos_totales_t'),
#  (64, 'Juegos_totales_t_1'),
#  (65, 'Jugador'),
#  (66, 'Losses_2_t'),
#  (67, 'Losses_2_t_1'),
#  (68, 'Losses_t'),
#  (69, 'Losses_t_1'),
#  (70, 'Pago_efectivo_t'),
#  (71, 'Pago_efectivo_t_1'),
#  (72, 'Pennants_won_t'),
#  (73, 'Pennants_won_t_1'),
#  (74, 'Peso_t'),
#  (75, 'Peso_t_1'),
#  (76, 'Playoffs_t'),
#  (77, 'Playoffs_t_1'),
#  (78, 'Porcentaje_juegos_t'),
#  (79, 'Porcentaje_juegos_t_1'),
#  (80, 'Posicion_t'),
#  (81, 'Posicion_t_1'),
#  (82, 'Promedio_victorias_t'),
#  (83, 'Promedio_victorias_t_1'),
#  (84, 'Saves_2_t'),
#  (85, 'Saves_2_t_1'),
#  (86, 'Saves_t'),
#  (87, 'Saves_t_1'),
#  (88, 'Status_agente_libre'),
#  (89, 'Strike_outs_2_t'),
#  (90, 'Strike_outs_2_t_1'),
#  (91, 'Strike_outs_t'),
#  (92, 'Strike_outs_t_1'),
#  (93, 'Sueldo_ajustado_t'),
#  (94, 'Sueldo_ajustado_t_1'),
#  (95, 'Sueldo_base_t'),
#  (96, 'Sueldo_base_t_1'),
#  (97, 'Sueldo_porcentual_t'),
#  (98, 'Sueldo_porcentual_t_1'),
#  (99, 'Sueldo_regular_t'),
#  (100, 'Sueldo_regular_t_1'),
#  (101, 'TVS_2_t'),
#  (102, 'TVS_2_t_1'),
#  (103, 'TVS_t'),
#  (104, 'TVS_t_1'),
#  (105, 'Valor_contrato'),
#  (106, 'Valor_contrato_promedio_t'),
#  (107, 'Valor_contrato_promedio_t_1'),
#  (108, 'Valor_contrato_total_t'),
#  (109, 'Valor_contrato_total_t_1'),
#  (110, 'Valor_del_contrato_t'),
#  (111, 'Valor_del_contrato_t_1'),
#  (112, 'Valor_promedio_contrato'),
#  (113, 'Victorias_t'),
#  (114, 'Victorias_t_1'),
#  (115, 'WAR_2_t'),
#  (116, 'WAR_2_t_1'),
#  (117, 'WAR_t'),
#  (118, 'WAR_t_1'),
#  (119, 'WHIP_2_t'),
#  (120, 'WHIP_2_t_1'),
#  (121, 'WHIP_t'),
#  (122, 'WHIP_t_1'),
#  (123, 'WS_ganadas_t'),
#  (124, 'WS_ganadas_t_1'),
#  (125, 'Walks_2_t'),
#  (126, 'Walks_2_t_1'),
#  (127, 'Walks_t'),
#  (128, 'Walks_t_1'),
#  (129, 'Wins_2_t'),
#  (130, 'Wins_2_t_1'),
#  (131, 'Wins_t'),
#  (132, 'Wins_t_1'),
#  (133, 'ln_Sueldo_ajustado_t'),
#  (134, 'ln_Sueldo_base_t'),
#  (135, 'ln_Sueldo_regular_t')]

# %%
# Hitters
df_hitters_copy[5].head()
# Out:
#   Acronimo_t Acronimo_t_1  Altura_t  Altura_t_1  Anio_de_agente_libre_t  \
# 0        NYM          NYM  5.718369     5.72134                    2021
# 1        STL          CHC  6.500000     6.50000                    2022
# 2        COL          TEX  6.300000     6.30000                    2023
# 3        HOU          LAD  6.200000     6.20000                    2021
# 4        LAD          LAD  6.500000     6.50000                    2020
#
#    Anio_de_agente_libre_t_1  Anio_t  Anios_de_contrato  Anios_de_contrato_t  \
# 0                      2017    2017                  4                    4
# 1                      2017    2017                  5                    5
# 2                      2017    2017                  5                    5
# 3                      2017    2017                  4                    4
# 4                      2017    2017                  3                    3
#
#    Anios_de_contrato_t_1  ...  Victorias_t_1    WAR_2_t  WAR_2_t_1     WAR_t  \
# 0                      3  ...             87   3.841600     8.7025  1.960000
# 1                      1  ...            102   3.097600    15.9201  1.760000
# 2                      1  ...             95   3.009561     4.8841  1.734809
# 3                      1  ...             91  20.250000     0.0016  4.500000
# 4                      1  ...             91   4.884100     1.9321  2.210000
#
#    WAR_t_1  WS_ganadas_t  WS_ganadas_t_1  ln_Sueldo_ajustado_t  \
# 0     2.95             2               2             16.929026
# 1     3.99            11               3             16.618871
# 2     2.21             0               0             15.894952
# 3     0.04             1               6             16.380460
# 4     1.39             6               6             16.354484
#
#    ln_Sueldo_base_t  ln_Sueldo_regular_t
# 0         16.929026            16.929026
# 1         16.489659            16.618871
# 2         15.894952            15.894952
# 3         16.380460            16.380460
# 4         16.300417            16.354484
#
# [5 rows x 126 columns]

# %% [markdown]
# Veamos las columnas con sus índices

# %%
list(enumerate(df_hitters_copy[5].columns))
# Out:
# [(0, 'Acronimo_t'),
#  (1, 'Acronimo_t_1'),
#  (2, 'Altura_t'),
#  (3, 'Altura_t_1'),
#  (4, 'Anio_de_agente_libre_t'),
#  (5, 'Anio_de_agente_libre_t_1'),
#  (6, 'Anio_t'),
#  (7, 'Anios_de_contrato'),
#  (8, 'Anios_de_contrato_t'),
#  (9, 'Anios_de_contrato_t_1'),
#  (10, 'Antiguedad_t'),
#  (11, 'Antiguedad_t_1'),
#  (12, 'At_bats_2_t'),
#  (13, 'At_bats_2_t_1'),
#  (14, 'At_bats_t'),
#  (15, 'At_bats_t_1'),
#  (16, 'Bateos_2_t'),
#  (17, 'Bateos_2_t_1'),
#  (18, 'Bateos_promedio_2_t'),
#  (19, 'Bateos_promedio_2_t_1'),
#  (20, 'Bateos_promedio_t'),
#  (21, 'Bateos_promedio_t_1'),
#  (22, 'Bateos_t'),
#  (23, 'Bateos_t_1'),
#  (24, 'Bono_por_firma_t'),
#  (25, 'Bono_por_firma_t_1'),
#  (26, 'Cantidad_agentes_libres_t'),
#  (27, 'Cantidad_agentes_libres_t_1'),
#  (28, 'Cantidad_de_equipos_t'),
#  (29, 'Cantidad_de_equipos_t_1'),
#  (30, 'Dobles_2_t'),
#  (31, 'Dobles_2_t_1'),
#  (32, 'Dobles_t'),
#  (33, 'Dobles_t_1'),
#  (34, 'Edad_al_firmar_t'),
#  (35, 'Edad_al_firmar_t_1'),
#  (36, 'Edad_t'),
#  (37, 'Equipo_anterior'),
#  (38, 'Equipo_t'),
#  (39, 'Equipo_t_1'),
#  (40, 'Estado_t'),
#  (41, 'Ganancias_t'),
#  (42, 'Ganancias_t_1'),
#  (43, 'Home_runs_2_t'),
#  (44, 'Home_runs_2_t_1'),
#  (45, 'Home_runs_t'),
#  (46, 'Home_runs_t_1'),
#  (47, 'Juegos_iniciados_2_t'),
#  (48, 'Juegos_iniciados_2_t_1'),
#  (49, 'Juegos_iniciados_t'),
#  (50, 'Juegos_iniciados_t_1'),
#  (51, 'Juegos_t'),
#  (52, 'Juegos_t_1'),
#  (53, 'Juegos_totales_t'),
#  (54, 'Juegos_totales_t_1'),
#  (55, 'Jugador'),
#  (56, 'Pago_efectivo_t'),
#  (57, 'Pago_efectivo_t_1'),
#  (58, 'Pennants_won_t'),
#  (59, 'Pennants_won_t_1'),
#  (60, 'Peso_t'),
#  (61, 'Peso_t_1'),
#  (62, 'Playoffs_t'),
#  (63, 'Playoffs_t_1'),
#  (64, 'Porcentaje_On_base_plus_slugging_2_t'),
#  (65, 'Porcentaje_On_base_plus_slugging_2_t_1'),
#  (66, 'Porcentaje_On_base_plus_slugging_t'),
#  (67, 'Porcentaje_On_base_plus_slugging_t_1'),
#  (68, 'Porcentaje_juegos_iniciados_2_t'),
#  (69, 'Porcentaje_juegos_iniciados_2_t_1'),
#  (70, 'Porcentaje_juegos_iniciados_t'),
#  (71, 'Porcentaje_juegos_iniciados_t_1'),
#  (72, 'Porcentaje_juegos_t'),
#  (73, 'Porcentaje_juegos_t_1'),
#  (74, 'Porcentaje_on_base_2_t'),
#  (75, 'Porcentaje_on_base_2_t_1'),
#  (76, 'Porcentaje_on_base_t'),
#  (77, 'Porcentaje_on_base_t_1'),
#  (78, 'Porcentaje_slugging_2_t'),
#  (79, 'Porcentaje_slugging_2_t_1'),
#  (80, 'Porcentaje_slugging_t'),
#  (81, 'Porcentaje_slugging_t_1'),
#  (82, 'Posicion_t'),
#  (83, 'Posicion_t_1'),
#  (84, 'Promedio_victorias_t'),
#  (85, 'Promedio_victorias_t_1'),
#  (86, 'Runs_batted_in_2_t'),
#  (87, 'Runs_batted_in_2_t_1'),
#  (88, 'Runs_batted_in_t'),
#  (89, 'Runs_batted_in_t_1'),
#  (90, 'Status_agente_libre'),
#  (91, 'Sueldo_ajustado_t'),
#  (92, 'Sueldo_ajustado_t_1'),
#  (93, 'Sueldo_base_t'),
#  (94, 'Sueldo_base_t_1'),
#  (95, 'Sueldo_porcentual_t'),
#  (96, 'Sueldo_porcentual_t_1'),
#  (97, 'Sueldo_regular_t'),
#  (98, 'Sueldo_regular_t_1'),
#  (99, 'TVS_2_t'),
#  (100, 'TVS_2_t_1'),
#  (101, 'TVS_t'),
#  (102, 'TVS_t_1'),
#  (103, 'Triples_2_t'),
#  (104, 'Triples_2_t_1'),
#  (105, 'Triples_t'),
#  (106, 'Triples_t_1'),
#  (107, 'Valor_contrato'),
#  (108, 'Valor_contrato_promedio_t'),
#  (109, 'Valor_contrato_promedio_t_1'),
#  (110, 'Valor_contrato_total_t'),
#  (111, 'Valor_contrato_total_t_1'),
#  (112, 'Valor_del_contrato_t'),
#  (113, 'Valor_del_contrato_t_1'),
#  (114, 'Valor_promedio_contrato'),
#  (115, 'Victorias_t'),
#  (116, 'Victorias_t_1'),
#  (117, 'WAR_2_t'),
#  (118, 'WAR_2_t_1'),
#  (119, 'WAR_t'),
#  (120, 'WAR_t_1'),
#  (121, 'WS_ganadas_t'),
#  (122, 'WS_ganadas_t_1'),
#  (123, 'ln_Sueldo_ajustado_t'),
#  (124, 'ln_Sueldo_base_t'),
#  (125, 'ln_Sueldo_regular_t')]

# %% [markdown]
# Veamos si hay bases de datos con variables que distintas entre sí

# %% [markdown]
# ## Test

# %%
def etl_regression(X_raw, Y_raw, df_copy):
    # Creación de la base de datos a transformar las variables de la regresión
    jugador = 'Jugador'
    YX_raw = [None]*period
    
    for year in range(0, period):
        YX_raw[year] = df_copy[year][[jugador, Y_raw, X_raw]]

    # Ajuste de inflación en los salarios    
    # Ajuste de inflación en los salarios    
    cpi = {2012:1.31, 2013:1.29,
           2014:1.27, 2015:1.27,
           2016:1.26, 2017:1.23,
           2018:1.20, 2019:1.18,
           2020:1.15, 2021:1.14,
           2022:1}
    
    for year in range(0, period):
        YX_raw[year][[Y_raw]] = YX_raw[year][[Y_raw]]*cpi[starting_year + year]
        YX_raw[year].rename(columns = {Y_raw: Y_raw + '_' + str(2012 + year)}, inplace = True)
        YX_raw[year].rename(columns = {X_raw: X_raw + '_' + str(2012 + year)}, inplace = True)

    # Filtrado de base de datos
    YX_panel_raw = pd.merge(YX_raw[0], YX_raw[1], how = 'outer', on = 'Jugador')

    for year in range(2,period):
        YX_panel_raw = pd.merge(YX_panel_raw, YX_raw[year], how = 'outer', on = 'Jugador')

    YX_panel_raw.drop_duplicates(subset = 'Jugador', inplace = True)
    YX_panel_raw = YX_panel_raw.sort_values(by = 'Jugador', ascending = True)
    YX_panel_raw.reset_index(drop = True, inplace = True)
    YX_panel_raw.sort_index(axis = 1, inplace = True)

    # Recolocación al principio de Jugador
    player_column = YX_panel_raw.pop('Jugador')
    YX_panel_raw.insert(0, 'Jugador', player_column)

    # Creación de base de datos auxiliares  para remover los NaN
    split_column = 1 + period
    max_nan = 2

    if Y_raw > X_raw:
        X_drop_etl = YX_panel_raw.iloc[:, 1:split_column]
    else:
        X_drop_etl = YX_panel_raw.iloc[:, split_column:YX_panel_raw.shape[1]]

    nulls_quantity = period - max_nan
    X_drop_etl = X_drop_etl.iloc[X_drop_etl[(X_drop_etl.isnull().sum(axis = 1) > nulls_quantity)].index]
    X_index_drop = X_drop_etl.index

    if Y_raw > X_raw:
        Y_drop_etl = YX_panel_raw.iloc[:, split_column:YX_panel_raw.shape[1]]
    else:
        Y_drop_etl = YX_panel_raw.iloc[:, 1:split_column]
    Y_drop_etl = Y_drop_etl.iloc[Y_drop_etl[(Y_drop_etl.isnull().sum(axis = 1) > nulls_quantity)].index]
    Y_index_drop = Y_drop_etl.index

    # índice de los jugadores que no tienen más de dos observaciones en el periodo de analisis
    index_drop = list(set(X_index_drop).union(set(Y_index_drop)))

    YX_panel_raw.drop(index = index_drop, inplace = True)
    YX_panel_raw.reset_index(drop = True, inplace = True)
    YX_panel_raw = YX_panel_raw.sort_values(by = 'Jugador', ascending = True)

    # Borremos provicionalmente a los jugadores cuyo estadística máxima es igual a 0
    if Y_raw > X_raw:
        YX_panel_raw[X_raw + '_max'] = YX_panel_raw.iloc[:, 1:split_column].max(axis = 1)
    else:
        YX_panel_raw[X_raw + '_max'] = YX_panel_raw.iloc[:, split_column:YX_panel_raw.shape[1]].max(axis = 1)
    YX_max_0 = YX_panel_raw[YX_panel_raw[X_raw + '_max'] == 0]
    YX_max_0_index_drop = YX_max_0.index
    YX_panel_raw.drop(columns = X_raw + '_max', inplace = True)
    YX_panel_raw.drop(index = YX_max_0_index_drop, inplace = True)
    YX_panel_raw.reset_index(drop = True, inplace = True)

    # Variable X
    if Y_raw > X_raw:
        X_etl = YX_panel_raw.iloc[:, 1:split_column]
    else:
        X_etl = YX_panel_raw.iloc[:, split_column:YX_panel_raw.shape[1]]
    max_element = X_etl.max(axis = 1)
    min_element = X_etl.min(axis = 1)
    max_min = (max_element + min_element)/2
    dummy_names = []
    X_names = []
    for year in range(0,period):
        dummy_names.append("I_" + str(2012 + year))
        X_names.append("X_" + str(2012 + year))
    for year in range(0,period):
        X_conditions = [
        (X_etl.iloc[:,year] == max_element) & ~(X_etl.iloc[:,year].isnull()),
        (X_etl.iloc[:,year] != max_element) & ~(X_etl.iloc[:,year].isnull())
        ]
        X_conditions_values = [0,1]
        X_etl[dummy_names[year]] = np.select(X_conditions, X_conditions_values, default = np.nan)
    X_aux = X_etl.iloc[:,:period]
    Dummy = X_etl.iloc[:,period:]
    X_max = X_aux.max(axis = 1)
    X_aux[['Max']] = np.sqrt(X_max)
    for year in range(0,period):    
        X_etl['X_' + str(2012 + year)] = \
        (X_aux[X_raw + '_' + str(2012 + year)]*
        ((-1)**Dummy['I_' + str(2012 + year)]))
    X_etl = X_etl.div(X_aux['Max'].values, axis = 0)
    X_etl = X_etl.iloc[:,2*period:]
    for i in range(0,X_etl.shape[0]):
        row = X_etl.iloc[i]
        row_length = row.size
        sustitute = []

        for j in range(row_length):
            if pd.isna(row[j]) != True:
                sustitute.append(row[j])

        sustitute_length = len(sustitute)

        for k in range(row_length - sustitute_length):
            sustitute.append(np.nan)

        for j in range(row_length):
            X_etl.iloc[i,j] = sustitute[j]

    X_etl.columns = ['X_1', 'X_2', 'X_3', 'X_4', 'X_5', 'X_6', 
                     'X_7', 'X_8', 'X_9', 'X_10', 'X_11']
    X_etl[['Jugador']] = YX_panel_raw[['Jugador']]
    X_player_column = X_etl.pop('Jugador')
    X_etl.insert(0, 'Jugador', X_player_column)

    # Variable Y
    if Y_raw > X_raw:
        Y_etl = YX_panel_raw.iloc[:, split_column:YX_panel_raw.shape[1]]
    else:
        Y_etl = YX_panel_raw.iloc[:, 1:split_column]
    for i in range(0,Y_etl.shape[0]):
        row = Y_etl.iloc[i]
        row_length = row.size
        sustitute = []

        for j in range(row_length):
            if pd.isna(row[j]) != True:
                sustitute.append(row[j])

        sustitute_length = len(sustitute)

        for k in range(row_length - sustitute_length):
            sustitute.append(np.nan)

        for j in range(row_length):
            Y_etl.iloc[i,j] = sustitute[j]

    Y_etl.columns = ['w_1', 'w_2', 'w_3', 'w_4', 'w_5', 'w_6', 
                     'w_7', 'w_8', 'w_9', 'w_10', 'w_11']
    Y_etl[['Jugador']] = YX_panel_raw[['Jugador']]
    Y_player_column = Y_etl.pop('Jugador')
    Y_etl.insert(0, 'Jugador', Y_player_column)
    Y_etl_copy = Y_etl.copy()
    y_etl_names = Y_etl_copy['Jugador']
    for i in range(0,len(y_etl_names)):
        row = Y_etl_copy.iloc[i]
        row_length = row.size
        k = 0

        sustitute = []

        for j in range(0, row_length):
            if pd.isna(row[j]) != True:
                k = k + 1

        sustitute.append(y_etl_names[i])
        for j in range(1,k - 1):
            sustitute.append(row[j + 1]**0.5 - row[j]**0.5)

        sustitute_length = len(sustitute)

        for k in range(row_length - sustitute_length):
            sustitute.append(np.nan)

        for j in range(row_length):
            Y_etl_copy.iloc[i,j] = sustitute[j]

    Y_etl_copy.columns = ['Jugador', 'Y_1', 'Y_2', 'Y_3', 'Y_4', 'Y_5', 'Y_6', 
                          'Y_7', 'Y_8', 'Y_9', 'Y_10', 'Y_11']
    Y_etl = Y_etl_copy

    # Base de datos
    regression_list = [None]*(period-1)
    for i in range(0,len(regression_list)):
        merge = pd.merge(Y_etl.iloc[:,[0,i+1]], X_etl.iloc[:,[0,i+1]])
        regression_list[i] = merge
        regression_list[i].columns = ['Jugador', 'Y', 'X']
    df_article_regression = regression_list[0]
    for i in range(1,len(regression_list)):
        df_article_regression = pd.concat([df_article_regression, regression_list[i]])
    df_article_regression = df_article_regression.sort_values(by = 'Jugador', ascending = True)
    df_article_regression.reset_index(drop = True, inplace = True)
    df_article_regression.dropna(inplace = True)
    df_article_regression.reset_index(drop = True, inplace = True)
    
    # Construimos la regresion
    Y = df_article_regression['Y'].tolist()
    X = df_article_regression['X'].tolist()
    X = sm.add_constant(X)
    model = sm.OLS(Y, X).fit()
    
    # Regresamos como argumento al modelo
    return [df_article_regression, model]

# %%
X_raw_pitcher_t = 'Inning_pitched_t_1'
Y_raw_t = 'Sueldo_ajustado_t'
df_copy_t = df_pitchers_copy

# %%
df_regression_t, model_t = etl_regression(X_raw_pitcher_t, Y_raw_t, df_copy_t)

# %% [markdown]
# Veamos la base de datos ocupada para la regresión y después los datos sobre la regresión

# %%
df_regression_t
# Out:
#            Jugador            Y          X
# 0     A.J. Burnett  -494.306419 -13.065653
# 1     Aaron Harang  -143.723487 -12.572276
# 2    Adam Ottavino -1124.025620   8.814760
# 3    Adam Ottavino  -633.871074  -2.076063
# 4    Adam Ottavino   735.130524  -7.521475
# ..             ...          ...        ...
# 376   Zack Greinke -2781.936494 -13.556132
# 377   Zack Greinke   -78.388783  14.923136
# 378   Zack Greinke   910.513434 -13.556132
# 379   Zack Greinke  -111.589325 -11.907685
# 380   Zack Greinke   795.545642 -14.226232
#
# [381 rows x 3 columns]

# %%
model_t.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                  0.006415
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):              0.936
# Time:                        14:34:17   Log-Likelihood:                -3222.9
# No. Observations:                 381   AIC:                             6450.
# Df Residuals:                     379   BIC:                             6458.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         37.8318     58.805      0.643      0.520     -77.793     153.457
# x1             0.5277      6.589      0.080      0.936     -12.428      13.483
# ==============================================================================
# Omnibus:                       20.774   Durbin-Watson:                   2.205
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.992
# Skew:                          -0.456   Prob(JB):                     1.38e-06
# Kurtosis:                       3.933   Cond. No.                         8.95
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Vemos que el algoritmo funciona adecuadamente
#
# ## Pitchers
#
# Hagamos una prueba con una serie de estadísticas deportivas para cada grupo

# %%
pitcher_statistics_t = ['Bateos_en_contra_t_1', 'Carreras_en_contra_t_1', 'Carreras_ganadas_t_1', 'Comando_t_1', 'Control_t_1',
                        'Dominio_t_1', 'ERA_t_1', 'Inning_pitched_t_1', 'Juegos_t_1', 'Juegos_iniciados_t_1', 
                        'Losses_t_1', 'Saves_t_1', 'TVS_t_1', 'WAR_t_1', 'WHIP_t_1', 'Walks_t_1', 'Wins_t_1', 
                        'Bateos_en_contra_2_t_1', 'Carreras_en_contra_2_t_1', 'Carreras_ganadas_2_t_1', 'Comando_2_t_1', 'Control_2_t_1',
                        'Dominio_2_t_1', 'ERA_2_t_1', 'Inning_pitched_2_t_1', #'Juegos_iniciados_2_t_1', 
                        'Losses_2_t_1', 'Saves_2_t_1', 'TVS_2_t_1', 'WAR_2_t_1', 'WHIP_2_t_1', 'Walks_2_t_1', 'Wins_2_t_1']
Y_pitcher_raw_t = 'Sueldo_ajustado_t'
pitcher_Statistics_len = len(pitcher_statistics_t)
pitcher_model_t = [None]*pitcher_Statistics_len
df_pitcher_model_t = [None]*pitcher_Statistics_len

# %%
for statistic in range(0,pitcher_Statistics_len):
    df_pitcher_model_t[statistic], pitcher_model_t[statistic] = etl_regression(pitcher_statistics_t[statistic],
                                                                               Y_pitcher_raw_t,
                                                                               df_pitchers_copy)
    
    print(colored(pitcher_statistics_t[statistic], "cyan"))
    print(pitcher_model_t[statistic].summary())
    print('\n')
# Out:
# Bateos_en_contra_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.1569
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):              0.692
# Time:                        14:46:51   Log-Likelihood:                -3222.9
# No. Observations:                 381   AIC:                             6450.
# Df Residuals:                     379   BIC:                             6458.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         41.2833     59.411      0.695      0.488     -75.533     158.099
# x1             2.6877      6.785      0.396      0.692     -10.652      16.028
# ==============================================================================
# Omnibus:                       21.105   Durbin-Watson:                   2.204
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.530
# Skew:                          -0.460   Prob(JB):                     1.05e-06
# Kurtosis:                       3.943   Cond. No.                         8.88
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Carreras_en_contra_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     2.498
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):              0.115
# Time:                        14:46:53   Log-Likelihood:                -3221.7
# No. Observations:                 381   AIC:                             6447.
# Df Residuals:                     379   BIC:                             6455.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         54.4132     59.424      0.916      0.360     -62.429     171.255
# x1            15.7111      9.940      1.581      0.115      -3.834      35.256
# ==============================================================================
# Omnibus:                       22.280   Durbin-Watson:                   2.211
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.069
# Skew:                          -0.480   Prob(JB):                     4.87e-07
# Kurtosis:                       3.954   Cond. No.                         6.08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Carreras_ganadas_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     3.428
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):             0.0649
# Time:                        14:46:54   Log-Likelihood:                -3221.2
# No. Observations:                 381   AIC:                             6446.
# Df Residuals:                     379   BIC:                             6454.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         57.5756     59.380      0.970      0.333     -59.179     174.330
# x1            19.2159     10.378      1.852      0.065      -1.190      39.622
# ==============================================================================
# Omnibus:                       21.074   Durbin-Watson:                   2.202
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.857
# Skew:                          -0.469   Prob(JB):                     1.47e-06
# Kurtosis:                       3.902   Cond. No.                         5.83
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Comando_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     2.757
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):             0.0977
# Time:                        14:46:56   Log-Likelihood:                -3221.6
# No. Observations:                 381   AIC:                             6447.
# Df Residuals:                     379   BIC:                             6455.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         47.8305     58.762      0.814      0.416     -67.711     163.372
# x1            47.5305     28.628      1.660      0.098      -8.758     103.819
# ==============================================================================
# Omnibus:                       19.314   Durbin-Watson:                   2.221
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.773
# Skew:                          -0.452   Prob(JB):                     6.88e-06
# Kurtosis:                       3.825   Cond. No.                         2.07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Control_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     5.491
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):             0.0196
# Time:                        14:46:57   Log-Likelihood:                -3220.2
# No. Observations:                 381   AIC:                             6444.
# Df Residuals:                     379   BIC:                             6452.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         66.6811     59.541      1.120      0.263     -50.392     183.754
# x1           786.0778    335.468      2.343      0.020     126.466    1445.689
# ==============================================================================
# Omnibus:                       23.041   Durbin-Watson:                   2.241
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.484
# Skew:                          -0.487   Prob(JB):                     2.40e-07
# Kurtosis:                       3.985   Cond. No.                         5.77
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Dominio_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.1832
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):              0.669
# Time:                        14:46:59   Log-Likelihood:                -3222.9
# No. Observations:                 381   AIC:                             6450.
# Df Residuals:                     379   BIC:                             6458.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         46.2894     62.136      0.745      0.457     -75.884     168.463
# x1            87.3751    204.155      0.428      0.669    -314.043     488.793
# ==============================================================================
# Omnibus:                       20.856   Durbin-Watson:                   2.206
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.841
# Skew:                          -0.461   Prob(JB):                     1.48e-06
# Kurtosis:                       3.917   Cond. No.                         3.52
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ERA_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     6.597
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):             0.0106
# Time:                        14:47:00   Log-Likelihood:                -3219.7
# No. Observations:                 381   AIC:                             6443.
# Df Residuals:                     379   BIC:                             6451.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         64.8153     59.105      1.097      0.274     -51.399     181.030
# x1            86.2573     33.582      2.569      0.011      20.227     152.288
# ==============================================================================
# Omnibus:                       21.988   Durbin-Watson:                   2.222
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.537
# Skew:                          -0.477   Prob(JB):                     6.36e-07
# Kurtosis:                       3.942   Cond. No.                         1.82
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Inning_pitched_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     2.490
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):              0.115
# Time:                        14:47:02   Log-Likelihood:                -3221.7
# No. Observations:                 381   AIC:                             6447.
# Df Residuals:                     379   BIC:                             6455.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         50.0130     58.988      0.848      0.397     -65.972     165.998
# x1            10.2107      6.470      1.578      0.115      -2.511      22.933
# ==============================================================================
# Omnibus:                       17.811   Durbin-Watson:                   2.202
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.854
# Skew:                          -0.425   Prob(JB):                     1.80e-05
# Kurtosis:                       3.808   Cond. No.                         9.20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Juegos_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                   0.01504
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):              0.902
# Time:                        14:47:03   Log-Likelihood:                -3222.9
# No. Observations:                 381   AIC:                             6450.
# Df Residuals:                     379   BIC:                             6458.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         38.5179     59.247      0.650      0.516     -77.976     155.012
# x1             1.2180      9.930      0.123      0.902     -18.308      20.744
# ==============================================================================
# Omnibus:                       20.773   Durbin-Watson:                   2.206
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.028
# Skew:                          -0.455   Prob(JB):                     1.35e-06
# Kurtosis:                       3.935   Cond. No.                         6.03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Juegos_iniciados_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.1838
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):              0.669
# Time:                        14:47:04   Log-Likelihood:                -1923.1
# No. Observations:                 225   AIC:                             3850.
# Df Residuals:                     223   BIC:                             3857.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         84.7555     83.507      1.015      0.311     -79.809     249.320
# x1             8.6165     20.099      0.429      0.669     -30.991      48.224
# ==============================================================================
# Omnibus:                       14.102   Durbin-Watson:                   2.103
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               16.175
# Skew:                          -0.514   Prob(JB):                     0.000307
# Kurtosis:                       3.818   Cond. No.                         4.16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Losses_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.4799
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):              0.489
# Time:                        14:47:06   Log-Likelihood:                -3222.7
# No. Observations:                 381   AIC:                             6449.
# Df Residuals:                     379   BIC:                             6457.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         38.4537     58.623      0.656      0.512     -76.813     153.720
# x1            19.9492     28.797      0.693      0.489     -36.672      76.570
# ==============================================================================
# Omnibus:                       20.427   Durbin-Watson:                   2.211
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.581
# Skew:                          -0.449   Prob(JB):                     1.69e-06
# Kurtosis:                       3.932   Cond. No.                         2.04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Saves_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.8328
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):              0.363
# Time:                        14:47:06   Log-Likelihood:                -1766.0
# No. Observations:                 211   AIC:                             3536.
# Df Residuals:                     209   BIC:                             3543.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -54.8599     73.413     -0.747      0.456    -199.585      89.865
# x1            26.8279     29.399      0.913      0.363     -31.128      84.784
# ==============================================================================
# Omnibus:                        6.869   Durbin-Watson:                   2.325
# Prob(Omnibus):                  0.032   Jarque-Bera (JB):                7.252
# Skew:                          -0.317   Prob(JB):                       0.0266
# Kurtosis:                       3.649   Cond. No.                         2.55
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# TVS_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.1449
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):              0.704
# Time:                        14:47:08   Log-Likelihood:                -3044.6
# No. Observations:                 360   AIC:                             6093.
# Df Residuals:                     358   BIC:                             6101.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         36.7740     60.740      0.605      0.545     -82.677     156.225
# x1            -4.0918     10.749     -0.381      0.704     -25.231      17.048
# ==============================================================================
# Omnibus:                       22.947   Durbin-Watson:                   2.211
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.556
# Skew:                          -0.515   Prob(JB):                     3.82e-07
# Kurtosis:                       3.954   Cond. No.                         5.70
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# WAR_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.1507
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):              0.698
# Time:                        14:47:09   Log-Likelihood:                -3222.9
# No. Observations:                 381   AIC:                             6450.
# Df Residuals:                     379   BIC:                             6458.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         37.8301     58.638      0.645      0.519     -77.467     153.127
# x1           -20.6650     53.237     -0.388      0.698    -125.343      84.013
# ==============================================================================
# Omnibus:                       20.650   Durbin-Watson:                   2.204
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.834
# Skew:                          -0.453   Prob(JB):                     1.49e-06
# Kurtosis:                       3.932   Cond. No.                         1.10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# WHIP_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     9.494
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):            0.00221
# Time:                        14:47:11   Log-Likelihood:                -3218.2
# No. Observations:                 381   AIC:                             6440.
# Df Residuals:                     379   BIC:                             6448.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         83.3085     59.801      1.393      0.164     -34.275     200.891
# x1           173.3022     56.243      3.081      0.002      62.714     283.890
# ==============================================================================
# Omnibus:                       24.303   Durbin-Watson:                   2.217
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.794
# Skew:                          -0.500   Prob(JB):                     7.57e-08
# Kurtosis:                       4.032   Cond. No.                         1.30
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Walks_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     3.721
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):             0.0545
# Time:                        14:47:12   Log-Likelihood:                -3221.1
# No. Observations:                 381   AIC:                             6446.
# Df Residuals:                     379   BIC:                             6454.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         49.6697     58.698      0.846      0.398     -65.745     165.084
# x1            22.6782     11.756      1.929      0.054      -0.437      45.793
# ==============================================================================
# Omnibus:                       23.569   Durbin-Watson:                   2.213
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.559
# Skew:                          -0.479   Prob(JB):                     8.51e-08
# Kurtosis:                       4.064   Cond. No.                         5.02
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Wins_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     2.475
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):              0.117
# Time:                        14:47:14   Log-Likelihood:                -3204.2
# No. Observations:                 379   AIC:                             6412.
# Df Residuals:                     377   BIC:                             6420.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         20.6515     58.979      0.350      0.726     -95.318     136.622
# x1            41.9619     26.675      1.573      0.117     -10.488      94.412
# ==============================================================================
# Omnibus:                       21.321   Durbin-Watson:                   2.191
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.470
# Skew:                          -0.456   Prob(JB):                     6.58e-07
# Kurtosis:                       3.986   Cond. No.                         2.24
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Bateos_en_contra_2_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.3734
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):              0.542
# Time:                        14:47:15   Log-Likelihood:                -3222.8
# No. Observations:                 381   AIC:                             6450.
# Df Residuals:                     379   BIC:                             6457.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         38.5416     58.640      0.657      0.511     -76.758     153.842
# x1             0.3599      0.589      0.611      0.542      -0.798       1.518
# ==============================================================================
# Omnibus:                       21.110   Durbin-Watson:                   2.202
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.568
# Skew:                          -0.459   Prob(JB):                     1.03e-06
# Kurtosis:                       3.945   Cond. No.                         99.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Carreras_en_contra_2_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     2.644
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):              0.105
# Time:                        14:47:17   Log-Likelihood:                -3221.6
# No. Observations:                 381   AIC:                             6447.
# Df Residuals:                     379   BIC:                             6455.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         42.8405     58.532      0.732      0.465     -72.248     157.929
# x1             2.0122      1.238      1.626      0.105      -0.421       4.446
# ==============================================================================
# Omnibus:                       22.201   Durbin-Watson:                   2.208
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.088
# Skew:                          -0.477   Prob(JB):                     4.83e-07
# Kurtosis:                       3.961   Cond. No.                         47.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Carreras_ganadas_2_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     4.347
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):             0.0377
# Time:                        14:47:18   Log-Likelihood:                -3220.8
# No. Observations:                 381   AIC:                             6446.
# Df Residuals:                     379   BIC:                             6453.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         44.3440     58.402      0.759      0.448     -70.489     159.177
# x1             2.7983      1.342      2.085      0.038       0.159       5.437
# ==============================================================================
# Omnibus:                       20.451   Durbin-Watson:                   2.196
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.919
# Skew:                          -0.460   Prob(JB):                     2.35e-06
# Kurtosis:                       3.887   Cond. No.                         43.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Comando_2_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     3.090
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):             0.0796
# Time:                        14:47:20   Log-Likelihood:                -3221.4
# No. Observations:                 381   AIC:                             6447.
# Df Residuals:                     379   BIC:                             6455.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         30.1339     58.555      0.515      0.607     -84.999     145.267
# x1             4.4830      2.550      1.758      0.080      -0.532       9.498
# ==============================================================================
# Omnibus:                       21.141   Durbin-Watson:                   2.221
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.087
# Skew:                          -0.468   Prob(JB):                     1.31e-06
# Kurtosis:                       3.912   Cond. No.                         23.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Control_2_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     5.747
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):             0.0170
# Time:                        14:47:21   Log-Likelihood:                -3220.1
# No. Observations:                 381   AIC:                             6444.
# Df Residuals:                     379   BIC:                             6452.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         44.2252     58.271      0.759      0.448     -70.350     158.801
# x1          3828.6022   1597.001      2.397      0.017     688.510    6968.694
# ==============================================================================
# Omnibus:                       23.148   Durbin-Watson:                   2.243
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.830
# Skew:                          -0.486   Prob(JB):                     2.02e-07
# Kurtosis:                       3.998   Cond. No.                         27.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Dominio_2_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                   0.08512
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):              0.771
# Time:                        14:47:23   Log-Likelihood:                -3222.9
# No. Observations:                 381   AIC:                             6450.
# Df Residuals:                     379   BIC:                             6458.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         41.6837     60.379      0.690      0.490     -77.036     160.404
# x1           179.8295    616.374      0.292      0.771   -1032.111    1391.770
# ==============================================================================
# Omnibus:                       20.873   Durbin-Watson:                   2.206
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.957
# Skew:                          -0.460   Prob(JB):                     1.40e-06
# Kurtosis:                       3.923   Cond. No.                         10.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ERA_2_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     7.861
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):            0.00531
# Time:                        14:47:24   Log-Likelihood:                -3219.0
# No. Observations:                 381   AIC:                             6442.
# Df Residuals:                     379   BIC:                             6450.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         37.2934     58.044      0.642      0.521     -76.836     151.422
# x1            45.0915     16.083      2.804      0.005      13.469      76.714
# ==============================================================================
# Omnibus:                       21.920   Durbin-Watson:                   2.223
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.556
# Skew:                          -0.474   Prob(JB):                     6.30e-07
# Kurtosis:                       3.948   Cond. No.                         3.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Inning_pitched_2_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     3.885
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):             0.0494
# Time:                        14:47:26   Log-Likelihood:                -3221.0
# No. Observations:                 381   AIC:                             6446.
# Df Residuals:                     379   BIC:                             6454.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         39.7095     58.356      0.680      0.497     -75.032     154.451
# x1             1.0859      0.551      1.971      0.049       0.003       2.169
# ==============================================================================
# Omnibus:                       16.850   Durbin-Watson:                   2.198
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.154
# Skew:                          -0.418   Prob(JB):                     4.20e-05
# Kurtosis:                       3.755   Cond. No.                         106.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Losses_2_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.1510
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):              0.698
# Time:                        14:47:27   Log-Likelihood:                -3222.9
# No. Observations:                 381   AIC:                             6450.
# Df Residuals:                     379   BIC:                             6458.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         35.0843     58.955      0.595      0.552     -80.836     151.004
# x1             4.0237     10.354      0.389      0.698     -16.335      24.382
# ==============================================================================
# Omnibus:                       20.872   Durbin-Watson:                   2.208
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.285
# Skew:                          -0.455   Prob(JB):                     1.19e-06
# Kurtosis:                       3.944   Cond. No.                         5.73
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Saves_2_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.5042
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):              0.478
# Time:                        14:47:28   Log-Likelihood:                -1766.1
# No. Observations:                 211   AIC:                             3536.
# Df Residuals:                     209   BIC:                             3543.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -52.9220     73.667     -0.718      0.473    -198.149      92.305
# x1             3.9486      5.561      0.710      0.478      -7.014      14.911
# ==============================================================================
# Omnibus:                        7.082   Durbin-Watson:                   2.324
# Prob(Omnibus):                  0.029   Jarque-Bera (JB):                7.509
# Skew:                          -0.324   Prob(JB):                       0.0234
# Kurtosis:                       3.658   Cond. No.                         13.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# TVS_2_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.2247
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):              0.636
# Time:                        14:47:29   Log-Likelihood:                -3044.5
# No. Observations:                 360   AIC:                             6093.
# Df Residuals:                     358   BIC:                             6101.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         41.3227     62.295      0.663      0.508     -81.188     163.833
# x1            -0.6511      1.374     -0.474      0.636      -3.352       2.050
# ==============================================================================
# Omnibus:                       22.894   Durbin-Watson:                   2.210
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.432
# Skew:                          -0.515   Prob(JB):                     4.06e-07
# Kurtosis:                       3.950   Cond. No.                         46.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# WAR_2_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.1096
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):              0.741
# Time:                        14:47:31   Log-Likelihood:                -3222.9
# No. Observations:                 381   AIC:                             6450.
# Df Residuals:                     379   BIC:                             6458.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         33.6985     59.738      0.564      0.573     -83.760     151.157
# x1            10.7652     32.515      0.331      0.741     -53.167      74.697
# ==============================================================================
# Omnibus:                       21.455   Durbin-Watson:                   2.204
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.163
# Skew:                          -0.463   Prob(JB):                     7.66e-07
# Kurtosis:                       3.957   Cond. No.                         1.90
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# WHIP_2_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                  0.024
# Method:                 Least Squares   F-statistic:                     10.38
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):            0.00139
# Time:                        14:47:32   Log-Likelihood:                -3217.8
# No. Observations:                 381   AIC:                             6440.
# Df Residuals:                     379   BIC:                             6447.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         64.8154     58.475      1.108      0.268     -50.161     179.791
# x1           158.8389     49.306      3.222      0.001      61.892     255.786
# ==============================================================================
# Omnibus:                       24.462   Durbin-Watson:                   2.221
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               33.092
# Skew:                          -0.502   Prob(JB):                     6.52e-08
# Kurtosis:                       4.038   Cond. No.                         1.25
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Walks_2_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     4.535
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):             0.0338
# Time:                        14:47:34   Log-Likelihood:                -3220.7
# No. Observations:                 381   AIC:                             6445.
# Df Residuals:                     379   BIC:                             6453.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         35.3770     58.304      0.607      0.544     -79.262     150.016
# x1             3.8665      1.816      2.130      0.034       0.297       7.436
# ==============================================================================
# Omnibus:                       23.543   Durbin-Watson:                   2.213
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.824
# Skew:                          -0.475   Prob(JB):                     7.45e-08
# Kurtosis:                       4.079   Cond. No.                         32.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Wins_2_t_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     3.209
# Date:                Thu, 12 Jan 2023   Prob (F-statistic):             0.0740
# Time:                        14:47:35   Log-Likelihood:                -3203.8
# No. Observations:                 379   AIC:                             6412.
# Df Residuals:                     377   BIC:                             6420.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.1257     60.121      0.119      0.906    -111.089     125.341
# x1            15.6600      8.741      1.791      0.074      -1.528      32.848
# ==============================================================================
# Omnibus:                       22.553   Durbin-Watson:                   2.189
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.885
# Skew:                          -0.467   Prob(JB):                     1.97e-07
# Kurtosis:                       4.041   Cond. No.                         7.08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Hitters
#
# Hagamos lo mismo para los *hitters*.

# %%
hitter_statistics_t = ['At_bats_t_1', 'Bateos_t_1', 'Home_runs_t_1', 'Juegos_t_1',
                       'Porcentaje_On_base_plus_slugging_t_1', 'Bateos_promedio_t_1', 'Porcetnaje_juegos_t_1',
                       'Runs_batted_in_t_1', 'TVS_t_1', 'WAR_t_1', 'At_bats_2_t_1', 'Bateos_2_t_1',
                       'Home_runs_2_t_1', 'Juegos_2_t_1', 'Porcentaje_On_base_plus_slugging_2_t_1',
                       'Bateos_promedio_2_t_1', 'Porcetnaje_juegos_2_t_1',
                       'Runs_batted_in_2_t_1', 'TVS_2_t_1', 'WAR_2_t_1']
Y_hitter_raw_t = 'Sueld_ajustado_t'
hitter_Statistics_len = len(hitter_statistics_t)
hitter_model_t = [None]*hitter_Statistics_len
df_hitter_model_t = [None]*hitter_Statistics_len

# %%
for statistic in range(0,hitter_Statistics_len):
    df_hitter_model_t[statistic], hitter_model_t[statistic] = etl_regression(hitter_statistics_t[statistic],
                                                                             Y_hitter_raw_t, df_hitters_t_copy)
    
    print(colored(hitter_statistics_t[statistic], "cyan"))
    print(hitter_model_t[statistic].summary())
    print('\n')
# Out:
# At-bats
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     2.715
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.100
# Time:                        11:26:05   Log-Likelihood:                 348.75
# No. Observations:                 492   AIC:                            -693.5
# Df Residuals:                     490   BIC:                            -685.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0468      0.005     -8.598      0.000      -0.057      -0.036
# x1            -0.0006      0.000     -1.648      0.100      -0.001       0.000
# ==============================================================================
# Omnibus:                      127.193   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              471.122
# Skew:                          -1.137   Prob(JB):                    4.98e-103
# Kurtosis:                       7.221   Cond. No.                         15.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Bateos
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.019
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.313
# Time:                        11:26:07   Log-Likelihood:                 330.55
# No. Observations:                 472   AIC:                            -657.1
# Df Residuals:                     470   BIC:                            -648.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0479      0.006     -8.549      0.000      -0.059      -0.037
# x1            -0.0007      0.001     -1.009      0.313      -0.002       0.001
# ==============================================================================
# Omnibus:                      123.010   Durbin-Watson:                   2.089
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              457.358
# Skew:                          -1.140   Prob(JB):                    4.85e-100
# Kurtosis:                       7.250   Cond. No.                         7.70
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Home-runs
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.2498
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.618
# Time:                        11:26:09   Log-Likelihood:                 241.40
# No. Observations:                 361   AIC:                            -478.8
# Df Residuals:                     359   BIC:                            -471.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0498      0.007     -7.591      0.000      -0.063      -0.037
# x1            -0.0010      0.002     -0.500      0.618      -0.005       0.003
# ==============================================================================
# Omnibus:                       97.290   Durbin-Watson:                   2.147
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              354.955
# Skew:                          -1.149   Prob(JB):                     8.37e-78
# Kurtosis:                       7.280   Cond. No.                         3.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Juegos
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.447
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.230
# Time:                        11:26:11   Log-Likelihood:                 348.11
# No. Observations:                 492   AIC:                            -692.2
# Df Residuals:                     490   BIC:                            -683.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0471      0.006     -8.470      0.000      -0.058      -0.036
# x1            -0.0008      0.001     -1.203      0.230      -0.002       0.001
# ==============================================================================
# Omnibus:                      129.417   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              486.796
# Skew:                          -1.152   Prob(JB):                    1.97e-106
# Kurtosis:                       7.294   Cond. No.                         8.75
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# OPS
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.353
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.245
# Time:                        11:26:14   Log-Likelihood:                 339.17
# No. Observations:                 480   AIC:                            -674.3
# Df Residuals:                     478   BIC:                            -666.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0452      0.006     -8.123      0.000      -0.056      -0.034
# x1             0.0087      0.007      1.163      0.245      -0.006       0.023
# ==============================================================================
# Omnibus:                      124.506   Durbin-Watson:                   2.154
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              478.824
# Skew:                          -1.124   Prob(JB):                    1.06e-104
# Kurtosis:                       7.346   Cond. No.                         1.42
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Porcentaje_bateo
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                   0.03761
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.846
# Time:                        11:26:16   Log-Likelihood:                 330.06
# No. Observations:                 472   AIC:                            -656.1
# Df Residuals:                     470   BIC:                            -647.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0472      0.006     -8.419      0.000      -0.058      -0.036
# x1            -0.0024      0.013     -0.194      0.846      -0.027       0.022
# ==============================================================================
# Omnibus:                      124.340   Durbin-Watson:                   2.087
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              475.142
# Skew:                          -1.143   Prob(JB):                    6.67e-104
# Kurtosis:                       7.351   Cond. No.                         2.27
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Porcetnaje_juegos
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9976
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.318
# Time:                        11:26:18   Log-Likelihood:                 347.89
# No. Observations:                 492   AIC:                            -691.8
# Df Residuals:                     490   BIC:                            -683.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0464      0.005     -8.478      0.000      -0.057      -0.036
# x1            -0.0078      0.008     -0.999      0.318      -0.023       0.008
# ==============================================================================
# Omnibus:                      129.793   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              492.202
# Skew:                          -1.153   Prob(JB):                    1.32e-107
# Kurtosis:                       7.324   Cond. No.                         1.50
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# RBI
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.5325
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.466
# Time:                        11:26:21   Log-Likelihood:                 298.63
# No. Observations:                 438   AIC:                            -593.3
# Df Residuals:                     436   BIC:                            -585.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0470      0.006     -7.975      0.000      -0.059      -0.035
# x1            -0.0008      0.001     -0.730      0.466      -0.003       0.001
# ==============================================================================
# Omnibus:                      114.664   Durbin-Watson:                   2.257
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              430.005
# Skew:                          -1.132   Prob(JB):                     4.22e-94
# Kurtosis:                       7.293   Cond. No.                         5.66
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# TVS
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.572
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.210
# Time:                        11:26:23   Log-Likelihood:                 319.46
# No. Observations:                 462   AIC:                            -634.9
# Df Residuals:                     460   BIC:                            -626.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0459      0.006     -8.105      0.000      -0.057      -0.035
# x1             0.0013      0.001      1.254      0.210      -0.001       0.003
# ==============================================================================
# Omnibus:                      119.323   Durbin-Watson:                   2.197
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              445.417
# Skew:                          -1.125   Prob(JB):                     1.90e-97
# Kurtosis:                       7.252   Cond. No.                         5.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# WAR
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.088
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.149
# Time:                        11:26:25   Log-Likelihood:                 350.62
# No. Observations:                 474   AIC:                            -697.2
# Df Residuals:                     472   BIC:                            -688.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0439      0.005     -8.080      0.000      -0.055      -0.033
# x1             0.0065      0.005      1.445      0.149      -0.002       0.015
# ==============================================================================
# Omnibus:                      121.941   Durbin-Watson:                   2.409
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              530.533
# Skew:                          -1.070   Prob(JB):                    6.25e-116
# Kurtosis:                       7.720   Cond. No.                         1.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# At-bats_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     4.283
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):             0.0390
# Time:                        11:26:27   Log-Likelihood:                 349.53
# No. Observations:                 492   AIC:                            -695.1
# Df Residuals:                     490   BIC:                            -686.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0463      0.005     -8.595      0.000      -0.057      -0.036
# x1         -3.674e-05   1.78e-05     -2.070      0.039   -7.16e-05   -1.86e-06
# ==============================================================================
# Omnibus:                      125.654   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              461.876
# Skew:                          -1.125   Prob(JB):                    5.07e-101
# Kurtosis:                       7.180   Cond. No.                         304.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Bateos_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.919
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.167
# Time:                        11:26:30   Log-Likelihood:                 331.00
# No. Observations:                 472   AIC:                            -658.0
# Df Residuals:                     470   BIC:                            -649.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0476      0.006     -8.578      0.000      -0.059      -0.037
# x1         -9.423e-05    6.8e-05     -1.385      0.167      -0.000    3.94e-05
# ==============================================================================
# Omnibus:                      122.277   Durbin-Watson:                   2.088
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              451.981
# Skew:                          -1.135   Prob(JB):                     7.14e-99
# Kurtosis:                       7.223   Cond. No.                         81.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Home-runs_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.8251
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.364
# Time:                        11:26:31   Log-Likelihood:                 241.69
# No. Observations:                 361   AIC:                            -479.4
# Df Residuals:                     359   BIC:                            -471.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0494      0.007     -7.558      0.000      -0.062      -0.037
# x1            -0.0004      0.000     -0.908      0.364      -0.001       0.000
# ==============================================================================
# Omnibus:                       96.855   Durbin-Watson:                   2.154
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              351.953
# Skew:                          -1.145   Prob(JB):                     3.75e-77
# Kurtosis:                       7.261   Cond. No.                         14.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Juegos_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     2.669
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.103
# Time:                        11:26:34   Log-Likelihood:                 348.72
# No. Observations:                 492   AIC:                            -693.4
# Df Residuals:                     490   BIC:                            -685.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0468      0.005     -8.597      0.000      -0.057      -0.036
# x1            -0.0001   6.18e-05     -1.634      0.103      -0.000    2.04e-05
# ==============================================================================
# Omnibus:                      128.176   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              474.900
# Skew:                          -1.146   Prob(JB):                    7.53e-104
# Kurtosis:                       7.233   Cond. No.                         89.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# OPS_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.547
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.214
# Time:                        11:26:36   Log-Likelihood:                 339.27
# No. Observations:                 480   AIC:                            -674.5
# Df Residuals:                     478   BIC:                            -666.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0456      0.006     -8.282      0.000      -0.056      -0.035
# x1             0.0108      0.009      1.244      0.214      -0.006       0.028
# ==============================================================================
# Omnibus:                      124.447   Durbin-Watson:                   2.153
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              478.183
# Skew:                          -1.124   Prob(JB):                    1.46e-104
# Kurtosis:                       7.342   Cond. No.                         1.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Porcentaje_bateo_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                   0.02234
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.881
# Time:                        11:26:39   Log-Likelihood:                 330.05
# No. Observations:                 472   AIC:                            -656.1
# Df Residuals:                     470   BIC:                            -647.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0471      0.006     -8.474      0.000      -0.058      -0.036
# x1            -0.0036      0.024     -0.149      0.881      -0.051       0.044
# ==============================================================================
# Omnibus:                      124.265   Durbin-Watson:                   2.086
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              474.880
# Skew:                          -1.142   Prob(JB):                    7.60e-104
# Kurtosis:                       7.350   Cond. No.                         4.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Porcetnaje_juegos_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.620
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.204
# Time:                        11:26:42   Log-Likelihood:                 348.20
# No. Observations:                 492   AIC:                            -692.4
# Df Residuals:                     490   BIC:                            -684.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0460      0.005     -8.517      0.000      -0.057      -0.035
# x1            -0.0118      0.009     -1.273      0.204      -0.030       0.006
# ==============================================================================
# Omnibus:                      128.930   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              484.540
# Skew:                          -1.148   Prob(JB):                    6.08e-106
# Kurtosis:                       7.286   Cond. No.                         1.73
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# RBI_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9457
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.331
# Time:                        11:26:44   Log-Likelihood:                 298.84
# No. Observations:                 438   AIC:                            -593.7
# Df Residuals:                     436   BIC:                            -585.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0466      0.006     -7.951      0.000      -0.058      -0.035
# x1            -0.0001      0.000     -0.972      0.331      -0.000       0.000
# ==============================================================================
# Omnibus:                      114.035   Durbin-Watson:                   2.258
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              428.284
# Skew:                          -1.125   Prob(JB):                     9.99e-94
# Kurtosis:                       7.290   Cond. No.                         44.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# TVS_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     2.866
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):             0.0911
# Time:                        11:26:46   Log-Likelihood:                 320.10
# No. Observations:                 462   AIC:                            -636.2
# Df Residuals:                     460   BIC:                            -627.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0472      0.006     -8.229      0.000      -0.058      -0.036
# x1             0.0002      0.000      1.693      0.091   -3.92e-05       0.001
# ==============================================================================
# Omnibus:                      119.057   Durbin-Watson:                   2.193
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              442.311
# Skew:                          -1.124   Prob(JB):                     8.98e-97
# Kurtosis:                       7.234   Cond. No.                         40.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# WAR_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.022
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.313
# Time:                        11:26:48   Log-Likelihood:                 341.76
# No. Observations:                 486   AIC:                            -679.5
# Df Residuals:                     484   BIC:                            -671.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0469      0.006     -8.450      0.000      -0.058      -0.036
# x1             0.0026      0.003      1.011      0.313      -0.002       0.008
# ==============================================================================
# Omnibus:                      126.326   Durbin-Watson:                   2.390
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              487.535
# Skew:                          -1.127   Prob(JB):                    1.36e-106
# Kurtosis:                       7.358   Cond. No.                         2.20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
