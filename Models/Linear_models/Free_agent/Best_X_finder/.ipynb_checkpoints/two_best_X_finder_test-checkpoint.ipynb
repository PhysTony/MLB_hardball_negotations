# %% [markdown]
# # Best X finder - Test
#
# Veremos cómo funciona el algoritmo en un script distinto puesto que podría haber variables inicializadas en los test del script *two_best_X_finder.ipynb*

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from matplotlib.colors import ListedColormap
from termcolor import colored
from sklearn.naive_bayes import GaussianNB
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
import pandas as pd
import numpy as np
import array
import math
import os
import warnings
print('Modulos importados')
# Out:
# Modulos importados

# %%
# Configuraciones
warnings.filterwarnings('ignore')
# Reduzcamos el número de línea a leer
pd.options.display.max_rows = 15

# %%
# Veamos el directorio actual de trabajo
print(os.getcwd())
# El directorio anterior es el correcto, pero si no lo fuese, hacemos lo sigueinte:
path = '/home/usuario/Documentos/Github/Proyectos/MLB_HN'
os.chdir(path)
# Out:
# /home/usuario/Documentos/Github/Proyectos/MLB_HN/Models/Linear_models/Free_agent/Best_X_finder

# %%
print("Para modificar el tamaño de todos los gráficos")
from matplotlib import rcParams
rcParams['figure.figsize'] = 15,9
# Out:
# Para modificar el tamaño de todos los gráficos

# %%
# Veamos el directorio actual de trabajo
print(os.getcwd())
# El directorio anterior es el correcto, pero si no lo fuese, hacemos lo sigueinte:
path = '/home/usuario/Documentos/Github/Proyectos/MLB_HN'
print("Nuevo directorio de trabajo: " + str(os.chdir(path)))
# Out:
# /home/usuario/Documentos/Github/Proyectos/MLB_HN
# Nuevo directorio de trabajo: None

# %% [markdown]
# ## Exploración de datos
#
# Estudiaremos de manera general si hay datos faltantes, así como el tipo de datos que contiene

# %%
# Años de análisis
starting_year = 2011
period = 11
csv = '.csv'
# Directorios
pitchers_path = 'ETL_data/Free_Agent/Pitchers/free_agents_pitchers_'
hitters_path = 'ETL_data/Free_Agent/Hitters/free_agents_batters_'
# Originales:
df_pitchers = [None]*period
df_pitchers_copy = [None]*period
df_hitters = [None]*period
df_hitters_copy = [None]*period

# %% [markdown]
# Leamos todos las bases de datos correspondientes

# %%
for year in range(0,period):
    df_pitchers[year] = pd.read_csv(pitchers_path + str(starting_year + year) + csv)
    df_pitchers_copy[year] = df_pitchers[year].copy()
    
    df_hitters[year] = pd.read_csv(hitters_path + str(starting_year + year) + csv)
    df_hitters_copy[year] = df_hitters[year].copy()

# %% [markdown]
# Observemos el contenido de las bases de datos

# %%
# Pitchers
df_pitchers_copy[5].head()
# Out:
#   Acronimo  Altura  Anio  Anios_contrato  Bateos_pitcher  Bateos_pitcher_2  \
# 0      TEX     6.5  2016               1             116             13456
# 1      CIN     6.6  2016               1              89              7921
# 2      DET     6.0  2013               5             171             29241
# 3      MIL     6.3  2016               1              80              6400
# 4      CIN     6.5  2016               1              72              5184
#
#    Cantidad de equipos  Cantidad_agentes_libres  Carreras  Carreras_2  ...  \
# 0                    2                       10        68        4624  ...
# 1                    2                        8        64        4096  ...
# 2                    1                       11       108       11664  ...
# 3                    1                        8        30         900  ...
# 4                    2                        8        38        1444  ...
#
#    Victorias   WAR   WAR_2  WHIP  WHIP_2  WS ganadas  Walks  Walks_2  Wins  \
# 0         95  0.93  0.8649  1.36  1.8496           0     46     2116     7
# 1         68 -2.14  4.5796  2.05  4.2025           5     31      961     2
# 2         86 -0.96  0.9216  1.46  2.1316           4     53     2809     7
# 3         72  0.60  0.3600  1.47  2.1609           0     17      289     2
# 4         68  0.53  0.2809  1.44  2.0736           5     38     1444     6
#
#    Wins_2
# 0      49
# 1       4
# 2      49
# 3       4
# 4      36
#
# [5 rows x 62 columns]

# %%
list(enumerate(df_pitchers_copy[5].columns))
# Out:
# [(0, 'Acronimo'),
#  (1, 'Altura'),
#  (2, 'Anio'),
#  (3, 'Anios_contrato'),
#  (4, 'Bateos_pitcher'),
#  (5, 'Bateos_pitcher_2'),
#  (6, 'Cantidad de equipos'),
#  (7, 'Cantidad_agentes_libres'),
#  (8, 'Carreras'),
#  (9, 'Carreras_2'),
#  (10, 'Carreras_ganadas'),
#  (11, 'Carreras_ganadas_2'),
#  (12, 'Comando'),
#  (13, 'Comando_2'),
#  (14, 'Control'),
#  (15, 'Control_2'),
#  (16, 'Dominio'),
#  (17, 'Dominio_2'),
#  (18, 'ERA'),
#  (19, 'ERA_2'),
#  (20, 'Edad'),
#  (21, 'Equipo'),
#  (22, 'Equipo_anterior'),
#  (23, 'Estado'),
#  (24, 'Inning_pitched'),
#  (25, 'Inning_pitched_2'),
#  (26, 'Juegos'),
#  (27, 'Juegos totales'),
#  (28, 'Juegos_2'),
#  (29, 'Juegos_iniciados'),
#  (30, 'Juegos_iniciados_2'),
#  (31, 'Jugador'),
#  (32, 'Losses'),
#  (33, 'Losses_2'),
#  (34, 'Pennants won'),
#  (35, 'Peso'),
#  (36, 'Playoffs'),
#  (37, 'Posicion'),
#  (38, 'Promedio_victorias'),
#  (39, 'Saves'),
#  (40, 'Saves_2'),
#  (41, 'Status'),
#  (42, 'Strike-outs'),
#  (43, 'Strike-outs_2'),
#  (44, 'Sueldo'),
#  (45, 'Sueldo_base'),
#  (46, 'Sueldo_regular'),
#  (47, 'TVS'),
#  (48, 'TVS_2'),
#  (49, 'Valor_contrato'),
#  (50, 'Valor_contrato_total'),
#  (51, 'Valor_promedio_contrato'),
#  (52, 'Victorias'),
#  (53, 'WAR'),
#  (54, 'WAR_2'),
#  (55, 'WHIP'),
#  (56, 'WHIP_2'),
#  (57, 'WS ganadas'),
#  (58, 'Walks'),
#  (59, 'Walks_2'),
#  (60, 'Wins'),
#  (61, 'Wins_2')]

# %%
# Hitters
df_hitters_copy[5].head()
# Out:
#   Acronimo  Altura  Anio  Anios_contrato  At-bats  At-bats_2  Bateos  \
# 0      TEX     6.5  2016               1        2          4       0
# 1      ATL     6.3  2016               1      247      61009      55
# 2      LAA     6.3  2012              10      593     351649     159
# 3      NYM     6.0  2016               1      234      54756      48
# 4       KC     6.1  2016               4      445     198025      98
#
#    Bateos_2  Cantidad de equipos  Cantidad_agentes_libres  ...  \
# 0         0                    2                       10  ...
# 1      3025                    1                       13  ...
# 2     25281                    5                        9  ...
# 3      2304                    2                        9  ...
# 4      9604                    2                       10  ...
#
#    Sueldo_regular    TVS     TVS_2 Valor_contrato  Valor_contrato_total  \
# 0          493633   0.00    0.0000         507500              20165000
# 1         3050000   0.00    0.0000        3000000              19157500
# 2        25000000  20.37  414.9369      240000000              12525000
# 3         5750000   4.25   18.0625        5750000              48757500
# 4        12000000  12.36  152.7696       72000000             186750000
#
#    Valor_promedio_contrato  Victorias   WAR   WAR_2 WS ganadas
# 0                   507500         95  0.93  0.8649          0
# 1                  3000000         67 -1.28  1.6384          3
# 2                 24000000         73  1.29  1.6641          1
# 3                  5750000         87 -0.38  0.1444          2
# 4                 18000000         81  0.91  0.8281          2
#
# [5 rows x 46 columns]

# %% [markdown]
# Veamos las columnas con sus índices

# %%
list(enumerate(df_hitters_copy[5].columns))
# Out:
# [(0, 'Acronimo'),
#  (1, 'Altura'),
#  (2, 'Anio'),
#  (3, 'Anios_contrato'),
#  (4, 'At-bats'),
#  (5, 'At-bats_2'),
#  (6, 'Bateos'),
#  (7, 'Bateos_2'),
#  (8, 'Cantidad de equipos'),
#  (9, 'Cantidad_agentes_libres'),
#  (10, 'Edad'),
#  (11, 'Equipo'),
#  (12, 'Equipo_anterior'),
#  (13, 'Estado'),
#  (14, 'Home-runs'),
#  (15, 'Home-runs_2'),
#  (16, 'Juegos'),
#  (17, 'Juegos totales'),
#  (18, 'Juegos_2'),
#  (19, 'Jugador'),
#  (20, 'OPS'),
#  (21, 'OPS_2'),
#  (22, 'Pennants won'),
#  (23, 'Peso'),
#  (24, 'Playoffs'),
#  (25, 'Porcentaje_bateo'),
#  (26, 'Porcentaje_bateo_2'),
#  (27, 'Porcetnaje_juegos'),
#  (28, 'Porcetnaje_juegos_2'),
#  (29, 'Posicion'),
#  (30, 'Promedio_victorias'),
#  (31, 'RBI'),
#  (32, 'RBI_2'),
#  (33, 'Status'),
#  (34, 'Sueldo'),
#  (35, 'Sueldo_base'),
#  (36, 'Sueldo_regular'),
#  (37, 'TVS'),
#  (38, 'TVS_2'),
#  (39, 'Valor_contrato'),
#  (40, 'Valor_contrato_total'),
#  (41, 'Valor_promedio_contrato'),
#  (42, 'Victorias'),
#  (43, 'WAR'),
#  (44, 'WAR_2'),
#  (45, 'WS ganadas')]

# %% [markdown]
# Veamos si hay bases de datos con variables que distintas entre sí

# %% [markdown]
# ## Test

# %%
def etl_regression(X_raw, Y_raw, df_copy):
    # Creación de la base de datos a transformar las variables de la regresión
    jugador = 'Jugador'
    YX_raw = [None]*period
    
    for year in range(0, period):
        YX_raw[year] = df_copy[year][[jugador, Y_raw, X_raw]]

    # Ajuste de inflación en los salarios    
    change_inflation_percentage = {2011:20.46, 2012:18.02, 2013:16.32, 2014:14.46,
                                   2015:14.33, 2016:12.90, 2017:10.55, 2018:7.86,
                                   2019:5.99, 2020:4.70, 2021:1}
    for year in range(0, period):
        YX_raw[year][[Y_raw]] = YX_raw[year][[Y_raw]]*(1 + change_inflation_percentage[2011 + year]*0.01)
        YX_raw[year].rename(columns = {Y_raw: Y_raw + '_' + str(2011 + year)}, inplace = True)
        YX_raw[year].rename(columns = {X_raw: X_raw + '_' + str(2011 + year)}, inplace = True)

    # Filtrado de base de datos
    YX_panel_raw = pd.merge(YX_raw[0], YX_raw[1], how = 'outer', on = 'Jugador')

    for year in range(2,period):
        YX_panel_raw = pd.merge(YX_panel_raw, YX_raw[year], how = 'outer', on = 'Jugador')

    YX_panel_raw.drop_duplicates(subset = 'Jugador', inplace = True)
    YX_panel_raw = YX_panel_raw.sort_values(by = 'Jugador', ascending = True)
    YX_panel_raw.reset_index(drop = True, inplace = True)
    YX_panel_raw.sort_index(axis = 1, inplace = True)

    # Recolocación al principio de Jugador
    player_column = YX_panel_raw.pop('Jugador')
    YX_panel_raw.insert(0, 'Jugador', player_column)

    # Creación de base de datos auxiliares  para remover los NaN
    split_column = 1 + period
    max_nan = 2

    if Y_raw > X_raw:
        X_drop_etl = YX_panel_raw.iloc[:, 1:split_column]
    else:
        X_drop_etl = YX_panel_raw.iloc[:, split_column:YX_panel_raw.shape[1]]

    nulls_quantity = period - max_nan
    X_drop_etl = X_drop_etl.iloc[X_drop_etl[(X_drop_etl.isnull().sum(axis = 1) > nulls_quantity)].index]
    X_index_drop = X_drop_etl.index

    if Y_raw > X_raw:
        Y_drop_etl = YX_panel_raw.iloc[:, split_column:YX_panel_raw.shape[1]]
    else:
        Y_drop_etl = YX_panel_raw.iloc[:, 1:split_column]
    Y_drop_etl = Y_drop_etl.iloc[Y_drop_etl[(Y_drop_etl.isnull().sum(axis = 1) > nulls_quantity)].index]
    Y_index_drop = Y_drop_etl.index

    # índice de los jugadores que no tienen más de dos observaciones en el periodo de analisis
    index_drop = list(set(X_index_drop).union(set(Y_index_drop)))

    YX_panel_raw.drop(index = index_drop, inplace = True)
    YX_panel_raw.reset_index(drop = True, inplace = True)
    YX_panel_raw = YX_panel_raw.sort_values(by = 'Jugador', ascending = True)

    # Borremos provicionalmente a los jugadores cuyo estadística máxima es igual a 0
    if Y_raw > X_raw:
        YX_panel_raw[X_raw + '_max'] = YX_panel_raw.iloc[:, 1:split_column].max(axis = 1)
    else:
        YX_panel_raw[X_raw + '_max'] = YX_panel_raw.iloc[:, split_column:YX_panel_raw.shape[1]].max(axis = 1)
    YX_max_0 = YX_panel_raw[YX_panel_raw[X_raw + '_max'] == 0]
    YX_max_0_index_drop = YX_max_0.index
    YX_panel_raw.drop(columns = X_raw + '_max', inplace = True)
    YX_panel_raw.drop(index = YX_max_0_index_drop, inplace = True)
    YX_panel_raw.reset_index(drop = True, inplace = True)

    # Variable X
    if Y_raw > X_raw:
        X_etl = YX_panel_raw.iloc[:, 1:split_column]
    else:
        X_etl = YX_panel_raw.iloc[:, split_column:YX_panel_raw.shape[1]]
    max_element = X_etl.max(axis = 1)
    min_element = X_etl.min(axis = 1)
    max_min = (max_element + min_element)/2
    dummy_names = []
    X_names = []
    for year in range(0,period):
        dummy_names.append("I_" + str(2011 + year))
        X_names.append("X_" + str(2011 + year))
    for year in range(0,period):
        X_conditions = [
        (X_etl.iloc[:,year] == max_element) & ~(X_etl.iloc[:,year].isnull()),
        (X_etl.iloc[:,year] != max_element) & ~(X_etl.iloc[:,year].isnull())
        ]
        X_conditions_values = [0,1]
        X_etl[dummy_names[year]] = np.select(X_conditions, X_conditions_values, default = np.nan)
    X_aux = X_etl.iloc[:,:period]
    Dummy = X_etl.iloc[:,period:]
    X_max = X_aux.max(axis = 1)
    X_aux[['Max']] = np.sqrt(X_max)
    for year in range(0,period):    
        X_etl['X_' + str(2011 + year)] = \
        (X_aux[X_raw + '_' + str(2011 + year)]*
        ((-1)**Dummy['I_' + str(2011 + year)]))
    X_etl = X_etl.div(X_aux['Max'].values, axis = 0)
    X_etl = X_etl.iloc[:,2*period:]
    for i in range(0,X_etl.shape[0]):
        row = X_etl.iloc[i]
        row_length = row.size
        sustitute = []

        for j in range(row_length):
            if pd.isna(row[j]) != True:
                sustitute.append(row[j])

        sustitute_length = len(sustitute)

        for k in range(row_length - sustitute_length):
            sustitute.append(np.nan)

        for j in range(row_length):
            X_etl.iloc[i,j] = sustitute[j]

    X_etl.columns = ['X_1', 'X_2', 'X_3', 'X_4', 'X_5', 'X_6', 
                     'X_7', 'X_8', 'X_9', 'X_10', 'X_11']
    X_etl[['Jugador']] = YX_panel_raw[['Jugador']]
    X_player_column = X_etl.pop('Jugador')
    X_etl.insert(0, 'Jugador', X_player_column)

    # Variable Y
    if Y_raw > X_raw:
        Y_etl = YX_panel_raw.iloc[:, split_column:YX_panel_raw.shape[1]]
    else:
        Y_etl = YX_panel_raw.iloc[:, 1:split_column]
    for i in range(0,Y_etl.shape[0]):
        row = Y_etl.iloc[i]
        row_length = row.size
        sustitute = []

        for j in range(row_length):
            if pd.isna(row[j]) != True:
                sustitute.append(row[j])

        sustitute_length = len(sustitute)

        for k in range(row_length - sustitute_length):
            sustitute.append(np.nan)

        for j in range(row_length):
            Y_etl.iloc[i,j] = sustitute[j]

    Y_etl.columns = ['w_1', 'w_2', 'w_3', 'w_4', 'w_5', 'w_6', 
                     'w_7', 'w_8', 'w_9', 'w_10', 'w_11']
    Y_etl[['Jugador']] = YX_panel_raw[['Jugador']]
    Y_player_column = Y_etl.pop('Jugador')
    Y_etl.insert(0, 'Jugador', Y_player_column)
    Y_etl_copy = Y_etl.copy()
    y_etl_names = Y_etl_copy['Jugador']
    for i in range(0,len(y_etl_names)):
        row = Y_etl_copy.iloc[i]
        row_length = row.size
        k = 0

        sustitute = []

        for j in range(0, row_length):
            if pd.isna(row[j]) != True:
                k = k + 1

        sustitute.append(y_etl_names[i])
        for j in range(1,k - 1):
            sustitute.append(row[j + 1]**0.5 - row[j]**0.5)

        sustitute_length = len(sustitute)

        for k in range(row_length - sustitute_length):
            sustitute.append(np.nan)

        for j in range(row_length):
            Y_etl_copy.iloc[i,j] = sustitute[j]

    Y_etl_copy.columns = ['Jugador', 'Y_1', 'Y_2', 'Y_3', 'Y_4', 'Y_5', 'Y_6', 
                          'Y_7', 'Y_8', 'Y_9', 'Y_10', 'Y_11']
    Y_etl = Y_etl_copy

    # Base de datos
    regression_list = [None]*(period-1)
    for i in range(0,len(regression_list)):
        merge = pd.merge(Y_etl.iloc[:,[0,i+1]], X_etl.iloc[:,[0,i+1]])
        regression_list[i] = merge
        regression_list[i].columns = ['Jugador', 'Y', 'X']
    df_article_regression = regression_list[0]
    for i in range(1,len(regression_list)):
        df_article_regression = pd.concat([df_article_regression, regression_list[i]])
    df_article_regression = df_article_regression.sort_values(by = 'Jugador', ascending = True)
    df_article_regression.reset_index(drop = True, inplace = True)
    df_article_regression.dropna(inplace = True)
    df_article_regression.reset_index(drop = True, inplace = True)
    
    # Construimos la regresion
    Y = df_article_regression['Y'].tolist()
    X = df_article_regression['X'].tolist()
    X = sm.add_constant(X)
    model = sm.OLS(Y, X).fit()
    
    # Regresamos como argumento al modelo
    return [df_article_regression, model]

# %%
X_raw_pitcher = 'Inning_pitched'
Y_raw = 'Sueldo'
df_copy = df_pitchers_copy

# %%
df_regression, model = etl_regression(X_raw_pitcher, Y_raw, df_copy)

# %% [markdown]
# Veamos la base de datos ocupada para la regresión y después los datos sobre la regresión

# %%
df_regression
# Out:
#            Jugador           Y          X
# 0     A.J. Burnett -471.040165  14.618481
# 1     Aaron Harang  647.699528  13.405223
# 2     Aaron Harang -138.427417 -10.689863
# 3    Adam Ottavino -368.340054  -2.042177
# 4    Adam Ottavino  -18.852808  -7.398706
# ..             ...         ...        ...
# 420   Zack Greinke    6.483182 -13.528012
# 421   Zack Greinke  -75.049658 -13.113161
# 422   Zack Greinke  -64.819869 -10.286993
# 423   Zack Greinke  740.407614 -13.113161
# 424   Zack Greinke  754.087221  -11.51858
#
# [425 rows x 3 columns]

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.1909
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.662
# Time:                        15:39:38   Log-Likelihood:                -3447.7
# No. Observations:                 425   AIC:                             6899.
# Df Residuals:                     423   BIC:                             6907.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         27.9714     40.685      0.688      0.492     -51.999     107.941
# x1            -2.0278      4.641     -0.437      0.662     -11.150       7.094
# ==============================================================================
# Omnibus:                       89.562   Durbin-Watson:                   2.229
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              260.360
# Skew:                          -0.983   Prob(JB):                     2.91e-57
# Kurtosis:                       6.292   Cond. No.                         9.10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Vemos que el algoritmo funciona adecuadamente
#
# ## Pitchers
#
# Hagamos una prueba con una serie de estadísticas deportivas para cada grupo

# %%
pitcher_statistics = ['Bateos_pitcher', 'Carreras', 'Carreras_ganadas', 'Comando', 'Control',
                      'Dominio', 'ERA', 'Inning_pitched', 'Juegos', 'Juegos_iniciados', 
                      'Losses', 'Saves', 'TVS', 'WAR', 'WHIP', 'Walks', 'Wins', 
                      'Bateos_pitcher_2', 'Carreras_2', 'Carreras_ganadas_2', 'Comando_2', 'Control_2',
                      'Dominio_2', 'ERA_2', 'Inning_pitched_2', 'Juegos_2', 'Juegos_iniciados_2', 
                      'Losses_2', 'Saves_2', 'TVS_2', 'WAR_2', 'WHIP_2', 'Walks_2', 'Wins_2']
Y_pitcher_raw = 'Sueldo'
pitcher_Statistics_len = len(pitcher_statistics)
pitcher_model = [None]*pitcher_Statistics_len
df_pitcher_model = [None]*pitcher_Statistics_len

# %%
for statistic in range(0,pitcher_Statistics_len):
    df_pitcher_model[statistic], pitcher_model[statistic] = etl_regression(pitcher_statistics[statistic], Y_raw, df_pitchers_copy)
    
    print(colored(pitcher_statistics[statistic], "cyan"))
    print(pitcher_model[statistic].summary())
    print('\n')
# Out:
# Bateos_pitcher
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     2.331
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.128
# Time:                        15:39:40   Log-Likelihood:                -3446.6
# No. Observations:                 425   AIC:                             6897.
# Df Residuals:                     423   BIC:                             6905.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         17.1756     40.429      0.425      0.671     -62.292      96.643
# x1            -7.2712      4.762     -1.527      0.128     -16.632       2.090
# ==============================================================================
# Omnibus:                       91.392   Durbin-Watson:                   2.224
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              271.286
# Skew:                          -0.995   Prob(JB):                     1.23e-59
# Kurtosis:                       6.370   Cond. No.                         8.78
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Carreras
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     5.443
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):             0.0201
# Time:                        15:39:42   Log-Likelihood:                -3436.7
# No. Observations:                 424   AIC:                             6877.
# Df Residuals:                     422   BIC:                             6885.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          8.2098     40.670      0.202      0.840     -71.731      88.151
# x1           -16.1845      6.937     -2.333      0.020     -29.821      -2.548
# ==============================================================================
# Omnibus:                       92.522   Durbin-Watson:                   2.184
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              281.018
# Skew:                          -1.002   Prob(JB):                     9.50e-62
# Kurtosis:                       6.449   Cond. No.                         6.13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Carreras_ganadas
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     3.559
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):             0.0599
# Time:                        15:39:43   Log-Likelihood:                -3437.6
# No. Observations:                 424   AIC:                             6879.
# Df Residuals:                     422   BIC:                             6887.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         15.6079     40.430      0.386      0.700     -63.862      95.078
# x1           -13.5319      7.173     -1.887      0.060     -27.631       0.567
# ==============================================================================
# Omnibus:                       88.817   Durbin-Watson:                   2.186
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              261.430
# Skew:                          -0.972   Prob(JB):                     1.70e-57
# Kurtosis:                       6.319   Cond. No.                         5.84
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Comando
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     4.531
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):             0.0339
# Time:                        15:39:45   Log-Likelihood:                -3429.5
# No. Observations:                 423   AIC:                             6863.
# Df Residuals:                     421   BIC:                             6871.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         48.2100     39.637      1.216      0.225     -29.702     126.122
# x1            52.3624     24.599      2.129      0.034       4.011     100.714
# ==============================================================================
# Omnibus:                       92.476   Durbin-Watson:                   2.160
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              274.664
# Skew:                          -1.011   Prob(JB):                     2.28e-60
# Kurtosis:                       6.390   Cond. No.                         1.66
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Control
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                  0.002904
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.957
# Time:                        15:39:47   Log-Likelihood:                -3439.4
# No. Observations:                 424   AIC:                             6883.
# Df Residuals:                     422   BIC:                             6891.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         34.2730     41.619      0.824      0.411     -47.533     116.079
# x1           -12.9333    239.987     -0.054      0.957    -484.653     458.786
# ==============================================================================
# Omnibus:                       91.226   Durbin-Watson:                   2.174
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              267.363
# Skew:                          -1.000   Prob(JB):                     8.77e-59
# Kurtosis:                       6.337   Cond. No.                         6.13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Dominio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.641
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.201
# Time:                        15:39:49   Log-Likelihood:                -3446.9
# No. Observations:                 425   AIC:                             6898.
# Df Residuals:                     423   BIC:                             6906.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         47.0039     40.730      1.154      0.249     -33.054     127.062
# x1           170.7708    133.298      1.281      0.201     -91.238     432.780
# ==============================================================================
# Omnibus:                       88.498   Durbin-Watson:                   2.221
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              258.692
# Skew:                          -0.969   Prob(JB):                     6.70e-57
# Kurtosis:                       6.294   Cond. No.                         3.43
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ERA
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.5954
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.441
# Time:                        15:39:50   Log-Likelihood:                -3439.1
# No. Observations:                 424   AIC:                             6882.
# Df Residuals:                     422   BIC:                             6890.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         16.7985     45.792      0.367      0.714     -73.211     106.808
# x1           -21.3105     27.618     -0.772      0.441     -75.596      32.975
# ==============================================================================
# Omnibus:                       90.438   Durbin-Watson:                   2.168
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              261.840
# Skew:                          -0.996   Prob(JB):                     1.39e-57
# Kurtosis:                       6.295   Cond. No.                         2.18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Inning_pitched
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.1909
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.662
# Time:                        15:39:52   Log-Likelihood:                -3447.7
# No. Observations:                 425   AIC:                             6899.
# Df Residuals:                     423   BIC:                             6907.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         27.9714     40.685      0.688      0.492     -51.999     107.941
# x1            -2.0278      4.641     -0.437      0.662     -11.150       7.094
# ==============================================================================
# Omnibus:                       89.562   Durbin-Watson:                   2.229
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              260.360
# Skew:                          -0.983   Prob(JB):                     2.91e-57
# Kurtosis:                       6.292   Cond. No.                         9.10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Juegos
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.2167
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.642
# Time:                        15:39:54   Log-Likelihood:                -3447.6
# No. Observations:                 425   AIC:                             6899.
# Df Residuals:                     423   BIC:                             6907.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         26.7384     41.255      0.648      0.517     -54.351     107.828
# x1            -3.4112      7.327     -0.466      0.642     -17.814      10.991
# ==============================================================================
# Omnibus:                       90.405   Durbin-Watson:                   2.227
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              263.385
# Skew:                          -0.991   Prob(JB):                     6.41e-58
# Kurtosis:                       6.308   Cond. No.                         5.94
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Juegos_iniciados
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                   0.04467
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.833
# Time:                        15:39:55   Log-Likelihood:                -2148.0
# No. Observations:                 263   AIC:                             4300.
# Df Residuals:                     261   BIC:                             4307.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         47.2085     53.792      0.878      0.381     -58.713     153.130
# x1             2.8417     13.445      0.211      0.833     -23.633      29.317
# ==============================================================================
# Omnibus:                       53.235   Durbin-Watson:                   2.238
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              133.155
# Skew:                          -0.931   Prob(JB):                     1.22e-29
# Kurtosis:                       5.947   Cond. No.                         4.09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Losses
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                   0.01073
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.918
# Time:                        15:39:57   Log-Likelihood:                -3412.0
# No. Observations:                 421   AIC:                             6828.
# Df Residuals:                     419   BIC:                             6836.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         31.5558     39.168      0.806      0.421     -45.434     108.546
# x1            -1.9919     19.234     -0.104      0.918     -39.798      35.815
# ==============================================================================
# Omnibus:                       96.703   Durbin-Watson:                   2.193
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              283.329
# Skew:                          -1.067   Prob(JB):                     2.99e-62
# Kurtosis:                       6.405   Cond. No.                         2.04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Saves
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                   0.04013
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.841
# Time:                        15:39:58   Log-Likelihood:                -1815.4
# No. Observations:                 226   AIC:                             3635.
# Df Residuals:                     224   BIC:                             3642.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         35.3277     50.038      0.706      0.481     -63.277     133.933
# x1            -4.1816     20.874     -0.200      0.841     -45.317      36.954
# ==============================================================================
# Omnibus:                       56.540   Durbin-Watson:                   1.946
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              180.940
# Skew:                          -1.021   Prob(JB):                     5.12e-40
# Kurtosis:                       6.879   Cond. No.                         2.41
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# TVS
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     3.674
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):             0.0560
# Time:                        15:40:00   Log-Likelihood:                -3223.7
# No. Observations:                 399   AIC:                             6451.
# Df Residuals:                     397   BIC:                             6459.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         44.7467     39.199      1.142      0.254     -32.318     121.811
# x1            14.4586      7.543      1.917      0.056      -0.370      29.287
# ==============================================================================
# Omnibus:                       83.246   Durbin-Watson:                   2.099
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              235.698
# Skew:                          -0.975   Prob(JB):                     6.59e-52
# Kurtosis:                       6.221   Cond. No.                         5.20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# WAR
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     5.132
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):             0.0240
# Time:                        15:40:02   Log-Likelihood:                -3350.1
# No. Observations:                 414   AIC:                             6704.
# Df Residuals:                     412   BIC:                             6712.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         29.0616     39.404      0.738      0.461     -48.396     106.519
# x1            86.2982     38.096      2.265      0.024      11.412     161.184
# ==============================================================================
# Omnibus:                       78.758   Durbin-Watson:                   2.208
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              224.504
# Skew:                          -0.891   Prob(JB):                     1.78e-49
# Kurtosis:                       6.137   Cond. No.                         1.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# WHIP
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     2.830
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):             0.0933
# Time:                        15:40:03   Log-Likelihood:                -3446.3
# No. Observations:                 425   AIC:                             6897.
# Df Residuals:                     423   BIC:                             6905.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -11.9140     47.247     -0.252      0.801    -104.782      80.954
# x1           -81.8303     48.642     -1.682      0.093    -177.441      13.781
# ==============================================================================
# Omnibus:                       89.707   Durbin-Watson:                   2.209
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              257.015
# Skew:                          -0.990   Prob(JB):                     1.55e-56
# Kurtosis:                       6.255   Cond. No.                         1.89
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Walks
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.3766
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.540
# Time:                        15:40:05   Log-Likelihood:                -3439.2
# No. Observations:                 424   AIC:                             6882.
# Df Residuals:                     422   BIC:                             6890.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         29.3943     40.301      0.729      0.466     -49.822     108.611
# x1            -5.1249      8.351     -0.614      0.540     -21.539      11.289
# ==============================================================================
# Omnibus:                       91.036   Durbin-Watson:                   2.178
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              267.158
# Skew:                          -0.998   Prob(JB):                     9.71e-59
# Kurtosis:                       6.338   Cond. No.                         4.97
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Wins
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.341
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.248
# Time:                        15:40:07   Log-Likelihood:                -3399.3
# No. Observations:                 420   AIC:                             6803.
# Df Residuals:                     418   BIC:                             6811.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         46.7926     38.924      1.202      0.230     -29.718     123.303
# x1            21.3212     18.414      1.158      0.248     -14.874      57.517
# ==============================================================================
# Omnibus:                       81.101   Durbin-Watson:                   2.127
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              224.081
# Skew:                          -0.917   Prob(JB):                     2.20e-49
# Kurtosis:                       6.073   Cond. No.                         2.13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Bateos_pitcher_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     2.088
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.149
# Time:                        15:40:09   Log-Likelihood:                -3446.7
# No. Observations:                 425   AIC:                             6897.
# Df Residuals:                     423   BIC:                             6906.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         25.3349     39.473      0.642      0.521     -52.253     102.923
# x1            -0.5931      0.410     -1.445      0.149      -1.400       0.214
# ==============================================================================
# Omnibus:                       91.382   Durbin-Watson:                   2.225
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              272.312
# Skew:                          -0.994   Prob(JB):                     7.38e-60
# Kurtosis:                       6.380   Cond. No.                         97.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Carreras_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     4.968
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):             0.0263
# Time:                        15:40:11   Log-Likelihood:                -3436.9
# No. Observations:                 424   AIC:                             6878.
# Df Residuals:                     422   BIC:                             6886.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         23.2814     39.388      0.591      0.555     -54.140     100.703
# x1            -1.8748      0.841     -2.229      0.026      -3.528      -0.221
# ==============================================================================
# Omnibus:                       93.492   Durbin-Watson:                   2.183
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              287.463
# Skew:                          -1.008   Prob(JB):                     3.79e-63
# Kurtosis:                       6.494   Cond. No.                         47.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Carreras_ganadas_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     3.686
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):             0.0555
# Time:                        15:40:12   Log-Likelihood:                -3437.5
# No. Observations:                 424   AIC:                             6879.
# Df Residuals:                     422   BIC:                             6887.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         26.7327     39.331      0.680      0.497     -50.576     104.041
# x1            -1.7385      0.905     -1.920      0.056      -3.518       0.041
# ==============================================================================
# Omnibus:                       88.662   Durbin-Watson:                   2.187
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              262.573
# Skew:                          -0.968   Prob(JB):                     9.61e-58
# Kurtosis:                       6.334   Cond. No.                         43.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Comando_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     5.083
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):             0.0247
# Time:                        15:40:14   Log-Likelihood:                -3429.2
# No. Observations:                 423   AIC:                             6862.
# Df Residuals:                     421   BIC:                             6871.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         33.0130     39.131      0.844      0.399     -43.904     109.930
# x1            27.5163     12.205      2.255      0.025       3.527      51.506
# ==============================================================================
# Omnibus:                       91.085   Durbin-Watson:                   2.161
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              269.062
# Skew:                          -0.998   Prob(JB):                     3.75e-59
# Kurtosis:                       6.359   Cond. No.                         3.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Control_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                  0.001102
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.974
# Time:                        15:40:16   Log-Likelihood:                -3439.4
# No. Observations:                 424   AIC:                             6883.
# Df Residuals:                     422   BIC:                             6891.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         35.2292     39.781      0.886      0.376     -42.965     113.424
# x1            37.8890   1141.200      0.033      0.974   -2205.256    2281.034
# ==============================================================================
# Omnibus:                       90.998   Durbin-Watson:                   2.174
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              266.635
# Skew:                          -0.998   Prob(JB):                     1.26e-58
# Kurtosis:                       6.333   Cond. No.                         29.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Dominio_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.8938
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.345
# Time:                        15:40:18   Log-Likelihood:                -3447.3
# No. Observations:                 425   AIC:                             6899.
# Df Residuals:                     423   BIC:                             6907.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         39.5173     39.861      0.991      0.322     -38.834     117.868
# x1           378.5771    400.441      0.945      0.345    -408.525    1165.679
# ==============================================================================
# Omnibus:                       89.508   Durbin-Watson:                   2.224
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              261.761
# Skew:                          -0.980   Prob(JB):                     1.44e-57
# Kurtosis:                       6.308   Cond. No.                         10.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ERA_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.2267
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.634
# Time:                        15:40:20   Log-Likelihood:                -3439.3
# No. Observations:                 424   AIC:                             6883.
# Df Residuals:                     422   BIC:                             6891.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         28.8441     41.339      0.698      0.486     -52.412     110.100
# x1            -5.9539     12.505     -0.476      0.634     -30.535      18.627
# ==============================================================================
# Omnibus:                       90.664   Durbin-Watson:                   2.170
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              264.106
# Skew:                          -0.996   Prob(JB):                     4.47e-58
# Kurtosis:                       6.314   Cond. No.                         3.52
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Inning_pitched_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.6979
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.404
# Time:                        15:40:22   Log-Likelihood:                -3447.4
# No. Observations:                 425   AIC:                             6899.
# Df Residuals:                     423   BIC:                             6907.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         27.6104     39.675      0.696      0.487     -50.375     105.596
# x1            -0.3297      0.395     -0.835      0.404      -1.106       0.446
# ==============================================================================
# Omnibus:                       88.923   Durbin-Watson:                   2.226
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              258.593
# Skew:                          -0.976   Prob(JB):                     7.03e-57
# Kurtosis:                       6.286   Cond. No.                         102.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Juegos_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.2908
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.590
# Time:                        15:40:23   Log-Likelihood:                -3447.6
# No. Observations:                 425   AIC:                             6899.
# Df Residuals:                     423   BIC:                             6907.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         29.1445     39.772      0.733      0.464     -49.030     107.319
# x1            -0.5487      1.018     -0.539      0.590      -2.549       1.451
# ==============================================================================
# Omnibus:                       90.448   Durbin-Watson:                   2.227
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              263.819
# Skew:                          -0.991   Prob(JB):                     5.16e-58
# Kurtosis:                       6.312   Cond. No.                         39.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Juegos_iniciados_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                   0.09912
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.753
# Time:                        15:40:25   Log-Likelihood:                -2148.0
# No. Observations:                 263   AIC:                             4300.
# Df Residuals:                     261   BIC:                             4307.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         43.4265     53.016      0.819      0.413     -60.967     147.820
# x1            -0.7768      2.467     -0.315      0.753      -5.635       4.081
# ==============================================================================
# Omnibus:                       53.409   Durbin-Watson:                   2.227
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              135.048
# Skew:                          -0.930   Prob(JB):                     4.73e-30
# Kurtosis:                       5.977   Cond. No.                         21.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Losses_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                   0.01522
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.902
# Time:                        15:40:26   Log-Likelihood:                -3412.0
# No. Observations:                 421   AIC:                             6828.
# Df Residuals:                     419   BIC:                             6836.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         31.2783     39.311      0.796      0.427     -45.993     108.550
# x1             0.8316      6.742      0.123      0.902     -12.420      14.084
# ==============================================================================
# Omnibus:                       96.054   Durbin-Watson:                   2.194
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              280.172
# Skew:                          -1.062   Prob(JB):                     1.45e-61
# Kurtosis:                       6.385   Cond. No.                         5.86
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Saves_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.2416
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.624
# Time:                        15:40:27   Log-Likelihood:                -1815.3
# No. Observations:                 226   AIC:                             3635.
# Df Residuals:                     224   BIC:                             3641.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         37.5158     50.192      0.747      0.456     -61.394     136.425
# x1            -1.9891      4.047     -0.491      0.624      -9.964       5.986
# ==============================================================================
# Omnibus:                       56.822   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              181.835
# Skew:                          -1.026   Prob(JB):                     3.27e-40
# Kurtosis:                       6.886   Cond. No.                         12.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# TVS_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     4.513
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):             0.0343
# Time:                        15:40:29   Log-Likelihood:                -3223.3
# No. Observations:                 399   AIC:                             6451.
# Df Residuals:                     397   BIC:                             6458.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         35.4236     39.327      0.901      0.368     -41.893     112.740
# x1             2.1139      0.995      2.124      0.034       0.158       4.070
# ==============================================================================
# Omnibus:                       82.427   Durbin-Watson:                   2.094
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              233.164
# Skew:                          -0.966   Prob(JB):                     2.34e-51
# Kurtosis:                       6.209   Cond. No.                         39.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# WAR_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     3.757
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):             0.0532
# Time:                        15:40:31   Log-Likelihood:                -3445.9
# No. Observations:                 425   AIC:                             6896.
# Df Residuals:                     423   BIC:                             6904.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         24.1255     39.316      0.614      0.540     -53.154     101.405
# x1            45.0385     23.236      1.938      0.053      -0.633      90.710
# ==============================================================================
# Omnibus:                       91.162   Durbin-Watson:                   2.224
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              267.850
# Skew:                          -0.996   Prob(JB):                     6.87e-59
# Kurtosis:                       6.340   Cond. No.                         1.71
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# WHIP_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     2.148
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.144
# Time:                        15:40:32   Log-Likelihood:                -3446.7
# No. Observations:                 425   AIC:                             6897.
# Df Residuals:                     423   BIC:                             6905.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          5.0051     43.458      0.115      0.908     -80.416      90.427
# x1           -62.5062     42.649     -1.466      0.144    -146.337      21.324
# ==============================================================================
# Omnibus:                       90.140   Durbin-Watson:                   2.212
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              260.152
# Skew:                          -0.992   Prob(JB):                     3.23e-57
# Kurtosis:                       6.280   Cond. No.                         1.59
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Walks_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.2268
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.634
# Time:                        15:40:34   Log-Likelihood:                -3439.3
# No. Observations:                 424   AIC:                             6883.
# Df Residuals:                     422   BIC:                             6891.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         33.2403     39.430      0.843      0.400     -44.264     110.744
# x1            -0.6048      1.270     -0.476      0.634      -3.101       1.891
# ==============================================================================
# Omnibus:                       91.067   Durbin-Watson:                   2.177
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              267.371
# Skew:                          -0.998   Prob(JB):                     8.73e-59
# Kurtosis:                       6.339   Cond. No.                         31.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Wins_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.4052
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.525
# Time:                        15:40:36   Log-Likelihood:                -3399.8
# No. Observations:                 420   AIC:                             6804.
# Df Residuals:                     418   BIC:                             6812.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         41.6996     38.802      1.075      0.283     -34.572     117.971
# x1             3.8082      5.983      0.637      0.525      -7.951      15.568
# ==============================================================================
# Omnibus:                       80.844   Durbin-Watson:                   2.125
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              225.218
# Skew:                          -0.911   Prob(JB):                     1.24e-49
# Kurtosis:                       6.090   Cond. No.                         6.49
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Hitters
#
# Hagamos lo mismo para los *hitters*.

# %%
hitter_statistics = ['At-bats', 'Bateos', 'Home-runs', 'Juegos',
                     'OPS', 'Porcentaje_bateo', 'Porcetnaje_juegos',
                     'RBI', 'TVS', 'WAR', 'At-bats_2', 'Bateos_2',
                     'Home-runs_2', 'Juegos_2', 'OPS_2',
                     'Porcentaje_bateo_2', 'Porcetnaje_juegos_2',
                     'RBI_2', 'TVS_2', 'WAR_2']
Y_hitter_raw = 'Sueldo'
hitter_Statistics_len = len(hitter_statistics)
hitter_model = [None]*hitter_Statistics_len
df_hitter_model = [None]*hitter_Statistics_len

# %%
for statistic in range(0,hitter_Statistics_len):
    df_hitter_model[statistic], hitter_model[statistic] = etl_regression(hitter_statistics[statistic], Y_raw, df_hitters_copy)
    
    print(colored(hitter_statistics[statistic], "cyan"))
    print(hitter_model[statistic].summary())
    print('\n')
# Out:
# At-bats
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9097
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.341
# Time:                        15:40:38   Log-Likelihood:                -4042.2
# No. Observations:                 492   AIC:                             8088.
# Df Residuals:                     490   BIC:                             8097.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -41.2872     40.874     -1.010      0.313    -121.598      39.024
# x1            -2.6301      2.758     -0.954      0.341      -8.048       2.788
# ==============================================================================
# Omnibus:                      145.091   Durbin-Watson:                   2.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              504.233
# Skew:                          -1.333   Prob(JB):                    3.21e-110
# Kurtosis:                       7.183   Cond. No.                         15.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Bateos
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.1463
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.702
# Time:                        15:40:40   Log-Likelihood:                -3881.9
# No. Observations:                 472   AIC:                             7768.
# Df Residuals:                     470   BIC:                             7776.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -52.7315     42.090     -1.253      0.211    -135.439      29.976
# x1            -2.1133      5.526     -0.382      0.702     -12.971       8.745
# ==============================================================================
# Omnibus:                      137.728   Durbin-Watson:                   2.139
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              471.197
# Skew:                          -1.318   Prob(JB):                    4.80e-103
# Kurtosis:                       7.124   Cond. No.                         7.70
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Home-runs
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.7244
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.395
# Time:                        15:40:42   Log-Likelihood:                -2972.1
# No. Observations:                 361   AIC:                             5948.
# Df Residuals:                     359   BIC:                             5956.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -105.8650     48.179     -2.197      0.029    -200.613     -11.117
# x1           -12.7203     14.946     -0.851      0.395     -42.113      16.672
# ==============================================================================
# Omnibus:                      114.411   Durbin-Watson:                   2.093
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              403.021
# Skew:                          -1.384   Prob(JB):                     3.06e-88
# Kurtosis:                       7.375   Cond. No.                         3.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Juegos
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.7836
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.376
# Time:                        15:40:44   Log-Likelihood:                -4042.2
# No. Observations:                 492   AIC:                             8088.
# Df Residuals:                     490   BIC:                             8097.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -44.8237     41.766     -1.073      0.284    -126.887      37.239
# x1            -4.3695      4.936     -0.885      0.376     -14.068       5.329
# ==============================================================================
# Omnibus:                      145.786   Durbin-Watson:                   2.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              507.755
# Skew:                          -1.339   Prob(JB):                    5.52e-111
# Kurtosis:                       7.195   Cond. No.                         8.75
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# OPS
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.035
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.154
# Time:                        15:40:46   Log-Likelihood:                -3945.2
# No. Observations:                 480   AIC:                             7894.
# Df Residuals:                     478   BIC:                             7903.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -32.2628     41.836     -0.771      0.441    -114.468      49.942
# x1            79.9003     56.005      1.427      0.154     -30.147     189.947
# ==============================================================================
# Omnibus:                      138.434   Durbin-Watson:                   2.208
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              480.172
# Skew:                          -1.299   Prob(JB):                    5.39e-105
# Kurtosis:                       7.155   Cond. No.                         1.42
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Porcentaje_bateo
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                  0.009831
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.921
# Time:                        15:40:48   Log-Likelihood:                -3882.0
# No. Observations:                 472   AIC:                             7768.
# Df Residuals:                     470   BIC:                             7776.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -49.7748     42.112     -1.182      0.238    -132.527      32.977
# x1             9.3271     94.072      0.099      0.921    -175.526     194.180
# ==============================================================================
# Omnibus:                      137.953   Durbin-Watson:                   2.136
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              474.146
# Skew:                          -1.319   Prob(JB):                    1.10e-103
# Kurtosis:                       7.142   Cond. No.                         2.27
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Porcetnaje_juegos
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.1841
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.668
# Time:                        15:40:51   Log-Likelihood:                -4042.5
# No. Observations:                 492   AIC:                             8089.
# Df Residuals:                     490   BIC:                             8097.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -38.6732     41.102     -0.941      0.347    -119.431      42.085
# x1           -25.2787     58.921     -0.429      0.668    -141.048      90.490
# ==============================================================================
# Omnibus:                      145.503   Durbin-Watson:                   2.071
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              509.943
# Skew:                          -1.333   Prob(JB):                    1.85e-111
# Kurtosis:                       7.215   Cond. No.                         1.50
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# RBI
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.7301
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.393
# Time:                        15:40:52   Log-Likelihood:                -3609.8
# No. Observations:                 438   AIC:                             7224.
# Df Residuals:                     436   BIC:                             7232.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -61.8647     44.203     -1.400      0.162    -148.743      25.014
# x1            -6.7098      7.853     -0.854      0.393     -22.143       8.724
# ==============================================================================
# Omnibus:                      126.663   Durbin-Watson:                   2.248
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              425.852
# Skew:                          -1.302   Prob(JB):                     3.37e-93
# Kurtosis:                       7.069   Cond. No.                         5.66
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# TVS
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.768
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.184
# Time:                        15:40:54   Log-Likelihood:                -3799.7
# No. Observations:                 462   AIC:                             7603.
# Df Residuals:                     460   BIC:                             7612.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -38.0133     42.164     -0.902      0.368    -120.871      44.844
# x1            10.5766      7.955      1.330      0.184      -5.056      26.209
# ==============================================================================
# Omnibus:                      132.096   Durbin-Watson:                   2.220
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              441.582
# Skew:                          -1.296   Prob(JB):                     1.29e-96
# Kurtosis:                       7.027   Cond. No.                         5.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# WAR
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     2.867
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):             0.0911
# Time:                        15:40:57   Log-Likelihood:                -3886.4
# No. Observations:                 474   AIC:                             7777.
# Df Residuals:                     472   BIC:                             7785.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -30.8502     41.391     -0.745      0.456    -112.184      50.483
# x1            58.2981     34.430      1.693      0.091      -9.356     125.953
# ==============================================================================
# Omnibus:                      136.883   Durbin-Watson:                   2.308
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              488.521
# Skew:                          -1.288   Prob(JB):                    8.30e-107
# Kurtosis:                       7.255   Cond. No.                         1.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# At-bats_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     2.439
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.119
# Time:                        15:40:59   Log-Likelihood:                -4041.4
# No. Observations:                 492   AIC:                             8087.
# Df Residuals:                     490   BIC:                             8095.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -40.4182     40.490     -0.998      0.319    -119.973      39.136
# x1            -0.2083      0.133     -1.562      0.119      -0.470       0.054
# ==============================================================================
# Omnibus:                      144.285   Durbin-Watson:                   2.070
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              496.431
# Skew:                          -1.329   Prob(JB):                    1.59e-108
# Kurtosis:                       7.142   Cond. No.                         304.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Bateos_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.7022
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.402
# Time:                        15:41:01   Log-Likelihood:                -3881.7
# No. Observations:                 472   AIC:                             7767.
# Df Residuals:                     470   BIC:                             7776.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -52.8928     41.726     -1.268      0.206    -134.884      29.099
# x1            -0.4285      0.511     -0.838      0.402      -1.433       0.576
# ==============================================================================
# Omnibus:                      137.267   Durbin-Watson:                   2.140
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              467.394
# Skew:                          -1.315   Prob(JB):                    3.21e-102
# Kurtosis:                       7.104   Cond. No.                         81.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Home-runs_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.612
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.205
# Time:                        15:41:02   Log-Likelihood:                -2971.7
# No. Observations:                 361   AIC:                             5947.
# Df Residuals:                     359   BIC:                             5955.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -101.5876     48.012     -2.116      0.035    -196.008      -7.167
# x1            -4.2919      3.380     -1.270      0.205     -10.939       2.356
# ==============================================================================
# Omnibus:                      114.692   Durbin-Watson:                   2.102
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              403.684
# Skew:                          -1.388   Prob(JB):                     2.19e-88
# Kurtosis:                       7.375   Cond. No.                         14.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Juegos_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.694
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.194
# Time:                        15:41:04   Log-Likelihood:                -4041.8
# No. Observations:                 492   AIC:                             8088.
# Df Residuals:                     490   BIC:                             8096.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -43.6199     40.871     -1.067      0.286    -123.924      36.685
# x1            -0.6035      0.464     -1.301      0.194      -1.515       0.308
# ==============================================================================
# Omnibus:                      145.086   Durbin-Watson:                   2.072
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              500.643
# Skew:                          -1.335   Prob(JB):                    1.94e-109
# Kurtosis:                       7.158   Cond. No.                         89.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# OPS_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.193
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.139
# Time:                        15:41:07   Log-Likelihood:                -3945.1
# No. Observations:                 480   AIC:                             7894.
# Df Residuals:                     478   BIC:                             7903.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -36.0374     41.384     -0.871      0.384    -117.354      45.280
# x1            96.6877     65.287      1.481      0.139     -31.597     224.972
# ==============================================================================
# Omnibus:                      138.134   Durbin-Watson:                   2.207
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              479.144
# Skew:                          -1.296   Prob(JB):                    9.02e-105
# Kurtosis:                       7.152   Cond. No.                         1.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Porcentaje_bateo_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                  0.009940
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.921
# Time:                        15:41:09   Log-Likelihood:                -3882.0
# No. Observations:                 472   AIC:                             7768.
# Df Residuals:                     470   BIC:                             7776.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -50.1102     41.745     -1.200      0.231    -132.141      31.920
# x1            18.1035    181.582      0.100      0.921    -338.710     374.917
# ==============================================================================
# Omnibus:                      137.928   Durbin-Watson:                   2.136
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              473.990
# Skew:                          -1.318   Prob(JB):                    1.19e-103
# Kurtosis:                       7.141   Cond. No.                         4.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Porcetnaje_juegos_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.5644
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.453
# Time:                        15:41:11   Log-Likelihood:                -4042.3
# No. Observations:                 492   AIC:                             8089.
# Df Residuals:                     490   BIC:                             8097.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -38.2162     40.600     -0.941      0.347    -117.988      41.556
# x1           -52.3284     69.653     -0.751      0.453    -189.185      84.528
# ==============================================================================
# Omnibus:                      145.341   Durbin-Watson:                   2.068
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              508.034
# Skew:                          -1.333   Prob(JB):                    4.81e-111
# Kurtosis:                       7.204   Cond. No.                         1.73
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# RBI_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.718
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.191
# Time:                        15:41:13   Log-Likelihood:                -3609.3
# No. Observations:                 438   AIC:                             7223.
# Df Residuals:                     436   BIC:                             7231.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -58.3859     43.930     -1.329      0.185    -144.728      27.956
# x1            -1.2822      0.978     -1.311      0.191      -3.205       0.640
# ==============================================================================
# Omnibus:                      126.440   Durbin-Watson:                   2.249
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              424.392
# Skew:                          -1.300   Prob(JB):                     6.99e-93
# Kurtosis:                       7.061   Cond. No.                         44.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# TVS_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     3.375
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):             0.0668
# Time:                        15:41:14   Log-Likelihood:                -3798.9
# No. Observations:                 462   AIC:                             7602.
# Df Residuals:                     460   BIC:                             7610.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -48.5026     42.683     -1.136      0.256    -132.380      35.375
# x1             1.9685      1.071      1.837      0.067      -0.137       4.074
# ==============================================================================
# Omnibus:                      131.884   Durbin-Watson:                   2.215
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              439.499
# Skew:                          -1.295   Prob(JB):                     3.66e-96
# Kurtosis:                       7.015   Cond. No.                         40.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# WAR_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     2.584
# Date:                Sat, 08 Oct 2022   Prob (F-statistic):              0.109
# Time:                        15:41:17   Log-Likelihood:                -3994.6
# No. Observations:                 486   AIC:                             7993.
# Df Residuals:                     484   BIC:                             8002.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -50.2840     41.627     -1.208      0.228    -132.076      31.508
# x1            31.2822     19.460      1.608      0.109      -6.954      69.518
# ==============================================================================
# Omnibus:                      140.947   Durbin-Watson:                   2.318
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              482.961
# Skew:                          -1.313   Prob(JB):                    1.34e-105
# Kurtosis:                       7.118   Cond. No.                         2.20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
