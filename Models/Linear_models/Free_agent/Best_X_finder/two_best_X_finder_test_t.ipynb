# %% [markdown]
# # Best X finder - Test for one period
#
# Veremos cómo funciona el algoritmo en un script distinto puesto que podría haber variables inicializadas en los test del script *two_best_X_finder.ipynb*

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from matplotlib.colors import ListedColormap
from termcolor import colored
from sklearn.naive_bayes import GaussianNB
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
import pandas as pd
import numpy as np
import array
import math
import os
import warnings
print('Modulos importados')
# Out:
# Modulos importados

# %%
# Configuraciones
warnings.filterwarnings('ignore')
# Reduzcamos el número de línea a leer
pd.options.display.max_rows = 15

# %%
# Veamos el directorio actual de trabajo
print(os.getcwd())
# El directorio anterior es el correcto, pero si no lo fuese, hacemos lo sigueinte:
path = '/home/usuario/Documentos/Github/Proyectos/MLB_HN'
os.chdir(path)
# Out:
# /home/usuario/Documentos/Github/Proyectos/MLB_HN/Models/Linear_models/Free_agent/Best_X_finder

# %%
print("Para modificar el tamaño de todos los gráficos")
from matplotlib import rcParams
rcParams['figure.figsize'] = 15,9
# Out:
# Para modificar el tamaño de todos los gráficos

# %%
# Veamos el directorio actual de trabajo
print(os.getcwd())
# El directorio anterior es el correcto, pero si no lo fuese, hacemos lo sigueinte:
path = '/home/usuario/Documentos/Github/Proyectos/MLB_HN'
print("Nuevo directorio de trabajo: " + str(os.chdir(path)))
# Out:
# /home/usuario/Documentos/Github/Proyectos/MLB_HN
# Nuevo directorio de trabajo: None

# %% [markdown]
# ## Exploración de datos
#
# Estudiaremos de manera general si hay datos faltantes, así como el tipo de datos que contiene

# %%
# Años de análisis
starting_year_t = 2011
period = 11
csv = '.csv'
# Directorios
pitchers_path_t = 'ETL_data/Period_t/Free_Agent/Pitchers/free_agents_pitchers_'
hitters_path_t = 'ETL_data/Period_t/Free_Agent/Hitters/free_agents_batters_'
# Originales:
df_pitchers_t = [None]*period
df_pitchers_t_copy = [None]*period
df_hitters_t = [None]*period
df_hitters_t_copy = [None]*period

# %% [markdown]
# Leamos todos las bases de datos correspondientes

# %%
for year in range(0,period):
    df_pitchers_t[year] = pd.read_csv(pitchers_path_t + str(starting_year_t + year) + csv)
    df_pitchers_t_copy[year] = df_pitchers_t[year].copy()
    
    df_hitters_t[year] = pd.read_csv(hitters_path_t + str(starting_year_t + year) + csv)
    df_hitters_t_copy[year] = df_hitters_t[year].copy()

# %% [markdown]
# Observemos el contenido de las bases de datos

# %%
# Pitchers
df_pitchers_t_copy[5].head()
# Out:
#   Acronimo  Altura  Anio_x  Anio_y  Anios_contrato  Bateos_pitcher  \
# 0      TEX     6.5    2016       6               1             116
# 1      CIN     6.6    2016       6               1              89
# 2      DET     6.0    2013       6               5             171
# 3      MIL     6.3    2016       6               1              80
# 4      CIN     6.5    2016       6               1              72
#
#    Bateos_pitcher_2  Cantidad de equipos  Cantidad_agentes_libres  Carreras  \
# 0             13456                    2                       10        68
# 1              7921                    2                        8        64
# 2             29241                    1                       11       108
# 3              6400                    1                        8        30
# 4              5184                    2                        8        38
#
#    ...  WHIP  WHIP_2  WS ganadas  Walks  Walks_2  Wins  Wins_2  ln_Sueldo  \
# 0  ...  1.36  1.8496           0     46     2116     7      49  13.137252
# 1  ...  2.05  4.2025           5     31      961     2       4  14.508658
# 2  ...  1.46  2.1316           4     53     2809     7      49  16.636889
# 3  ...  1.47  2.1609           0     17      289     2       4  13.764217
# 4  ...  1.44  2.0736           5     38     1444     6      36  13.304685
#
#    ln_Sueldo_base  ln_Sueldo_regular
# 0       13.137252          13.109548
# 1       14.508658          14.508658
# 2       16.588099          16.636889
# 3       13.764217          13.764217
# 4       13.304685          13.304685
#
# [5 rows x 66 columns]

# %%
list(enumerate(df_pitchers_t_copy[5].columns))
# Out:
# [(0, 'Acronimo'),
#  (1, 'Altura'),
#  (2, 'Anio_x'),
#  (3, 'Anio_y'),
#  (4, 'Anios_contrato'),
#  (5, 'Bateos_pitcher'),
#  (6, 'Bateos_pitcher_2'),
#  (7, 'Cantidad de equipos'),
#  (8, 'Cantidad_agentes_libres'),
#  (9, 'Carreras'),
#  (10, 'Carreras_2'),
#  (11, 'Carreras_ganadas'),
#  (12, 'Carreras_ganadas_2'),
#  (13, 'Comando'),
#  (14, 'Comando_2'),
#  (15, 'Control'),
#  (16, 'Control_2'),
#  (17, 'Dominio'),
#  (18, 'Dominio_2'),
#  (19, 'ERA'),
#  (20, 'ERA_2'),
#  (21, 'Edad'),
#  (22, 'Equipo'),
#  (23, 'Equipo_anterior'),
#  (24, 'Estado'),
#  (25, 'Inning_pitched'),
#  (26, 'Inning_pitched_2'),
#  (27, 'Juegos'),
#  (28, 'Juegos totales'),
#  (29, 'Juegos_2'),
#  (30, 'Juegos_iniciados'),
#  (31, 'Juegos_iniciados_2'),
#  (32, 'Jugador'),
#  (33, 'Losses'),
#  (34, 'Losses_2'),
#  (35, 'Pennants won'),
#  (36, 'Peso'),
#  (37, 'Playoffs'),
#  (38, 'Posicion'),
#  (39, 'Promedio_victorias'),
#  (40, 'Saves'),
#  (41, 'Saves_2'),
#  (42, 'Status'),
#  (43, 'Strike-outs'),
#  (44, 'Strike-outs_2'),
#  (45, 'Sueldo'),
#  (46, 'Sueldo_base'),
#  (47, 'Sueldo_regular'),
#  (48, 'TVS'),
#  (49, 'TVS_2'),
#  (50, 'Valor_contrato'),
#  (51, 'Valor_contrato_total'),
#  (52, 'Valor_promedio_contrato'),
#  (53, 'Victorias'),
#  (54, 'WAR'),
#  (55, 'WAR_2'),
#  (56, 'WHIP'),
#  (57, 'WHIP_2'),
#  (58, 'WS ganadas'),
#  (59, 'Walks'),
#  (60, 'Walks_2'),
#  (61, 'Wins'),
#  (62, 'Wins_2'),
#  (63, 'ln_Sueldo'),
#  (64, 'ln_Sueldo_base'),
#  (65, 'ln_Sueldo_regular')]

# %%
# Hitters
df_hitters_t_copy[5].head()
# Out:
#   Acronimo  Altura  Anio_x  Anio_y  Anios_contrato  At-bats  At-bats_2  \
# 0      TEX     6.5    2016       6               1        2          4
# 1      ATL     6.3    2016       6               1      247      61009
# 2      LAA     6.3    2012       6              10      593     351649
# 3      NYM     6.0    2016       6               1      234      54756
# 4       KC     6.1    2016       6               4      445     198025
#
#    Bateos  Bateos_2  Cantidad de equipos  ...  Valor_contrato  \
# 0       0         0                    2  ...          507500
# 1      55      3025                    1  ...         3000000
# 2     159     25281                    5  ...       240000000
# 3      48      2304                    2  ...         5750000
# 4      98      9604                    2  ...        72000000
#
#    Valor_contrato_total Valor_promedio_contrato Victorias   WAR   WAR_2  \
# 0              20165000                  507500        95  0.93  0.8649
# 1              19157500                 3000000        67 -1.28  1.6384
# 2              12525000                24000000        73  1.29  1.6641
# 3              48757500                 5750000        87 -0.38  0.1444
# 4             186750000                18000000        81  0.91  0.8281
#
#    WS ganadas  ln_Sueldo  ln_Sueldo_base  ln_Sueldo_regular
# 0           0  13.137252       13.137252          13.109548
# 1           3  14.930652       14.508658          14.930652
# 2           1  17.034386       17.034386          17.034386
# 3           2  15.564710       15.564710          15.564710
# 4           2  16.300417       16.300417          16.300417
#
# [5 rows x 50 columns]

# %% [markdown]
# Veamos las columnas con sus índices

# %%
list(enumerate(df_hitters_t_copy[5].columns))
# Out:
# [(0, 'Acronimo'),
#  (1, 'Altura'),
#  (2, 'Anio_x'),
#  (3, 'Anio_y'),
#  (4, 'Anios_contrato'),
#  (5, 'At-bats'),
#  (6, 'At-bats_2'),
#  (7, 'Bateos'),
#  (8, 'Bateos_2'),
#  (9, 'Cantidad de equipos'),
#  (10, 'Cantidad_agentes_libres'),
#  (11, 'Edad'),
#  (12, 'Equipo'),
#  (13, 'Equipo_anterior'),
#  (14, 'Estado'),
#  (15, 'Home-runs'),
#  (16, 'Home-runs_2'),
#  (17, 'Juegos'),
#  (18, 'Juegos totales'),
#  (19, 'Juegos_2'),
#  (20, 'Jugador'),
#  (21, 'OPS'),
#  (22, 'OPS_2'),
#  (23, 'Pennants won'),
#  (24, 'Peso'),
#  (25, 'Playoffs'),
#  (26, 'Porcentaje_bateo'),
#  (27, 'Porcentaje_bateo_2'),
#  (28, 'Porcetnaje_juegos'),
#  (29, 'Porcetnaje_juegos_2'),
#  (30, 'Posicion'),
#  (31, 'Promedio_victorias'),
#  (32, 'RBI'),
#  (33, 'RBI_2'),
#  (34, 'Status'),
#  (35, 'Sueldo'),
#  (36, 'Sueldo_base'),
#  (37, 'Sueldo_regular'),
#  (38, 'TVS'),
#  (39, 'TVS_2'),
#  (40, 'Valor_contrato'),
#  (41, 'Valor_contrato_total'),
#  (42, 'Valor_promedio_contrato'),
#  (43, 'Victorias'),
#  (44, 'WAR'),
#  (45, 'WAR_2'),
#  (46, 'WS ganadas'),
#  (47, 'ln_Sueldo'),
#  (48, 'ln_Sueldo_base'),
#  (49, 'ln_Sueldo_regular')]

# %% [markdown]
# Veamos si hay bases de datos con variables que distintas entre sí

# %% [markdown]
# ## Test

# %%
def etl_regression(X_raw, Y_raw, df_copy):
    # Creación de la base de datos a transformar las variables de la regresión
    jugador = 'Jugador'
    YX_raw = [None]*period
    
    for year in range(0, period):
        YX_raw[year] = df_copy[year][[jugador, Y_raw, X_raw]]

    # Ajuste de inflación en los salarios    
    change_inflation_percentage = {2011:20.46, 2012:18.02, 2013:16.32, 2014:14.46,
                                   2015:14.33, 2016:12.90, 2017:10.55, 2018:7.86,
                                   2019:5.99, 2020:4.70, 2021:1}
    for year in range(0, period):
        YX_raw[year][[Y_raw]] = YX_raw[year][[Y_raw]]*(1 + change_inflation_percentage[2011 + year]*0.01)
        YX_raw[year].rename(columns = {Y_raw: Y_raw + '_' + str(2011 + year)}, inplace = True)
        YX_raw[year].rename(columns = {X_raw: X_raw + '_' + str(2011 + year)}, inplace = True)

    # Filtrado de base de datos
    YX_panel_raw = pd.merge(YX_raw[0], YX_raw[1], how = 'outer', on = 'Jugador')

    for year in range(2,period):
        YX_panel_raw = pd.merge(YX_panel_raw, YX_raw[year], how = 'outer', on = 'Jugador')

    YX_panel_raw.drop_duplicates(subset = 'Jugador', inplace = True)
    YX_panel_raw = YX_panel_raw.sort_values(by = 'Jugador', ascending = True)
    YX_panel_raw.reset_index(drop = True, inplace = True)
    YX_panel_raw.sort_index(axis = 1, inplace = True)

    # Recolocación al principio de Jugador
    player_column = YX_panel_raw.pop('Jugador')
    YX_panel_raw.insert(0, 'Jugador', player_column)

    # Creación de base de datos auxiliares  para remover los NaN
    split_column = 1 + period
    max_nan = 2

    if Y_raw > X_raw:
        X_drop_etl = YX_panel_raw.iloc[:, 1:split_column]
    else:
        X_drop_etl = YX_panel_raw.iloc[:, split_column:YX_panel_raw.shape[1]]

    nulls_quantity = period - max_nan
    X_drop_etl = X_drop_etl.iloc[X_drop_etl[(X_drop_etl.isnull().sum(axis = 1) > nulls_quantity)].index]
    X_index_drop = X_drop_etl.index

    if Y_raw > X_raw:
        Y_drop_etl = YX_panel_raw.iloc[:, split_column:YX_panel_raw.shape[1]]
    else:
        Y_drop_etl = YX_panel_raw.iloc[:, 1:split_column]
    Y_drop_etl = Y_drop_etl.iloc[Y_drop_etl[(Y_drop_etl.isnull().sum(axis = 1) > nulls_quantity)].index]
    Y_index_drop = Y_drop_etl.index

    # índice de los jugadores que no tienen más de dos observaciones en el periodo de analisis
    index_drop = list(set(X_index_drop).union(set(Y_index_drop)))

    YX_panel_raw.drop(index = index_drop, inplace = True)
    YX_panel_raw.reset_index(drop = True, inplace = True)
    YX_panel_raw = YX_panel_raw.sort_values(by = 'Jugador', ascending = True)

    # Borremos provicionalmente a los jugadores cuyo estadística máxima es igual a 0
    if Y_raw > X_raw:
        YX_panel_raw[X_raw + '_max'] = YX_panel_raw.iloc[:, 1:split_column].max(axis = 1)
    else:
        YX_panel_raw[X_raw + '_max'] = YX_panel_raw.iloc[:, split_column:YX_panel_raw.shape[1]].max(axis = 1)
    YX_max_0 = YX_panel_raw[YX_panel_raw[X_raw + '_max'] == 0]
    YX_max_0_index_drop = YX_max_0.index
    YX_panel_raw.drop(columns = X_raw + '_max', inplace = True)
    YX_panel_raw.drop(index = YX_max_0_index_drop, inplace = True)
    YX_panel_raw.reset_index(drop = True, inplace = True)

    # Variable X
    if Y_raw > X_raw:
        X_etl = YX_panel_raw.iloc[:, 1:split_column]
    else:
        X_etl = YX_panel_raw.iloc[:, split_column:YX_panel_raw.shape[1]]
    max_element = X_etl.max(axis = 1)
    min_element = X_etl.min(axis = 1)
    max_min = (max_element + min_element)/2
    dummy_names = []
    X_names = []
    for year in range(0,period):
        dummy_names.append("I_" + str(2011 + year))
        X_names.append("X_" + str(2011 + year))
    for year in range(0,period):
        X_conditions = [
        (X_etl.iloc[:,year] == max_element) & ~(X_etl.iloc[:,year].isnull()),
        (X_etl.iloc[:,year] != max_element) & ~(X_etl.iloc[:,year].isnull())
        ]
        X_conditions_values = [0,1]
        X_etl[dummy_names[year]] = np.select(X_conditions, X_conditions_values, default = np.nan)
    X_aux = X_etl.iloc[:,:period]
    Dummy = X_etl.iloc[:,period:]
    X_max = X_aux.max(axis = 1)
    X_aux[['Max']] = np.sqrt(X_max)
    for year in range(0,period):    
        X_etl['X_' + str(2011 + year)] = \
        (X_aux[X_raw + '_' + str(2011 + year)]*
        ((-1)**Dummy['I_' + str(2011 + year)]))
    X_etl = X_etl.div(X_aux['Max'].values, axis = 0)
    X_etl = X_etl.iloc[:,2*period:]
    for i in range(0,X_etl.shape[0]):
        row = X_etl.iloc[i]
        row_length = row.size
        sustitute = []

        for j in range(row_length):
            if pd.isna(row[j]) != True:
                sustitute.append(row[j])

        sustitute_length = len(sustitute)

        for k in range(row_length - sustitute_length):
            sustitute.append(np.nan)

        for j in range(row_length):
            X_etl.iloc[i,j] = sustitute[j]

    X_etl.columns = ['X_1', 'X_2', 'X_3', 'X_4', 'X_5', 'X_6', 
                     'X_7', 'X_8', 'X_9', 'X_10', 'X_11']
    X_etl[['Jugador']] = YX_panel_raw[['Jugador']]
    X_player_column = X_etl.pop('Jugador')
    X_etl.insert(0, 'Jugador', X_player_column)

    # Variable Y
    if Y_raw > X_raw:
        Y_etl = YX_panel_raw.iloc[:, split_column:YX_panel_raw.shape[1]]
    else:
        Y_etl = YX_panel_raw.iloc[:, 1:split_column]
    for i in range(0,Y_etl.shape[0]):
        row = Y_etl.iloc[i]
        row_length = row.size
        sustitute = []

        for j in range(row_length):
            if pd.isna(row[j]) != True:
                sustitute.append(row[j])

        sustitute_length = len(sustitute)

        for k in range(row_length - sustitute_length):
            sustitute.append(np.nan)

        for j in range(row_length):
            Y_etl.iloc[i,j] = sustitute[j]

    Y_etl.columns = ['w_1', 'w_2', 'w_3', 'w_4', 'w_5', 'w_6', 
                     'w_7', 'w_8', 'w_9', 'w_10', 'w_11']
    Y_etl[['Jugador']] = YX_panel_raw[['Jugador']]
    Y_player_column = Y_etl.pop('Jugador')
    Y_etl.insert(0, 'Jugador', Y_player_column)
    Y_etl_copy = Y_etl.copy()
    y_etl_names = Y_etl_copy['Jugador']
    for i in range(0,len(y_etl_names)):
        row = Y_etl_copy.iloc[i]
        row_length = row.size
        k = 0

        sustitute = []

        for j in range(0, row_length):
            if pd.isna(row[j]) != True:
                k = k + 1

        sustitute.append(y_etl_names[i])
        for j in range(1,k - 1):
            sustitute.append(row[j + 1]**0.5 - row[j]**0.5)

        sustitute_length = len(sustitute)

        for k in range(row_length - sustitute_length):
            sustitute.append(np.nan)

        for j in range(row_length):
            Y_etl_copy.iloc[i,j] = sustitute[j]

    Y_etl_copy.columns = ['Jugador', 'Y_1', 'Y_2', 'Y_3', 'Y_4', 'Y_5', 'Y_6', 
                          'Y_7', 'Y_8', 'Y_9', 'Y_10', 'Y_11']
    Y_etl = Y_etl_copy

    # Base de datos
    regression_list = [None]*(period-1)
    for i in range(0,len(regression_list)):
        merge = pd.merge(Y_etl.iloc[:,[0,i+1]], X_etl.iloc[:,[0,i+1]])
        regression_list[i] = merge
        regression_list[i].columns = ['Jugador', 'Y', 'X']
    df_article_regression = regression_list[0]
    for i in range(1,len(regression_list)):
        df_article_regression = pd.concat([df_article_regression, regression_list[i]])
    df_article_regression = df_article_regression.sort_values(by = 'Jugador', ascending = True)
    df_article_regression.reset_index(drop = True, inplace = True)
    df_article_regression.dropna(inplace = True)
    df_article_regression.reset_index(drop = True, inplace = True)
    
    # Construimos la regresion
    Y = df_article_regression['Y'].tolist()
    X = df_article_regression['X'].tolist()
    X = sm.add_constant(X)
    model = sm.OLS(Y, X).fit()
    
    # Regresamos como argumento al modelo
    return [df_article_regression, model]

# %%
X_raw_pitcher_t = 'Inning_pitched'
Y_raw_t = 'Sueldo'
df_copy_t = df_pitchers_t_copy

# %%
df_regression_t, model_t = etl_regression(X_raw_pitcher_t, Y_raw_t, df_copy_t)

# %% [markdown]
# Veamos la base de datos ocupada para la regresión y después los datos sobre la regresión

# %%
df_regression_t
# Out:
#            Jugador           Y          X
# 0     A.J. Burnett -471.040165  14.618481
# 1     Aaron Harang  647.699528  13.405223
# 2     Aaron Harang -138.427417 -10.689863
# 3    Adam Ottavino -368.340054  -2.042177
# 4    Adam Ottavino  -18.852808  -7.398706
# ..             ...         ...        ...
# 420   Zack Greinke    6.483182 -13.528012
# 421   Zack Greinke  -75.049658 -13.113161
# 422   Zack Greinke  -64.819869 -10.286993
# 423   Zack Greinke  740.407614 -13.113161
# 424   Zack Greinke  754.087221  -11.51858
#
# [425 rows x 3 columns]

# %%
model_t.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.1909
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.662
# Time:                        11:24:58   Log-Likelihood:                -3447.7
# No. Observations:                 425   AIC:                             6899.
# Df Residuals:                     423   BIC:                             6907.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         27.9714     40.685      0.688      0.492     -51.999     107.941
# x1            -2.0278      4.641     -0.437      0.662     -11.150       7.094
# ==============================================================================
# Omnibus:                       89.562   Durbin-Watson:                   2.229
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              260.360
# Skew:                          -0.983   Prob(JB):                     2.91e-57
# Kurtosis:                       6.292   Cond. No.                         9.10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Vemos que el algoritmo funciona adecuadamente
#
# ## Pitchers
#
# Hagamos una prueba con una serie de estadísticas deportivas para cada grupo

# %%
pitcher_statistics_t = ['Bateos_pitcher', 'Carreras', 'Carreras_ganadas', 'Comando', 'Control',
                        'Dominio', 'ERA', 'Inning_pitched', 'Juegos', 'Juegos_iniciados', 
                        'Losses', 'Saves', 'TVS', 'WAR', 'WHIP', 'Walks', 'Wins', 
                        'Bateos_pitcher_2', 'Carreras_2', 'Carreras_ganadas_2', 'Comando_2', 'Control_2',
                        'Dominio_2', 'ERA_2', 'Inning_pitched_2', 'Juegos_2', 'Juegos_iniciados_2', 
                        'Losses_2', 'Saves_2', 'TVS_2', 'WAR_2', 'WHIP_2', 'Walks_2', 'Wins_2']
Y_pitcher_raw_t = 'ln_Sueldo'
pitcher_Statistics_len = len(pitcher_statistics_t)
pitcher_model_t = [None]*pitcher_Statistics_len
df_pitcher_model_t = [None]*pitcher_Statistics_len

# %%
for statistic in range(0,pitcher_Statistics_len):
    df_pitcher_model_t[statistic], pitcher_model_t[statistic] = etl_regression(pitcher_statistics_t[statistic],
                                                                               Y_pitcher_raw_t,
                                                                               df_pitchers_t_copy)
    
    print(colored(pitcher_statistics_t[statistic], "cyan"))
    print(pitcher_model_t[statistic].summary())
    print('\n')
# Out:
# Bateos_pitcher
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.368
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.243
# Time:                        11:25:01   Log-Likelihood:                 307.69
# No. Observations:                 425   AIC:                            -611.4
# Df Residuals:                     423   BIC:                            -603.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0377      0.006     -6.394      0.000      -0.049      -0.026
# x1            -0.0008      0.001     -1.170      0.243      -0.002       0.001
# ==============================================================================
# Omnibus:                       66.144   Durbin-Watson:                   2.258
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              210.407
# Skew:                          -0.695   Prob(JB):                     2.05e-46
# Kurtosis:                       6.154   Cond. No.                         8.78
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Carreras
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     5.571
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):             0.0187
# Time:                        11:25:02   Log-Likelihood:                 311.08
# No. Observations:                 424   AIC:                            -618.2
# Df Residuals:                     422   BIC:                            -610.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0393      0.006     -6.659      0.000      -0.051      -0.028
# x1            -0.0024      0.001     -2.360      0.019      -0.004      -0.000
# ==============================================================================
# Omnibus:                       66.581   Durbin-Watson:                   2.163
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              220.745
# Skew:                          -0.687   Prob(JB):                     1.16e-48
# Kurtosis:                       6.256   Cond. No.                         6.13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Carreras_ganadas
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     3.061
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):             0.0809
# Time:                        11:25:04   Log-Likelihood:                 309.83
# No. Observations:                 424   AIC:                            -615.7
# Df Residuals:                     422   BIC:                            -607.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0379      0.006     -6.469      0.000      -0.049      -0.026
# x1            -0.0018      0.001     -1.749      0.081      -0.004       0.000
# ==============================================================================
# Omnibus:                       65.108   Durbin-Watson:                   2.161
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              211.928
# Skew:                          -0.677   Prob(JB):                     9.56e-47
# Kurtosis:                       6.188   Cond. No.                         5.84
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Comando
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     5.483
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):             0.0197
# Time:                        11:25:06   Log-Likelihood:                 309.81
# No. Observations:                 423   AIC:                            -615.6
# Df Residuals:                     421   BIC:                            -607.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0332      0.006     -5.792      0.000      -0.045      -0.022
# x1             0.0083      0.004      2.342      0.020       0.001       0.015
# ==============================================================================
# Omnibus:                       71.623   Durbin-Watson:                   2.121
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              227.278
# Skew:                          -0.760   Prob(JB):                     4.44e-50
# Kurtosis:                       6.254   Cond. No.                         1.66
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Control
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.2756
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.600
# Time:                        11:25:08   Log-Likelihood:                 308.44
# No. Observations:                 424   AIC:                            -612.9
# Df Residuals:                     422   BIC:                            -604.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0364      0.006     -6.031      0.000      -0.048      -0.025
# x1            -0.0183      0.035     -0.525      0.600      -0.087       0.050
# ==============================================================================
# Omnibus:                       69.424   Durbin-Watson:                   2.150
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              224.358
# Skew:                          -0.728   Prob(JB):                     1.91e-49
# Kurtosis:                       6.253   Cond. No.                         6.13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Dominio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.307
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.254
# Time:                        11:25:10   Log-Likelihood:                 307.66
# No. Observations:                 425   AIC:                            -611.3
# Df Residuals:                     423   BIC:                            -603.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0341      0.006     -5.746      0.000      -0.046      -0.022
# x1             0.0222      0.019      1.143      0.254      -0.016       0.060
# ==============================================================================
# Omnibus:                       66.617   Durbin-Watson:                   2.256
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              210.760
# Skew:                          -0.702   Prob(JB):                     1.71e-46
# Kurtosis:                       6.151   Cond. No.                         3.43
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ERA
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.2317
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.630
# Time:                        11:25:12   Log-Likelihood:                 308.42
# No. Observations:                 424   AIC:                            -612.8
# Df Residuals:                     422   BIC:                            -604.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0370      0.007     -5.567      0.000      -0.050      -0.024
# x1            -0.0019      0.004     -0.481      0.630      -0.010       0.006
# ==============================================================================
# Omnibus:                       67.688   Durbin-Watson:                   2.145
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              219.281
# Skew:                          -0.707   Prob(JB):                     2.42e-48
# Kurtosis:                       6.226   Cond. No.                         2.18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Inning_pitched
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.4368
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.509
# Time:                        11:25:14   Log-Likelihood:                 307.23
# No. Observations:                 425   AIC:                            -610.5
# Df Residuals:                     423   BIC:                            -602.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0370      0.006     -6.246      0.000      -0.049      -0.025
# x1            -0.0004      0.001     -0.661      0.509      -0.002       0.001
# ==============================================================================
# Omnibus:                       65.752   Durbin-Watson:                   2.258
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              209.119
# Skew:                          -0.690   Prob(JB):                     3.89e-46
# Kurtosis:                       6.147   Cond. No.                         9.10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Juegos
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                  0.003282
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.954
# Time:                        11:25:16   Log-Likelihood:                 307.01
# No. Observations:                 425   AIC:                            -610.0
# Df Residuals:                     423   BIC:                            -601.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0358      0.006     -5.966      0.000      -0.048      -0.024
# x1          6.113e-05      0.001      0.057      0.954      -0.002       0.002
# ==============================================================================
# Omnibus:                       67.284   Durbin-Watson:                   2.263
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              211.713
# Skew:                          -0.711   Prob(JB):                     1.06e-46
# Kurtosis:                       6.152   Cond. No.                         5.94
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Juegos_iniciados
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                   0.04196
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.838
# Time:                        11:25:18   Log-Likelihood:                 189.77
# No. Observations:                 263   AIC:                            -375.5
# Df Residuals:                     261   BIC:                            -368.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0363      0.007     -4.900      0.000      -0.051      -0.022
# x1            -0.0004      0.002     -0.205      0.838      -0.004       0.003
# ==============================================================================
# Omnibus:                       43.077   Durbin-Watson:                   2.268
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              127.793
# Skew:                          -0.693   Prob(JB):                     1.78e-28
# Kurtosis:                       6.121   Cond. No.                         4.09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Losses
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.1563
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.693
# Time:                        11:25:20   Log-Likelihood:                 309.66
# No. Observations:                 421   AIC:                            -615.3
# Df Residuals:                     419   BIC:                            -607.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0358      0.006     -6.304      0.000      -0.047      -0.025
# x1            -0.0011      0.003     -0.395      0.693      -0.007       0.004
# ==============================================================================
# Omnibus:                       72.808   Durbin-Watson:                   2.182
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              239.694
# Skew:                          -0.764   Prob(JB):                     8.93e-53
# Kurtosis:                       6.366   Cond. No.                         2.04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Saves
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                   0.07657
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.782
# Time:                        11:25:21   Log-Likelihood:                 164.89
# No. Observations:                 226   AIC:                            -325.8
# Df Residuals:                     224   BIC:                            -318.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0337      0.008     -4.304      0.000      -0.049      -0.018
# x1            -0.0009      0.003     -0.277      0.782      -0.007       0.006
# ==============================================================================
# Omnibus:                       36.110   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              107.502
# Skew:                          -0.646   Prob(JB):                     4.53e-24
# Kurtosis:                       6.122   Cond. No.                         2.41
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# TVS
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     4.222
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):             0.0406
# Time:                        11:25:23   Log-Likelihood:                 306.42
# No. Observations:                 399   AIC:                            -608.8
# Df Residuals:                     397   BIC:                            -600.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0336      0.006     -5.969      0.000      -0.045      -0.023
# x1             0.0022      0.001      2.055      0.041    9.62e-05       0.004
# ==============================================================================
# Omnibus:                       68.262   Durbin-Watson:                   2.031
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              224.204
# Skew:                          -0.750   Prob(JB):                     2.06e-49
# Kurtosis:                       6.352   Cond. No.                         5.20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# WAR
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     3.430
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):             0.0648
# Time:                        11:25:25   Log-Likelihood:                 307.42
# No. Observations:                 414   AIC:                            -610.8
# Df Residuals:                     412   BIC:                            -602.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0355      0.006     -6.179      0.000      -0.047      -0.024
# x1             0.0103      0.006      1.852      0.065      -0.001       0.021
# ==============================================================================
# Omnibus:                       62.752   Durbin-Watson:                   2.256
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              215.707
# Skew:                          -0.647   Prob(JB):                     1.45e-47
# Kurtosis:                       6.291   Cond. No.                         1.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# WHIP
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     2.204
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.138
# Time:                        11:25:27   Log-Likelihood:                 308.11
# No. Observations:                 425   AIC:                            -612.2
# Df Residuals:                     423   BIC:                            -604.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0417      0.007     -6.055      0.000      -0.055      -0.028
# x1            -0.0105      0.007     -1.484      0.138      -0.024       0.003
# ==============================================================================
# Omnibus:                       66.373   Durbin-Watson:                   2.241
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              207.566
# Skew:                          -0.703   Prob(JB):                     8.47e-46
# Kurtosis:                       6.122   Cond. No.                         1.89
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Walks
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.6363
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.426
# Time:                        11:25:29   Log-Likelihood:                 308.62
# No. Observations:                 424   AIC:                            -613.2
# Df Residuals:                     422   BIC:                            -605.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0364      0.006     -6.230      0.000      -0.048      -0.025
# x1            -0.0010      0.001     -0.798      0.426      -0.003       0.001
# ==============================================================================
# Omnibus:                       67.884   Durbin-Watson:                   2.156
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              219.970
# Skew:                          -0.710   Prob(JB):                     1.71e-48
# Kurtosis:                       6.231   Cond. No.                         4.97
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Wins
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.8977
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.344
# Time:                        11:25:31   Log-Likelihood:                 310.26
# No. Observations:                 420   AIC:                            -616.5
# Df Residuals:                     418   BIC:                            -608.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0339      0.006     -5.968      0.000      -0.045      -0.023
# x1             0.0025      0.003      0.947      0.344      -0.003       0.008
# ==============================================================================
# Omnibus:                       64.950   Durbin-Watson:                   2.143
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              212.669
# Skew:                          -0.679   Prob(JB):                     6.60e-47
# Kurtosis:                       6.210   Cond. No.                         2.13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Bateos_pitcher_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9316
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.335
# Time:                        11:25:33   Log-Likelihood:                 307.47
# No. Observations:                 425   AIC:                            -610.9
# Df Residuals:                     423   BIC:                            -602.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0367      0.006     -6.371      0.000      -0.048      -0.025
# x1         -5.775e-05   5.98e-05     -0.965      0.335      -0.000    5.99e-05
# ==============================================================================
# Omnibus:                       66.579   Durbin-Watson:                   2.259
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              212.536
# Skew:                          -0.699   Prob(JB):                     7.05e-47
# Kurtosis:                       6.170   Cond. No.                         97.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Carreras_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     4.860
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):             0.0280
# Time:                        11:25:35   Log-Likelihood:                 310.73
# No. Observations:                 424   AIC:                            -617.5
# Df Residuals:                     422   BIC:                            -609.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0370      0.006     -6.481      0.000      -0.048      -0.026
# x1            -0.0003      0.000     -2.204      0.028      -0.001   -2.91e-05
# ==============================================================================
# Omnibus:                       67.623   Durbin-Watson:                   2.161
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              227.389
# Skew:                          -0.694   Prob(JB):                     4.20e-50
# Kurtosis:                       6.308   Cond. No.                         47.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Carreras_ganadas_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     2.959
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):             0.0861
# Time:                        11:25:37   Log-Likelihood:                 309.78
# No. Observations:                 424   AIC:                            -615.6
# Df Residuals:                     422   BIC:                            -607.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0364      0.006     -6.379      0.000      -0.048      -0.025
# x1            -0.0002      0.000     -1.720      0.086      -0.000    3.22e-05
# ==============================================================================
# Omnibus:                       65.254   Durbin-Watson:                   2.161
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              214.675
# Skew:                          -0.675   Prob(JB):                     2.42e-47
# Kurtosis:                       6.214   Cond. No.                         43.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Comando_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     5.710
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):             0.0173
# Time:                        11:25:39   Log-Likelihood:                 309.93
# No. Observations:                 423   AIC:                            -615.9
# Df Residuals:                     421   BIC:                            -607.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0357      0.006     -6.290      0.000      -0.047      -0.025
# x1             0.0042      0.002      2.390      0.017       0.001       0.008
# ==============================================================================
# Omnibus:                       70.229   Durbin-Watson:                   2.119
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              221.098
# Skew:                          -0.747   Prob(JB):                     9.75e-49
# Kurtosis:                       6.212   Cond. No.                         3.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Control_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                   0.09108
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.763
# Time:                        11:25:41   Log-Likelihood:                 308.34
# No. Observations:                 424   AIC:                            -612.7
# Df Residuals:                     422   BIC:                            -604.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0356      0.006     -6.175      0.000      -0.047      -0.024
# x1            -0.0499      0.165     -0.302      0.763      -0.375       0.275
# ==============================================================================
# Omnibus:                       68.933   Durbin-Watson:                   2.150
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              223.455
# Skew:                          -0.721   Prob(JB):                     3.00e-49
# Kurtosis:                       6.251   Cond. No.                         29.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Dominio_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.5558
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.456
# Time:                        11:25:43   Log-Likelihood:                 307.29
# No. Observations:                 425   AIC:                            -610.6
# Df Residuals:                     423   BIC:                            -602.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0352      0.006     -6.057      0.000      -0.047      -0.024
# x1             0.0435      0.058      0.745      0.456      -0.071       0.158
# ==============================================================================
# Omnibus:                       67.406   Durbin-Watson:                   2.259
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              213.155
# Skew:                          -0.711   Prob(JB):                     5.18e-47
# Kurtosis:                       6.165   Cond. No.                         10.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# ERA_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                   0.02026
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.887
# Time:                        11:25:45   Log-Likelihood:                 308.31
# No. Observations:                 424   AIC:                            -612.6
# Df Residuals:                     422   BIC:                            -604.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0356      0.006     -5.938      0.000      -0.047      -0.024
# x1            -0.0003      0.002     -0.142      0.887      -0.004       0.003
# ==============================================================================
# Omnibus:                       68.018   Durbin-Watson:                   2.149
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              220.974
# Skew:                          -0.710   Prob(JB):                     1.04e-48
# Kurtosis:                       6.239   Cond. No.                         3.52
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Inning_pitched_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9230
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.337
# Time:                        11:25:47   Log-Likelihood:                 307.47
# No. Observations:                 425   AIC:                            -610.9
# Df Residuals:                     423   BIC:                            -602.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0368      0.006     -6.372      0.000      -0.048      -0.025
# x1         -5.519e-05   5.74e-05     -0.961      0.337      -0.000    5.77e-05
# ==============================================================================
# Omnibus:                       65.079   Durbin-Watson:                   2.255
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              207.322
# Skew:                          -0.682   Prob(JB):                     9.56e-46
# Kurtosis:                       6.138   Cond. No.                         102.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Juegos_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                   0.06745
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.795
# Time:                        11:25:49   Log-Likelihood:                 307.04
# No. Observations:                 425   AIC:                            -610.1
# Df Residuals:                     423   BIC:                            -602.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0362      0.006     -6.250      0.000      -0.048      -0.025
# x1         -3.849e-05      0.000     -0.260      0.795      -0.000       0.000
# ==============================================================================
# Omnibus:                       67.300   Durbin-Watson:                   2.261
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              213.281
# Skew:                          -0.709   Prob(JB):                     4.86e-47
# Kurtosis:                       6.168   Cond. No.                         39.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Juegos_iniciados_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.7499
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.387
# Time:                        11:25:50   Log-Likelihood:                 190.13
# No. Observations:                 263   AIC:                            -376.3
# Df Residuals:                     261   BIC:                            -369.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0367      0.007     -5.020      0.000      -0.051      -0.022
# x1            -0.0003      0.000     -0.866      0.387      -0.001       0.000
# ==============================================================================
# Omnibus:                       42.537   Durbin-Watson:                   2.253
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              128.240
# Skew:                          -0.678   Prob(JB):                     1.42e-28
# Kurtosis:                       6.141   Cond. No.                         21.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Losses_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                   0.02092
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.885
# Time:                        11:25:52   Log-Likelihood:                 309.60
# No. Observations:                 421   AIC:                            -615.2
# Df Residuals:                     419   BIC:                            -607.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0356      0.006     -6.246      0.000      -0.047      -0.024
# x1            -0.0001      0.001     -0.145      0.885      -0.002       0.002
# ==============================================================================
# Omnibus:                       72.755   Durbin-Watson:                   2.183
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              238.427
# Skew:                          -0.765   Prob(JB):                     1.68e-52
# Kurtosis:                       6.355   Cond. No.                         5.86
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Saves_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.2749
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.601
# Time:                        11:25:53   Log-Likelihood:                 164.99
# No. Observations:                 226   AIC:                            -326.0
# Df Residuals:                     224   BIC:                            -319.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0334      0.008     -4.251      0.000      -0.049      -0.018
# x1            -0.0003      0.001     -0.524      0.601      -0.002       0.001
# ==============================================================================
# Omnibus:                       36.351   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              108.079
# Skew:                          -0.652   Prob(JB):                     3.40e-24
# Kurtosis:                       6.127   Cond. No.                         12.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# TVS_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     5.563
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):             0.0188
# Time:                        11:25:55   Log-Likelihood:                 307.09
# No. Observations:                 399   AIC:                            -610.2
# Df Residuals:                     397   BIC:                            -602.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0351      0.006     -6.215      0.000      -0.046      -0.024
# x1             0.0003      0.000      2.359      0.019    5.61e-05       0.001
# ==============================================================================
# Omnibus:                       67.282   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              219.390
# Skew:                          -0.741   Prob(JB):                     2.29e-48
# Kurtosis:                       6.317   Cond. No.                         39.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# WAR_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.659
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.198
# Time:                        11:25:57   Log-Likelihood:                 307.84
# No. Observations:                 425   AIC:                            -611.7
# Df Residuals:                     423   BIC:                            -603.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0368      0.006     -6.410      0.000      -0.048      -0.026
# x1             0.0044      0.003      1.288      0.198      -0.002       0.011
# ==============================================================================
# Omnibus:                       67.365   Durbin-Watson:                   2.263
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              213.949
# Skew:                          -0.709   Prob(JB):                     3.48e-47
# Kurtosis:                       6.174   Cond. No.                         1.71
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# WHIP_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.931
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.165
# Time:                        11:25:59   Log-Likelihood:                 307.97
# No. Observations:                 425   AIC:                            -611.9
# Df Residuals:                     423   BIC:                            -603.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0398      0.006     -6.284      0.000      -0.052      -0.027
# x1            -0.0086      0.006     -1.390      0.165      -0.021       0.004
# ==============================================================================
# Omnibus:                       66.722   Durbin-Watson:                   2.242
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              210.333
# Skew:                          -0.704   Prob(JB):                     2.12e-46
# Kurtosis:                       6.145   Cond. No.                         1.59
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Walks_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.2256
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.635
# Time:                        11:26:01   Log-Likelihood:                 308.41
# No. Observations:                 424   AIC:                            -612.8
# Df Residuals:                     422   BIC:                            -604.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0356      0.006     -6.225      0.000      -0.047      -0.024
# x1         -8.745e-05      0.000     -0.475      0.635      -0.000       0.000
# ==============================================================================
# Omnibus:                       68.080   Durbin-Watson:                   2.154
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              221.415
# Skew:                          -0.711   Prob(JB):                     8.32e-49
# Kurtosis:                       6.242   Cond. No.                         31.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Wins_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.1954
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.659
# Time:                        11:26:03   Log-Likelihood:                 309.91
# No. Observations:                 420   AIC:                            -615.8
# Df Residuals:                     418   BIC:                            -607.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0345      0.006     -6.094      0.000      -0.046      -0.023
# x1             0.0004      0.001      0.442      0.659      -0.001       0.002
# ==============================================================================
# Omnibus:                       64.094   Durbin-Watson:                   2.142
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              211.901
# Skew:                          -0.666   Prob(JB):                     9.69e-47
# Kurtosis:                       6.214   Cond. No.                         6.49
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Hitters
#
# Hagamos lo mismo para los *hitters*.

# %%
hitter_statistics_t = ['At-bats', 'Bateos', 'Home-runs', 'Juegos',
                       'OPS', 'Porcentaje_bateo', 'Porcetnaje_juegos',
                       'RBI', 'TVS', 'WAR', 'At-bats_2', 'Bateos_2',
                       'Home-runs_2', 'Juegos_2', 'OPS_2',
                       'Porcentaje_bateo_2', 'Porcetnaje_juegos_2',
                       'RBI_2', 'TVS_2', 'WAR_2']
Y_hitter_raw_t = 'ln_Sueldo'
hitter_Statistics_len = len(hitter_statistics_t)
hitter_model_t = [None]*hitter_Statistics_len
df_hitter_model_t = [None]*hitter_Statistics_len

# %%
for statistic in range(0,hitter_Statistics_len):
    df_hitter_model_t[statistic], hitter_model_t[statistic] = etl_regression(hitter_statistics_t[statistic],
                                                                             Y_hitter_raw_t, df_hitters_t_copy)
    
    print(colored(hitter_statistics_t[statistic], "cyan"))
    print(hitter_model_t[statistic].summary())
    print('\n')
# Out:
# At-bats
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     2.715
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.100
# Time:                        11:26:05   Log-Likelihood:                 348.75
# No. Observations:                 492   AIC:                            -693.5
# Df Residuals:                     490   BIC:                            -685.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0468      0.005     -8.598      0.000      -0.057      -0.036
# x1            -0.0006      0.000     -1.648      0.100      -0.001       0.000
# ==============================================================================
# Omnibus:                      127.193   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              471.122
# Skew:                          -1.137   Prob(JB):                    4.98e-103
# Kurtosis:                       7.221   Cond. No.                         15.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Bateos
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.019
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.313
# Time:                        11:26:07   Log-Likelihood:                 330.55
# No. Observations:                 472   AIC:                            -657.1
# Df Residuals:                     470   BIC:                            -648.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0479      0.006     -8.549      0.000      -0.059      -0.037
# x1            -0.0007      0.001     -1.009      0.313      -0.002       0.001
# ==============================================================================
# Omnibus:                      123.010   Durbin-Watson:                   2.089
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              457.358
# Skew:                          -1.140   Prob(JB):                    4.85e-100
# Kurtosis:                       7.250   Cond. No.                         7.70
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Home-runs
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.2498
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.618
# Time:                        11:26:09   Log-Likelihood:                 241.40
# No. Observations:                 361   AIC:                            -478.8
# Df Residuals:                     359   BIC:                            -471.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0498      0.007     -7.591      0.000      -0.063      -0.037
# x1            -0.0010      0.002     -0.500      0.618      -0.005       0.003
# ==============================================================================
# Omnibus:                       97.290   Durbin-Watson:                   2.147
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              354.955
# Skew:                          -1.149   Prob(JB):                     8.37e-78
# Kurtosis:                       7.280   Cond. No.                         3.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Juegos
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.447
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.230
# Time:                        11:26:11   Log-Likelihood:                 348.11
# No. Observations:                 492   AIC:                            -692.2
# Df Residuals:                     490   BIC:                            -683.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0471      0.006     -8.470      0.000      -0.058      -0.036
# x1            -0.0008      0.001     -1.203      0.230      -0.002       0.001
# ==============================================================================
# Omnibus:                      129.417   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              486.796
# Skew:                          -1.152   Prob(JB):                    1.97e-106
# Kurtosis:                       7.294   Cond. No.                         8.75
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# OPS
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.353
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.245
# Time:                        11:26:14   Log-Likelihood:                 339.17
# No. Observations:                 480   AIC:                            -674.3
# Df Residuals:                     478   BIC:                            -666.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0452      0.006     -8.123      0.000      -0.056      -0.034
# x1             0.0087      0.007      1.163      0.245      -0.006       0.023
# ==============================================================================
# Omnibus:                      124.506   Durbin-Watson:                   2.154
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              478.824
# Skew:                          -1.124   Prob(JB):                    1.06e-104
# Kurtosis:                       7.346   Cond. No.                         1.42
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Porcentaje_bateo
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                   0.03761
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.846
# Time:                        11:26:16   Log-Likelihood:                 330.06
# No. Observations:                 472   AIC:                            -656.1
# Df Residuals:                     470   BIC:                            -647.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0472      0.006     -8.419      0.000      -0.058      -0.036
# x1            -0.0024      0.013     -0.194      0.846      -0.027       0.022
# ==============================================================================
# Omnibus:                      124.340   Durbin-Watson:                   2.087
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              475.142
# Skew:                          -1.143   Prob(JB):                    6.67e-104
# Kurtosis:                       7.351   Cond. No.                         2.27
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Porcetnaje_juegos
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9976
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.318
# Time:                        11:26:18   Log-Likelihood:                 347.89
# No. Observations:                 492   AIC:                            -691.8
# Df Residuals:                     490   BIC:                            -683.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0464      0.005     -8.478      0.000      -0.057      -0.036
# x1            -0.0078      0.008     -0.999      0.318      -0.023       0.008
# ==============================================================================
# Omnibus:                      129.793   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              492.202
# Skew:                          -1.153   Prob(JB):                    1.32e-107
# Kurtosis:                       7.324   Cond. No.                         1.50
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# RBI
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.5325
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.466
# Time:                        11:26:21   Log-Likelihood:                 298.63
# No. Observations:                 438   AIC:                            -593.3
# Df Residuals:                     436   BIC:                            -585.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0470      0.006     -7.975      0.000      -0.059      -0.035
# x1            -0.0008      0.001     -0.730      0.466      -0.003       0.001
# ==============================================================================
# Omnibus:                      114.664   Durbin-Watson:                   2.257
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              430.005
# Skew:                          -1.132   Prob(JB):                     4.22e-94
# Kurtosis:                       7.293   Cond. No.                         5.66
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# TVS
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.572
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.210
# Time:                        11:26:23   Log-Likelihood:                 319.46
# No. Observations:                 462   AIC:                            -634.9
# Df Residuals:                     460   BIC:                            -626.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0459      0.006     -8.105      0.000      -0.057      -0.035
# x1             0.0013      0.001      1.254      0.210      -0.001       0.003
# ==============================================================================
# Omnibus:                      119.323   Durbin-Watson:                   2.197
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              445.417
# Skew:                          -1.125   Prob(JB):                     1.90e-97
# Kurtosis:                       7.252   Cond. No.                         5.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# WAR
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.088
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.149
# Time:                        11:26:25   Log-Likelihood:                 350.62
# No. Observations:                 474   AIC:                            -697.2
# Df Residuals:                     472   BIC:                            -688.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0439      0.005     -8.080      0.000      -0.055      -0.033
# x1             0.0065      0.005      1.445      0.149      -0.002       0.015
# ==============================================================================
# Omnibus:                      121.941   Durbin-Watson:                   2.409
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              530.533
# Skew:                          -1.070   Prob(JB):                    6.25e-116
# Kurtosis:                       7.720   Cond. No.                         1.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# At-bats_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     4.283
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):             0.0390
# Time:                        11:26:27   Log-Likelihood:                 349.53
# No. Observations:                 492   AIC:                            -695.1
# Df Residuals:                     490   BIC:                            -686.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0463      0.005     -8.595      0.000      -0.057      -0.036
# x1         -3.674e-05   1.78e-05     -2.070      0.039   -7.16e-05   -1.86e-06
# ==============================================================================
# Omnibus:                      125.654   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              461.876
# Skew:                          -1.125   Prob(JB):                    5.07e-101
# Kurtosis:                       7.180   Cond. No.                         304.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Bateos_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.919
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.167
# Time:                        11:26:30   Log-Likelihood:                 331.00
# No. Observations:                 472   AIC:                            -658.0
# Df Residuals:                     470   BIC:                            -649.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0476      0.006     -8.578      0.000      -0.059      -0.037
# x1         -9.423e-05    6.8e-05     -1.385      0.167      -0.000    3.94e-05
# ==============================================================================
# Omnibus:                      122.277   Durbin-Watson:                   2.088
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              451.981
# Skew:                          -1.135   Prob(JB):                     7.14e-99
# Kurtosis:                       7.223   Cond. No.                         81.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Home-runs_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.8251
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.364
# Time:                        11:26:31   Log-Likelihood:                 241.69
# No. Observations:                 361   AIC:                            -479.4
# Df Residuals:                     359   BIC:                            -471.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0494      0.007     -7.558      0.000      -0.062      -0.037
# x1            -0.0004      0.000     -0.908      0.364      -0.001       0.000
# ==============================================================================
# Omnibus:                       96.855   Durbin-Watson:                   2.154
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              351.953
# Skew:                          -1.145   Prob(JB):                     3.75e-77
# Kurtosis:                       7.261   Cond. No.                         14.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Juegos_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     2.669
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.103
# Time:                        11:26:34   Log-Likelihood:                 348.72
# No. Observations:                 492   AIC:                            -693.4
# Df Residuals:                     490   BIC:                            -685.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0468      0.005     -8.597      0.000      -0.057      -0.036
# x1            -0.0001   6.18e-05     -1.634      0.103      -0.000    2.04e-05
# ==============================================================================
# Omnibus:                      128.176   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              474.900
# Skew:                          -1.146   Prob(JB):                    7.53e-104
# Kurtosis:                       7.233   Cond. No.                         89.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# OPS_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.547
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.214
# Time:                        11:26:36   Log-Likelihood:                 339.27
# No. Observations:                 480   AIC:                            -674.5
# Df Residuals:                     478   BIC:                            -666.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0456      0.006     -8.282      0.000      -0.056      -0.035
# x1             0.0108      0.009      1.244      0.214      -0.006       0.028
# ==============================================================================
# Omnibus:                      124.447   Durbin-Watson:                   2.153
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              478.183
# Skew:                          -1.124   Prob(JB):                    1.46e-104
# Kurtosis:                       7.342   Cond. No.                         1.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Porcentaje_bateo_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                   0.02234
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.881
# Time:                        11:26:39   Log-Likelihood:                 330.05
# No. Observations:                 472   AIC:                            -656.1
# Df Residuals:                     470   BIC:                            -647.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0471      0.006     -8.474      0.000      -0.058      -0.036
# x1            -0.0036      0.024     -0.149      0.881      -0.051       0.044
# ==============================================================================
# Omnibus:                      124.265   Durbin-Watson:                   2.086
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              474.880
# Skew:                          -1.142   Prob(JB):                    7.60e-104
# Kurtosis:                       7.350   Cond. No.                         4.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Porcetnaje_juegos_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.620
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.204
# Time:                        11:26:42   Log-Likelihood:                 348.20
# No. Observations:                 492   AIC:                            -692.4
# Df Residuals:                     490   BIC:                            -684.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0460      0.005     -8.517      0.000      -0.057      -0.035
# x1            -0.0118      0.009     -1.273      0.204      -0.030       0.006
# ==============================================================================
# Omnibus:                      128.930   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              484.540
# Skew:                          -1.148   Prob(JB):                    6.08e-106
# Kurtosis:                       7.286   Cond. No.                         1.73
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# RBI_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9457
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.331
# Time:                        11:26:44   Log-Likelihood:                 298.84
# No. Observations:                 438   AIC:                            -593.7
# Df Residuals:                     436   BIC:                            -585.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0466      0.006     -7.951      0.000      -0.058      -0.035
# x1            -0.0001      0.000     -0.972      0.331      -0.000       0.000
# ==============================================================================
# Omnibus:                      114.035   Durbin-Watson:                   2.258
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              428.284
# Skew:                          -1.125   Prob(JB):                     9.99e-94
# Kurtosis:                       7.290   Cond. No.                         44.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# TVS_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     2.866
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):             0.0911
# Time:                        11:26:46   Log-Likelihood:                 320.10
# No. Observations:                 462   AIC:                            -636.2
# Df Residuals:                     460   BIC:                            -627.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0472      0.006     -8.229      0.000      -0.058      -0.036
# x1             0.0002      0.000      1.693      0.091   -3.92e-05       0.001
# ==============================================================================
# Omnibus:                      119.057   Durbin-Watson:                   2.193
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              442.311
# Skew:                          -1.124   Prob(JB):                     8.98e-97
# Kurtosis:                       7.234   Cond. No.                         40.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# WAR_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.022
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):              0.313
# Time:                        11:26:48   Log-Likelihood:                 341.76
# No. Observations:                 486   AIC:                            -679.5
# Df Residuals:                     484   BIC:                            -671.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0469      0.006     -8.450      0.000      -0.058      -0.036
# x1             0.0026      0.003      1.011      0.313      -0.002       0.008
# ==============================================================================
# Omnibus:                      126.326   Durbin-Watson:                   2.390
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              487.535
# Skew:                          -1.127   Prob(JB):                    1.36e-106
# Kurtosis:                       7.358   Cond. No.                         2.20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
